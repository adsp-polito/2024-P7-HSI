# %% [markdown]
# # **Data Preprocessing**

# %% [markdown]
# This notebook is dedicated to the **Data Processing Phase** of the project. Below are the key steps performed in this notebook:
#
# 1. **Loading and Inspecting the Dataset**: The raw hyperspectral dataset is loaded, visualized, and analyzed for its key properties.
# 2. **Noise Channel Detection and Removal**: Identifies and removes noisy channels based on visual inspection and statistical analysis to improve data quality.
# 3. **Data Normalization**: Applies standard normalization to ensure all spectral bands contribute equally to the variance.
# 4. **Dimensionality Reduction**: Performs PCA to reduce the dataset's dimensionality while retaining meaningful information.
# 5. **Tiling and Data Splitting**: Divides the dataset into smaller tiles and splits it into training, validation, and test sets to prevent data leakage.
# 6. **Data Augmentation**: Implements data augmentation techniques to address class imbalance and improve model generalization.
#
# At the end of this notebook, the processed dataset is saved, making it ready for use in the **Train Models Notebook** and **Test Models Notebook**

# %% [markdown]
# ## 1. Setup

# %% [markdown]
# ### 1.1 Install and Import Libraries

# %%
# !pip install \
    scipy \
    numpy \
    pandas \
    scikit-learn \
    tensorflow \
    matplotlib \
    joblib \
    scikit-image \
    opencv-python-headless \
    xgboost


import os
import pickle
import random
import gc
from multiprocessing import Pool
import joblib

import cv2
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.io
from google.colab import drive
from joblib import Parallel, delayed
from scipy.spatial.distance import euclidean
from skimage.transform import resize
from skimage.util import random_noise
from sklearn.decomposition import PCA
from scipy.stats import entropy
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    f1_score,
    roc_auc_score,
    accuracy_score,
    precision_score,
    recall_score,
    confusion_matrix
)
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import models
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.optimizers import Adam
import xgboost as xgb
# Out:
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (1.13.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.6.1)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.17.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (1.4.2)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.11/dist-packages (0.25.0)
# Collecting opencv-python-headless
#   Downloading opencv_python_headless-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting xgboost
#   Downloading xgboost-2.1.3-py3-none-manylinux_2_28_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.1.21)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.69.0)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.55.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (3.4.2)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (2025.1.10)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (0.4)
# Collecting nvidia-nccl-cu12 (from xgboost)
#   Downloading nvidia_nccl_cu12-2.25.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->tensorflow) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.12.14)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)
# Downloading opencv_python_headless-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (50.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.0/50.0 MB 23.1 MB/s eta 0:00:00
# Downloading xgboost-2.1.3-py3-none-manylinux_2_28_x86_64.whl (153.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.9/153.9 MB 6.6 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.25.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (201.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.4/201.4 MB 5.0 MB/s eta 0:00:00
# Installing collected packages: opencv-python-headless, nvidia-nccl-cu12, xgboost
# Successfully installed nvidia-nccl-cu12-2.25.1 opencv-python-headless-4.11.0.86 xgboost-2.1.3

# %% [markdown]
# ### 1.2 Setting Seeds

# %%
seed = 42
np.random.seed(seed)
tf.random.set_seed(seed)
random.seed(seed)

# %% [markdown]
# ### 1.3 Connect to Google Drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 1.4 Common Functions

# %%
# Used in
# 2.Data Loading,
# 3.3 Remove Noise Channels
def flatten_data(images, labels):
    """
    Flatten the HSI images and labels.

    Parameters:
    - images (list): List of HSI images.
    - labels (list): List of HSI labels.

    Returns:
    - all_data (ndarray): Flattened HSI images.
    - all_labels (ndarray): Flattened HSI labels.
    """
    flattened_images = [image.reshape(-1, image.shape[-1]) for image in images]
    flattened_labels = [label.flatten() for label in labels]

    print("\nCombining flattened data...")
    all_data = np.vstack(flattened_images)
    all_labels = np.hstack(flattened_labels)

    print(f"\nFinal combined data shape: {all_data.shape}")
    print(f"Final combined labels shape: {all_labels.shape}")
    return all_data, all_labels

# %% [markdown]
# ## 2. Data Loading

# %%
def load_and_separate_hsi_images(folder_path):
    """
    Load hyperspectral images from .mat files in the specified folder and separate them into images and labels.
    Ignores metadata keys (starting with '__').

    Parameters:
    - folder_path (str): Path to the folder containing .mat files.

    Returns:
    - hsi_images_list (list): List of loaded hyperspectral images.
    - hsi_images_labels_list (list): List of corresponding labels.
    """
    hsi_images_list = []
    hsi_images_labels_list = []

    # Get and sort all .mat files in the specified folder
    file_names = sorted(
        [file for file in os.listdir(folder_path) if file.endswith('.mat')]
    )
    print(f"Found {len(file_names)} .mat files in the folder.")

    for file_name in file_names:
        file_path = os.path.join(folder_path, file_name)

        # Load the .mat file
        mat_data = scipy.io.loadmat(file_path)

        # Append all variables in the .mat file to the dataset, excluding metadata
        for key in mat_data:
            if not key.startswith('__'):
                if (len(hsi_images_list) + len(hsi_images_labels_list) + 1) % 2 == 1:
                    hsi_images_list.append(mat_data[key])
                    print(f"Loaded image/key '{key}' with shape {mat_data[key].shape} from {file_name}")
                else:
                    hsi_images_labels_list.append(mat_data[key])
                    print(f"Loaded label/key '{key}' with shape {mat_data[key].shape} from {file_name}")

    print(f"Total HSI images: {len(hsi_images_list)}")
    print(f"Total HSI labels: {len(hsi_images_labels_list)}")
    return hsi_images_list, hsi_images_labels_list


# Specify the folder containing the dataset
dataset_folder = '/content/drive/MyDrive/DataSets/HSI'

# Load and separate the HSI images and labels
hsi_images_list, hsi_images_labels_list = load_and_separate_hsi_images(dataset_folder)

# Flatten all images and labels
all_data, all_labels = flatten_data(hsi_images_list, hsi_images_labels_list)

print(f"All data shape: {all_data.shape}")
print(f"All labels shape: {all_labels.shape}")
# Out:
# Found 18 .mat files in the folder.
# Loaded image/key 'img' with shape (1243, 684, 224) from GM01.mat
# Loaded label/key 'map' with shape (1243, 684) from GM01.mat
# Loaded image/key 'img' with shape (1786, 699, 224) from GM02.mat
# Loaded label/key 'map' with shape (1786, 699) from GM02.mat
# Loaded image/key 'img' with shape (1386, 690, 224) from GM03.mat
# Loaded label/key 'map' with shape (1386, 690) from GM03.mat
# Loaded image/key 'img' with shape (1466, 676, 224) from GM04.mat
# Loaded label/key 'map' with shape (1466, 676) from GM04.mat
# Loaded image/key 'img' with shape (2085, 682, 224) from GM05.mat
# Loaded label/key 'map' with shape (2085, 682) from GM05.mat
# Loaded image/key 'img' with shape (2088, 691, 224) from GM06.mat
# Loaded label/key 'map' with shape (2088, 691) from GM06.mat
# Loaded image/key 'img' with shape (1965, 492, 224) from GM07.mat
# Loaded label/key 'map' with shape (1965, 492) from GM07.mat
# Loaded image/key 'img' with shape (1532, 567, 224) from GM08.mat
# Loaded label/key 'map' with shape (1532, 567) from GM08.mat
# Loaded image/key 'img' with shape (1569, 517, 224) from GM09.mat
# Loaded label/key 'map' with shape (1569, 517) from GM09.mat
# Loaded image/key 'img' with shape (1084, 680, 224) from GM10.mat
# Loaded label/key 'map' with shape (1084, 680) from GM10.mat
# Loaded image/key 'img' with shape (1185, 682, 224) from GM11.mat
# Loaded label/key 'map' with shape (1185, 682) from GM11.mat
# Loaded image/key 'img' with shape (842, 640, 224) from GM12.mat
# Loaded label/key 'map' with shape (842, 640) from GM12.mat
# Loaded image/key 'img' with shape (836, 572, 224) from GM13.mat
# Loaded label/key 'map' with shape (836, 572) from GM13.mat
# Loaded image/key 'img' with shape (1342, 527, 224) from GM14.mat
# Loaded label/key 'map' with shape (1342, 527) from GM14.mat
# Loaded image/key 'img' with shape (1260, 523, 224) from GM15.mat
# Loaded label/key 'map' with shape (1260, 523) from GM15.mat
# Loaded image/key 'img' with shape (1033, 437, 224) from GM16.mat
# Loaded label/key 'map' with shape (1033, 437) from GM16.mat
# Loaded image/key 'img' with shape (600, 400, 224) from GM17.mat
# Loaded label/key 'map' with shape (600, 400) from GM17.mat
# Loaded image/key 'img' with shape (1175, 563, 224) from GM18.mat
# Loaded label/key 'map' with shape (1175, 563) from GM18.mat
# Total HSI images: 18
# Total HSI labels: 18
#
# Combining flattened data...
#
# Final combined data shape: (14838879, 224)
# Final combined labels shape: (14838879,)
# All data shape: (14838879, 224)
# All labels shape: (14838879,)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Replace this with your actual `all_labels` array
# Example: all_labels = np.array([...])

# Count the occurrences of each label
unique_labels, counts = np.unique(all_labels, return_counts=True)

# Define labels and colors for the pie chart
categories = ['Water', 'Oil']
colors = ['lightblue', 'Gray']


# Create the pie chart
plt.figure(figsize=(10, 10))
explode = [0, 0.1]  # Highlight the 'Yes' category by separating it slightly
wedges, texts, autotexts = plt.pie(
    counts,
    explode=explode,  # Explode the 'Yes' section
    labels=None,  # External labels added manually
    autopct='%1.0f%%',  # Display percentages inside
    startangle=90,  # Start from the top
    colors=colors,  # Define slice colors
    textprops={'color': 'black'},
    pctdistance=0.8  # Position percentages closer to the center
)

# Add category names outside the pie chart
for i, wedge in enumerate(wedges):
    angle = (wedge.theta2 + wedge.theta1) / 2  # Find the middle angle of the wedge
    x = 1.2 * wedge.r * np.cos(np.radians(angle))  # Adjust x position for label
    y = 1.2 * wedge.r * np.sin(np.radians(angle))  # Adjust y position for label
    plt.text(
        x, y,
        categories[i],
        fontsize=22,  # Font size for category names
        fontweight='bold',
        color=colors[i],  # Use the same color as the pie slice
        ha='center',
        va='center'
    )

# Customize percentage labels inside the pie chart
for autotext in autotexts:
    autotext.set_fontsize(22)  # Increase font size for percentages
    autotext.set_color('white')  # Use white font color for better visibility


# Display the chart
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Replace this with your actual `all_labels` array
# Example: all_labels = np.array([...])

# Dummy data for the example
categories = ['No', 'Yes']
counts = [95, 5]  # Example data: 90% No, 10% Yes
colors = ['blue', 'lightblue']  # Colors for the slices

# Create the pie chart
plt.figure(figsize=(10, 10))
explode = [0, 0.1]  # Highlight the 'Yes' category by slightly separating it
wedges, texts, autotexts = plt.pie(
    counts,
    explode=explode,  # Explode the 'Yes' section
    labels=None,  # Labels will be manually added inside the pie chart
    autopct='%1.0f%%',  # Display percentages as integers
    startangle=90,  # Start from the top
    colors=colors,  # Define slice colors
    textprops={'color': 'black'},
    pctdistance=0.8  # Adjust percentage position closer to the slice center
)

# Add category names and percentages inside the pie chart
for i, autotext in enumerate(autotexts):
    autotext.set_text(f"{categories[i]}, {autotext.get_text()}")
    if colors[i] == 'blue':
        autotext.set_color('white')  # White text for blue section
    autotext.set_fontsize(22)  # Larger font size for labels

# Add title
plt.title('Student and Faculty Response to the Poll\n"Should Avenue High School Adopt Student Uniform?"',
          fontsize=24, weight='bold', ha='center')

# Display the chart
plt.show()

# %% [markdown]
# ## 3. Detect Noise Channels Using Visualization

# %%
# Visual inspection for each channel
def visualize_hsi_channels_individually(hsi_images, num_channels):
    """
    Visualize each channel of each HSI image.
    """
    for image_idx, image in enumerate(hsi_images):
        print(f"Visualizing image {image_idx + 1} with shape {image.shape}")
        for channel in range(num_channels):
            plt.figure(figsize=(6, 6))
            plt.title(f"Image {image_idx + 1} - Channel {channel + 1}")
            plt.imshow(image[:, :, channel], cmap='gray')
            plt.colorbar()
            plt.show()

# Visualize channels without resizing
num_channels = 1   ## hsi_images_list[0].shape[-1]
visualize_hsi_channels_individually(hsi_images_list, num_channels)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ### 3.1 Compare A Normal Channel with Noisy Channels

# %%
import random
import matplotlib.pyplot as plt

# Define the list of noisy and non-noisy channels
noisy_channels = [106, 103, 107, 108, 109, 110, 111, 112, 113, 114, 152, 153, 154, 155, 156,
                  157, 158, 159, 160, 161, 162, 163, 164, 165, 166, 167, 168, 169, 221, 222, 223]

# Function to visualize specific channels
def visualize_selected_channels(image, noisy_channels, num_noisy=3):
    """
    Visualize one normal channel followed by a specified number of noisy channels for a given image.

    Parameters:
    - image: The HSI image to visualize.
    - noisy_channels: List of indices of noisy channels.
    - num_noisy: Number of noisy channels to randomly select.
    """
    # Identify non-noisy channels
    total_channels = image.shape[-1]
    all_channels = set(range(total_channels))
    non_noisy_channels = list(all_channels - set(noisy_channels))

    # Randomly select one normal channel
    selected_normal_channel = random.choice(non_noisy_channels)

    # Randomly select noisy channels
    selected_noisy_channels = random.sample(noisy_channels, num_noisy)

    # Combine the channels in the desired order (normal first)
    selected_channels = [selected_normal_channel] + selected_noisy_channels
    titles = [f"Normal Channel {selected_normal_channel}"] + [f"Noisy Channel {ch}" for ch in selected_noisy_channels]

    # Plot the selected channels horizontally with tighter spacing
    plt.figure(figsize=(16, 4))
    for i, channel in enumerate(selected_channels):
        ax = plt.subplot(1, len(selected_channels), i + 1)
        im = plt.imshow(image[:, :, channel], cmap='gray')
        ax.set_title(titles[i], fontsize=12, pad=5)  # Reduce padding for titles
        plt.axis('off')

        # Add a color bar with reduced spacing
        cbar = plt.colorbar(im, ax=ax, fraction=0.025, pad=0.02)  # Adjust fraction and pad for compact color bars
        cbar.ax.tick_params(labelsize=8)  # Adjust color bar tick size

    plt.tight_layout(pad=1.0, w_pad=1.0)  # Reduce overall subplot padding
    plt.show()


image_index = 1  # Python is zero-indexed
visualize_selected_channels(hsi_images_list[image_index], noisy_channels)

# %% [markdown]
# ## 4. Remove Noise Channels

# %% [markdown]
# This piece of code removes the noisy channels from the loaded dataset, and updates the variables `hsi_images_list` and `all_data`.

# %%
vis_noisy_channels = [
    106, 103, 107, 108, 109, 110, 111, 112, 113, 114, 152, 153, 154, 155, 156,
    157, 158, 159, 160, 161, 162, 163, 164, 165, 166, 167, 168, 169, 221, 222, 223
]

def remove_noise_chanels(hsi_dataset, noisy_channels):
    """
    Process the HSI dataset by removing noisy channels from images.

    Parameters:
    - hsi_dataset (list): List of HSI images and labels.
    - noisy_channels (list): List of indices of noisy channels to be removed.

    Returns:
    - cleaned_images (list): List of cleaned HSI images.
    - labels (list): List of HSI labels.
    """
    cleaned_images = []

    print("\nProcessing HSI dataset and removing noisy channels...")
    for i, hsi_image in enumerate(hsi_dataset):
        clean_image = np.delete(hsi_image, noisy_channels, axis=-1)
        cleaned_images.append(clean_image)
        print(f"Image {i + 1}: Cleaned shape {clean_image.shape} after removing {len(noisy_channels)} channels.")

    print(f"\nTotal cleaned HSI images: {len(cleaned_images)}")
    return cleaned_images



# Process and clean the HSI dataset
hsi_images_list = remove_noise_chanels(hsi_images_list, vis_noisy_channels)

# Flatten all images and labels
all_data, all_labels = flatten_data(hsi_images_list, hsi_images_labels_list)

print(f"All data shape: {all_data.shape}")
print(f"All labels shape: {all_labels.shape}")
# Out:
# Processing HSI dataset and removing noisy channels...
# Image 1: Cleaned shape (1243, 684, 193) after removing 31 channels.
# Image 2: Cleaned shape (1786, 699, 193) after removing 31 channels.
# Image 3: Cleaned shape (1386, 690, 193) after removing 31 channels.
# Image 4: Cleaned shape (1466, 676, 193) after removing 31 channels.
# Image 5: Cleaned shape (2085, 682, 193) after removing 31 channels.
# Image 6: Cleaned shape (2088, 691, 193) after removing 31 channels.
# Image 7: Cleaned shape (1965, 492, 193) after removing 31 channels.
# Image 8: Cleaned shape (1532, 567, 193) after removing 31 channels.
# Image 9: Cleaned shape (1569, 517, 193) after removing 31 channels.
# Image 10: Cleaned shape (1084, 680, 193) after removing 31 channels.
# Image 11: Cleaned shape (1185, 682, 193) after removing 31 channels.
# Image 12: Cleaned shape (842, 640, 193) after removing 31 channels.
# Image 13: Cleaned shape (836, 572, 193) after removing 31 channels.
# Image 14: Cleaned shape (1342, 527, 193) after removing 31 channels.
# Image 15: Cleaned shape (1260, 523, 193) after removing 31 channels.
# Image 16: Cleaned shape (1033, 437, 193) after removing 31 channels.
# Image 17: Cleaned shape (600, 400, 193) after removing 31 channels.
# Image 18: Cleaned shape (1175, 563, 193) after removing 31 channels.
#
# Total cleaned HSI images: 18
#
# Combining flattened data...
#
# Final combined data shape: (14838879, 193)
# Final combined labels shape: (14838879,)
# All data shape: (14838879, 224)
# All labels shape: (14838879,)

# %%
hsi_images_labels_list[0].shape
# Out:
# (1243, 684)

# %%
vis_noisy_channels = [
    106, 103, 107, 108, 109, 110, 111, 112, 113, 114, 152, 153, 154, 155, 156,
    157, 158, 159, 160, 161, 162, 163, 164, 165, 166, 167, 168, 169, 221, 222, 223
]

def remove_noise_chanels(hsi_dataset, noisy_channels):
    """
    Process the HSI dataset by removing noisy channels from images.

    Parameters:
    - hsi_dataset (list): List of HSI images and labels.
    - noisy_channels (list): List of indices of noisy channels to be removed.

    Returns:
    - cleaned_images (list): List of cleaned HSI images.
    - labels (list): List of HSI labels.
    """
    cleaned_images = []

    print("\nProcessing HSI dataset and removing noisy channels...")
    for i, hsi_image in enumerate(hsi_dataset):
        clean_image = np.delete(hsi_image, noisy_channels, axis=-1)
        cleaned_images.append(clean_image)
        print(f"Image {i + 1}: Cleaned shape {clean_image.shape} after removing {len(noisy_channels)} channels.")

    print(f"\nTotal cleaned HSI images: {len(cleaned_images)}")
    return cleaned_images



# Process and clean the HSI dataset
hsi_images_list = remove_noise_chanels(hsi_images_list, vis_noisy_channels)

# Flatten all images and labels
all_data_filtered, all_labels = flatten_data(hsi_images_list, hsi_images_labels_list)

print(f"All data shape: {all_data.shape}")
print(f"All labels shape: {all_labels.shape}")
# Out:
# Processing HSI dataset and removing noisy channels...
# Image 1: Cleaned shape (1243, 684, 193) after removing 31 channels.
# Image 2: Cleaned shape (1786, 699, 193) after removing 31 channels.
# Image 3: Cleaned shape (1386, 690, 193) after removing 31 channels.
# Image 4: Cleaned shape (1466, 676, 193) after removing 31 channels.
# Image 5: Cleaned shape (2085, 682, 193) after removing 31 channels.
# Image 6: Cleaned shape (2088, 691, 193) after removing 31 channels.
# Image 7: Cleaned shape (1965, 492, 193) after removing 31 channels.
# Image 8: Cleaned shape (1532, 567, 193) after removing 31 channels.
# Image 9: Cleaned shape (1569, 517, 193) after removing 31 channels.
# Image 10: Cleaned shape (1084, 680, 193) after removing 31 channels.
# Image 11: Cleaned shape (1185, 682, 193) after removing 31 channels.
# Image 12: Cleaned shape (842, 640, 193) after removing 31 channels.
# Image 13: Cleaned shape (836, 572, 193) after removing 31 channels.
# Image 14: Cleaned shape (1342, 527, 193) after removing 31 channels.
# Image 15: Cleaned shape (1260, 523, 193) after removing 31 channels.
# Image 16: Cleaned shape (1033, 437, 193) after removing 31 channels.
# Image 17: Cleaned shape (600, 400, 193) after removing 31 channels.
# Image 18: Cleaned shape (1175, 563, 193) after removing 31 channels.
#
# Total cleaned HSI images: 18
#
# Combining flattened data...
#
# Final combined data shape: (14838879, 193)
# Final combined labels shape: (14838879,)
# All data shape: (14838879, 224)
# All labels shape: (14838879,)

# %% [markdown]
# ## 5. Tile Data and Split To Train, Validation, Test Sets

# %%
def split_into_tiles(image, label, mask, tile_size):
    """
    Splits the pre-padded image, label, and mask into tiles.

    Parameters:
    - image (np.ndarray): Padded input image.
    - label (np.ndarray): Padded corresponding label.
    - mask (np.ndarray): Binary mask indicating real pixels in the padded image.
    - tile_size (tuple): (tile_height, tile_width) specifying the size of the tiles.

    Returns:
    - tiles (np.ndarray): List of image tiles.
    - label_tiles (np.ndarray): List of label tiles.
    - mask_tiles (np.ndarray): List of mask tiles.
    """
    h, w, _ = image.shape
    tiles, label_tiles, mask_tiles = [], [], []

    for i in range(0, h, tile_size[0]):
        for j in range(0, w, tile_size[1]):
            img_tile = image[i:i + tile_size[0], j:j + tile_size[1], :]
            lbl_tile = label[i:i + tile_size[0], j:j + tile_size[1]]
            msk_tile = mask[i:i + tile_size[0], j:j + tile_size[1]]

            if img_tile.shape[:2] == tile_size:
                tiles.append(img_tile)
                label_tiles.append(np.expand_dims(lbl_tile, axis=-1))  # Add channel dimension
                mask_tiles.append(msk_tile)

    print(f"Split image into {len(tiles)} tiles.")
    return np.array(tiles), np.array(label_tiles), np.array(mask_tiles)


def custom_padding(image, label, tile_size):
    """
    Custom padding that uses the average value of water pixels (label=0) for padding.

    Parameters:
    - image (np.ndarray): Input image (H, W, C).
    - label (np.ndarray): Corresponding label (H, W).
    - tile_size (tuple): (tile_height, tile_width).

    Returns:
    - padded_image (np.ndarray): Image padded with average water pixel values.
    - padded_label (np.ndarray): Label padded with zeros.
    - mask (np.ndarray): Binary mask indicating original, unpadded regions.
    """
    h, w, c = image.shape
    pad_h = (tile_size[0] - h % tile_size[0]) % tile_size[0]
    pad_w = (tile_size[1] - w % tile_size[1]) % tile_size[1]

    # Calculate average water pixel value across channels
    water_mask = (label == 0)
    water_mask_expanded = np.repeat(water_mask[:, :, np.newaxis], c, axis=2)
    avg_water_value = (
        image[water_mask_expanded].reshape(-1, c).mean(axis=0)
        if np.any(water_mask)
        else np.zeros(c)
    )

    # Pad each channel
    padded_channels = []
    for channel in range(c):
        padded_channel = np.pad(
            image[:, :, channel],
            ((0, pad_h), (0, pad_w)),
            mode="constant",
            constant_values=avg_water_value[channel],
        )
        padded_channels.append(padded_channel)

    padded_image = np.stack(padded_channels, axis=-1)

    # Pad label
    padded_label = np.pad(label, ((0, pad_h), (0, pad_w)), mode="constant", constant_values=0)

    # Create mask
    mask = np.ones((h, w), dtype=bool)
    mask = np.pad(mask, ((0, pad_h), (0, pad_w)), mode="constant", constant_values=False)

    print(f"Padded image shape: {padded_image.shape}")
    print(f"Padded label shape: {padded_label.shape}")

    return padded_image, padded_label, mask


def preprocess_and_split(images, labels, tile_size, train_ratio=0.6, test_ratio=0.2, val_ratio=0.2):
    """
    Preprocess images and labels into tiles, and split them into train, test, and validation sets.

    Parameters:
    - images (list): List of input images as NumPy arrays.
    - labels (list): List of corresponding labels as NumPy arrays.
    - tile_size (tuple): (tile_height, tile_width) specifying the size of the tiles.
    - train_ratio (float): Ratio of tiles for the training set.
    - test_ratio (float): Ratio of tiles for the testing set.
    - val_ratio (float): Ratio of tiles for the validation set.

    Returns:
    - train_images, train_labels: Tiles and labels for training.
    - val_images, val_labels: Tiles and labels for validation.
    - test_images, test_labels, test_masks: Tiles, labels, and masks for testing.
    """
    assert train_ratio + test_ratio + val_ratio == 1.0, "Ratios must sum to 1."

    train_images, train_labels = [], []
    test_images, test_labels, test_masks = [], [], []
    val_images, val_labels = [], []

    for idx in range(len(images)):
        # Apply custom padding
        image_padded, label_padded, mask = custom_padding(images[idx], labels[idx], tile_size)

        # Split into tiles
        tiles, lbl_tiles, mask_tiles = split_into_tiles(image_padded, label_padded, mask, tile_size)

        # Shuffle tiles
        combined = list(zip(tiles, lbl_tiles))
        np.random.shuffle(combined)
        tiles, lbl_tiles = zip(*combined) if combined else ([], [])

        # Split into train, test, and validation sets
        total_tiles = len(tiles)
        train_count = int(total_tiles * train_ratio)
        test_count = int(total_tiles * test_ratio)

        train_images.extend(tiles[:train_count])
        train_labels.extend(lbl_tiles[:train_count])

        val_images.extend(tiles[train_count:train_count + test_count])
        val_labels.extend(lbl_tiles[train_count:train_count + test_count])

        test_images.extend(tiles[train_count + test_count:])
        test_labels.extend(lbl_tiles[train_count + test_count:])
        test_masks.extend(mask_tiles[train_count + test_count:])

    # Normalize images and convert labels
    train_images = np.array(train_images) / 255.0
    train_labels = np.array(train_labels).astype("float32")

    test_images = np.array(test_images) / 255.0
    test_labels = np.array(test_labels).astype("float32")
    test_masks = np.array(test_masks)

    val_images = np.array(val_images) / 255.0
    val_labels = np.array(val_labels).astype("float32")

    print(f"\nTrain images: {train_images.shape}, Train labels: {train_labels.shape}")
    print(f"Validation images: {val_images.shape}, Validation labels: {val_labels.shape}")
    print(f"Test images: {test_images.shape}, Test labels: {test_labels.shape}, Test masks: {test_masks.shape}")

    return train_images, train_labels, val_images, val_labels, test_images, test_labels, test_masks


# Example data
images = hsi_images_list  # Replace with your actual dataset
labels = hsi_images_labels_list  # Replace with your actual labels
tile_size = (64, 64)

# Preprocess and split the data
train_images, train_labels, val_images, val_labels, test_images, test_labels, test_masks = preprocess_and_split(
    images, labels, tile_size
)
# Out:
# Padded image shape: (1280, 704, 193)
# Padded label shape: (1280, 704)
# Split image into 220 tiles.
# Padded image shape: (1792, 704, 193)
# Padded label shape: (1792, 704)
# Split image into 308 tiles.
# Padded image shape: (1408, 704, 193)
# Padded label shape: (1408, 704)
# Split image into 242 tiles.
# Padded image shape: (1472, 704, 193)
# Padded label shape: (1472, 704)
# Split image into 253 tiles.
# Padded image shape: (2112, 704, 193)
# Padded label shape: (2112, 704)
# Split image into 363 tiles.
# Padded image shape: (2112, 704, 193)
# Padded label shape: (2112, 704)
# Split image into 363 tiles.
# Padded image shape: (1984, 512, 193)
# Padded label shape: (1984, 512)
# Split image into 248 tiles.
# Padded image shape: (1536, 576, 193)
# Padded label shape: (1536, 576)
# Split image into 216 tiles.
# Padded image shape: (1600, 576, 193)
# Padded label shape: (1600, 576)
# Split image into 225 tiles.
# Padded image shape: (1088, 704, 193)
# Padded label shape: (1088, 704)
# Split image into 187 tiles.
# Padded image shape: (1216, 704, 193)
# Padded label shape: (1216, 704)
# Split image into 209 tiles.
# Padded image shape: (896, 640, 193)
# Padded label shape: (896, 640)
# Split image into 140 tiles.
# Padded image shape: (896, 576, 193)
# Padded label shape: (896, 576)
# Split image into 126 tiles.
# Padded image shape: (1344, 576, 193)
# Padded label shape: (1344, 576)
# Split image into 189 tiles.
# Padded image shape: (1280, 576, 193)
# Padded label shape: (1280, 576)
# Split image into 180 tiles.
# Padded image shape: (1088, 448, 193)
# Padded label shape: (1088, 448)
# Split image into 119 tiles.
# Padded image shape: (640, 448, 193)
# Padded label shape: (640, 448)
# Split image into 70 tiles.
# Padded image shape: (1216, 576, 193)
# Padded label shape: (1216, 576)
# Split image into 171 tiles.
#
# Train images: (2290, 64, 64, 193), Train labels: (2290, 64, 64, 1)
# Validation images: (759, 64, 64, 193), Validation labels: (759, 64, 64, 1)
# Test images: (780, 64, 64, 193), Test labels: (780, 64, 64, 1), Test masks: (780, 64, 64)

# %% [markdown]
# ## 6. Data Augmentation

# %%
def rotate_image(image, label, angle):
    """
    Rotate the image and label by a given angle.

    Parameters:
    - image: NumPy array of the image.
    - label: NumPy array of the label.
    - angle: Rotation angle in degrees.

    Returns:
    - rotated_image: Rotated image.
    - rotated_label: Rotated label.
    """
    print(f"Rotating image by {angle} degrees.")
    center = (image.shape[1] // 2, image.shape[0] // 2)
    rotation_matrix = cv2.getRotationMatrix2D(center, angle, 1.0)
    rotated_image = cv2.warpAffine(image, rotation_matrix, (image.shape[1], image.shape[0]))
    rotated_label = cv2.warpAffine(label, rotation_matrix, (label.shape[1], label.shape[0]), flags=cv2.INTER_NEAREST)
    return rotated_image, rotated_label


def flip_image(image, label):
    """
    Flip the image and label randomly either horizontally or vertically.

    Parameters:
    - image: NumPy array of the image.
    - label: NumPy array of the label.

    Returns:
    - flipped_image: Flipped image.
    - flipped_label: Flipped label.
    """
    flip_type = "vertical" if random.choice([True, False]) else "horizontal"
    print(f"Flipping image {flip_type}.")
    flip_code = 0 if flip_type == "vertical" else 1
    flipped_image = cv2.flip(image, flip_code)
    flipped_label = cv2.flip(label, flip_code)
    return flipped_image, flipped_label


def add_gaussian_noise(image, mean=0, var=0.01):
    """
    Add Gaussian noise to the image (labels remain unaffected).

    Parameters:
    - image: NumPy array of the image.
    - mean: Mean of the Gaussian noise.
    - var: Variance of the Gaussian noise.

    Returns:
    - noisy_image: Image with Gaussian noise added.
    """
    print("Adding Gaussian noise to the image.")
    noisy_image = random_noise(image, mode='gaussian', mean=mean, var=var)
    noisy_image = np.array(255 * noisy_image, dtype=np.uint8)  # Convert back to 0-255 range
    return noisy_image


def augment_images(image, label):
    """
    Augment the image and label with various augmentations like rotations and flipping.

    Parameters:
    - image: NumPy array of the image.
    - label: NumPy array of the corresponding label.

    Returns:
    - augmented_images: List of augmented images.
    - augmented_labels: List of corresponding augmented labels.
    """
    print("Applying augmentations to the image and label.")
    augmented_images = []
    augmented_labels = []

    # Apply rotations
    for angle in [90, 180, 270]:
        rotated_image, rotated_label = rotate_image(image, label, angle)
        augmented_images.append(rotated_image)
        augmented_labels.append(rotated_label)

    # Apply flipping
    flipped_image, flipped_label = flip_image(image, label)
    augmented_images.append(flipped_image)
    augmented_labels.append(flipped_label)

    # Optionally add Gaussian noise
    noisy_image = add_gaussian_noise(image)
    augmented_images.append(noisy_image)
    augmented_labels.append(label)  # Label remains unchanged for noise augmentation

    print(f"Total augmentations for this image: {len(augmented_images)}")
    return augmented_images, augmented_labels


def augment_dataset(images, labels):
    """
    Apply augmentations to a dataset of images and labels.

    Parameters:
    - images: List of NumPy arrays representing the images.
    - labels: List of NumPy arrays representing the corresponding labels.

    Returns:
    - augmented_images: List of augmented images.
    - augmented_labels: List of augmented labels.
    """
    print("Starting dataset augmentation.")
    augmented_images = []
    augmented_labels = []

    for idx, (image, label) in enumerate(zip(images, labels)):
        print(f"Processing image {idx + 1}/{len(images)} with shape {image.shape}.")
        if np.all(label == 0): #no only-water tile is augmented
            print(f"Skipping augmentation for image {idx + 1} (only water).")
            augmented_images.append(image)
            augmented_labels.append(label)
            continue  # Skip augmentation for this tile

        # Add original image and label
        augmented_images.append(image)
        augmented_labels.append(label)

        # Apply augmentations
        augmented_image_set, augmented_label_set = augment_images(image, label)
        augmented_images.extend(augmented_image_set)
        augmented_labels.extend(augmented_label_set)

    print(f"Completed dataset augmentation. Total augmented images: {len(augmented_images)}")
    return augmented_images, augmented_labels

# %%
gc.collect()

print("Starting training data augmentation.")
augmented_train_images, augmented_train_labels = augment_dataset(train_images, train_labels)

# Ensure labels have the correct dimensions
converted_train_labels = []
for idx, lbl in enumerate(augmented_train_labels):
    if lbl.ndim == 2:  # If the label is (H, W), add a channel dimension
        lbl = np.expand_dims(lbl, axis=-1)
    elif lbl.shape[-1] != 1:  # Ensure the last dimension is 1
        raise ValueError(f"Label {idx + 1} has unexpected shape: {lbl.shape}")
    converted_train_labels.append(lbl)

train_images = np.array(augmented_train_images)
train_labels = np.array(converted_train_labels)

print(f"Final augmented training dataset shape: {train_images.shape}")
print(f"Final augmented labels dataset shape: {train_labels.shape}")
gc.collect()
# Out:
# Streaming output truncated to the last 5000 lines.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 511/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 512/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 513/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 514/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 515/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 516/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 517/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 518/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 519/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 520/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 521/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 522/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 523/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 524/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 525/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 526/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 527/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 528/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 529/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 530/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 531/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 532/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 533/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 534/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 535/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 536/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 537/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 538/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 539/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 540/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 541/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 542/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 543/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 544/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 545/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 546/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 547/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 548/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 549/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 550/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 551/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 552/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 553/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 554/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 555/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 556/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 557/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 558/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 559/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 560/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 561/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 562/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 563/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 564/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 565/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 566/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 567/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 568/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 569/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 570/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 571/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 572/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 573/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 574/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 575/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 576/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 577/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 578/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 579/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 580/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 581/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 582/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 583/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 584/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 585/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 586/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 587/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 588/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 589/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 590/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 591/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 592/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 593/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 594/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 595/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 596/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 597/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 598/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 599/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 600/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 601/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 602/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 603/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 604/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 605/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 606/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 607/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 608/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 609/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 610/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 611/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 612/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 613/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 614/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 615/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 616/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 617/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 618/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 619/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 620/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 621/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 622/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 623/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 624/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 625/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 626/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 627/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 628/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 629/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 630/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 631/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 632/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 633/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 634/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 635/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 636/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 637/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 638/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 639/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 640/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 641/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 642/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 643/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 644/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 645/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 646/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 647/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 648/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 649/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 650/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 651/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 652/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 653/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 654/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 655/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 656/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 657/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 658/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 659/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 660/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 661/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 662/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 663/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 664/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 665/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 666/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 667/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 668/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 669/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 670/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 671/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 672/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 673/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 674/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 675/1134 with shape (64, 64, 193).
# ...
# Total augmentations for this image: 5
# Processing image 1081/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 1082/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 1083/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 1084/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 1085/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 1086/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 1087/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 1088/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 1089/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 1090/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 1091/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 1092/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 1093/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 1094/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 1095/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 1096/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 1097/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 1098/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 1099/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 1100/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 1101/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 1102/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 1103/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 1104/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 1105/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 1106/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 1107/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 1108/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 1109/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 1110/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 1111/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 1112/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 1113/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 1114/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 1115/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 1116/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 1117/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 1118/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 1119/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 1120/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 1121/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 1122/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 1123/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 1124/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 1125/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 1126/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 1127/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 1128/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 1129/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 1130/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image vertical.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 1131/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 1132/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 1133/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Processing image 1134/1134 with shape (64, 64, 193).
# Applying augmentations to the image and label.
# Rotating image by 90 degrees.
# Rotating image by 180 degrees.
# Rotating image by 270 degrees.
# Flipping image horizontal.
# Adding Gaussian noise to the image.
# Total augmentations for this image: 5
# Completed dataset augmentation. Total augmented images: 6804
# Final augmented training dataset shape: (6804, 64, 64, 193)
# Final augmented labels dataset shape: (6804, 64, 64, 1)
# 0

# %% [markdown]
# ## 7. Flatten Augmented data for PCA

# %%
def flatten_dataset(images, labels):
    """
    Flatten the images and labels into a 2D array for the images and a 1D array for the labels.

    Parameters:
    - images: List of NumPy arrays representing the images (H, W, C).
    - labels: List of NumPy arrays representing the corresponding labels (H, W, 1).

    Returns:
    - flattened_images: 2D array of flattened images (num_pixels, num_features).
    - flattened_labels: 1D array of flattened labels (num_pixels).
    """
    flattened_images = []
    flattened_labels = []

    for idx, (image, label) in enumerate(zip(images, labels)):
        print(f"Flattening image {idx + 1}/{len(images)} with shape {image.shape}.")
        flattened_images.append(image.reshape(-1, image.shape[-1]))
        flattened_labels.append(label.flatten())

    flattened_images = np.vstack(flattened_images)
    flattened_labels = np.hstack(flattened_labels)

    print(f"Flattened images shape: {flattened_images.shape}")
    print(f"Flattened labels shape: {flattened_labels.shape}")
    return flattened_images, flattened_labels


# Flatten training data
print("\nFlattening training data...")
train_data_flattened, train_labels_flattened = flatten_dataset(train_images, train_labels)

# Flatten validation data
print("\nFlattening validation data...")
val_data_flattened, val_labels_flattened = flatten_dataset(val_images, val_labels)

# Flatten test data
print("\nFlattening test data...")
test_data_flattened, test_labels_flattened = flatten_dataset(test_images, test_labels)

# Final results
print("\nFinal Flattened Data Shapes:")
print(f"Train Data: {train_data_flattened.shape}, Train Labels: {train_labels_flattened.shape}")
print(f"Validation Data: {val_data_flattened.shape}, Validation Labels: {val_labels_flattened.shape}")
print(f"Test Data: {test_data_flattened.shape}, Test Labels: {test_labels_flattened.shape}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Flattening image 3359/6804 with shape (64, 64, 193).
# Flattening image 3360/6804 with shape (64, 64, 193).
# Flattening image 3361/6804 with shape (64, 64, 193).
# Flattening image 3362/6804 with shape (64, 64, 193).
# Flattening image 3363/6804 with shape (64, 64, 193).
# Flattening image 3364/6804 with shape (64, 64, 193).
# Flattening image 3365/6804 with shape (64, 64, 193).
# Flattening image 3366/6804 with shape (64, 64, 193).
# Flattening image 3367/6804 with shape (64, 64, 193).
# Flattening image 3368/6804 with shape (64, 64, 193).
# Flattening image 3369/6804 with shape (64, 64, 193).
# Flattening image 3370/6804 with shape (64, 64, 193).
# Flattening image 3371/6804 with shape (64, 64, 193).
# Flattening image 3372/6804 with shape (64, 64, 193).
# Flattening image 3373/6804 with shape (64, 64, 193).
# Flattening image 3374/6804 with shape (64, 64, 193).
# Flattening image 3375/6804 with shape (64, 64, 193).
# Flattening image 3376/6804 with shape (64, 64, 193).
# Flattening image 3377/6804 with shape (64, 64, 193).
# Flattening image 3378/6804 with shape (64, 64, 193).
# Flattening image 3379/6804 with shape (64, 64, 193).
# Flattening image 3380/6804 with shape (64, 64, 193).
# Flattening image 3381/6804 with shape (64, 64, 193).
# Flattening image 3382/6804 with shape (64, 64, 193).
# Flattening image 3383/6804 with shape (64, 64, 193).
# Flattening image 3384/6804 with shape (64, 64, 193).
# Flattening image 3385/6804 with shape (64, 64, 193).
# Flattening image 3386/6804 with shape (64, 64, 193).
# Flattening image 3387/6804 with shape (64, 64, 193).
# Flattening image 3388/6804 with shape (64, 64, 193).
# Flattening image 3389/6804 with shape (64, 64, 193).
# Flattening image 3390/6804 with shape (64, 64, 193).
# Flattening image 3391/6804 with shape (64, 64, 193).
# Flattening image 3392/6804 with shape (64, 64, 193).
# Flattening image 3393/6804 with shape (64, 64, 193).
# Flattening image 3394/6804 with shape (64, 64, 193).
# Flattening image 3395/6804 with shape (64, 64, 193).
# Flattening image 3396/6804 with shape (64, 64, 193).
# Flattening image 3397/6804 with shape (64, 64, 193).
# Flattening image 3398/6804 with shape (64, 64, 193).
# Flattening image 3399/6804 with shape (64, 64, 193).
# Flattening image 3400/6804 with shape (64, 64, 193).
# Flattening image 3401/6804 with shape (64, 64, 193).
# Flattening image 3402/6804 with shape (64, 64, 193).
# Flattening image 3403/6804 with shape (64, 64, 193).
# Flattening image 3404/6804 with shape (64, 64, 193).
# Flattening image 3405/6804 with shape (64, 64, 193).
# Flattening image 3406/6804 with shape (64, 64, 193).
# Flattening image 3407/6804 with shape (64, 64, 193).
# Flattening image 3408/6804 with shape (64, 64, 193).
# Flattening image 3409/6804 with shape (64, 64, 193).
# Flattening image 3410/6804 with shape (64, 64, 193).
# Flattening image 3411/6804 with shape (64, 64, 193).
# Flattening image 3412/6804 with shape (64, 64, 193).
# Flattening image 3413/6804 with shape (64, 64, 193).
# Flattening image 3414/6804 with shape (64, 64, 193).
# Flattening image 3415/6804 with shape (64, 64, 193).
# Flattening image 3416/6804 with shape (64, 64, 193).
# Flattening image 3417/6804 with shape (64, 64, 193).
# Flattening image 3418/6804 with shape (64, 64, 193).
# Flattening image 3419/6804 with shape (64, 64, 193).
# Flattening image 3420/6804 with shape (64, 64, 193).
# Flattening image 3421/6804 with shape (64, 64, 193).
# Flattening image 3422/6804 with shape (64, 64, 193).
# Flattening image 3423/6804 with shape (64, 64, 193).
# Flattening image 3424/6804 with shape (64, 64, 193).
# Flattening image 3425/6804 with shape (64, 64, 193).
# Flattening image 3426/6804 with shape (64, 64, 193).
# Flattening image 3427/6804 with shape (64, 64, 193).
# Flattening image 3428/6804 with shape (64, 64, 193).
# Flattening image 3429/6804 with shape (64, 64, 193).
# Flattening image 3430/6804 with shape (64, 64, 193).
# Flattening image 3431/6804 with shape (64, 64, 193).
# Flattening image 3432/6804 with shape (64, 64, 193).
# Flattening image 3433/6804 with shape (64, 64, 193).
# Flattening image 3434/6804 with shape (64, 64, 193).
# Flattening image 3435/6804 with shape (64, 64, 193).
# Flattening image 3436/6804 with shape (64, 64, 193).
# Flattening image 3437/6804 with shape (64, 64, 193).
# Flattening image 3438/6804 with shape (64, 64, 193).
# Flattening image 3439/6804 with shape (64, 64, 193).
# Flattening image 3440/6804 with shape (64, 64, 193).
# Flattening image 3441/6804 with shape (64, 64, 193).
# Flattening image 3442/6804 with shape (64, 64, 193).
# Flattening image 3443/6804 with shape (64, 64, 193).
# Flattening image 3444/6804 with shape (64, 64, 193).
# Flattening image 3445/6804 with shape (64, 64, 193).
# Flattening image 3446/6804 with shape (64, 64, 193).
# Flattening image 3447/6804 with shape (64, 64, 193).
# Flattening image 3448/6804 with shape (64, 64, 193).
# Flattening image 3449/6804 with shape (64, 64, 193).
# Flattening image 3450/6804 with shape (64, 64, 193).
# Flattening image 3451/6804 with shape (64, 64, 193).
# Flattening image 3452/6804 with shape (64, 64, 193).
# Flattening image 3453/6804 with shape (64, 64, 193).
# Flattening image 3454/6804 with shape (64, 64, 193).
# Flattening image 3455/6804 with shape (64, 64, 193).
# Flattening image 3456/6804 with shape (64, 64, 193).
# Flattening image 3457/6804 with shape (64, 64, 193).
# Flattening image 3458/6804 with shape (64, 64, 193).
# Flattening image 3459/6804 with shape (64, 64, 193).
# Flattening image 3460/6804 with shape (64, 64, 193).
# Flattening image 3461/6804 with shape (64, 64, 193).
# Flattening image 3462/6804 with shape (64, 64, 193).
# Flattening image 3463/6804 with shape (64, 64, 193).
# Flattening image 3464/6804 with shape (64, 64, 193).
# Flattening image 3465/6804 with shape (64, 64, 193).
# Flattening image 3466/6804 with shape (64, 64, 193).
# Flattening image 3467/6804 with shape (64, 64, 193).
# Flattening image 3468/6804 with shape (64, 64, 193).
# Flattening image 3469/6804 with shape (64, 64, 193).
# Flattening image 3470/6804 with shape (64, 64, 193).
# Flattening image 3471/6804 with shape (64, 64, 193).
# Flattening image 3472/6804 with shape (64, 64, 193).
# Flattening image 3473/6804 with shape (64, 64, 193).
# Flattening image 3474/6804 with shape (64, 64, 193).
# Flattening image 3475/6804 with shape (64, 64, 193).
# Flattening image 3476/6804 with shape (64, 64, 193).
# Flattening image 3477/6804 with shape (64, 64, 193).
# Flattening image 3478/6804 with shape (64, 64, 193).
# Flattening image 3479/6804 with shape (64, 64, 193).
# Flattening image 3480/6804 with shape (64, 64, 193).
# Flattening image 3481/6804 with shape (64, 64, 193).
# Flattening image 3482/6804 with shape (64, 64, 193).
# Flattening image 3483/6804 with shape (64, 64, 193).
# Flattening image 3484/6804 with shape (64, 64, 193).
# Flattening image 3485/6804 with shape (64, 64, 193).
# Flattening image 3486/6804 with shape (64, 64, 193).
# Flattening image 3487/6804 with shape (64, 64, 193).
# Flattening image 3488/6804 with shape (64, 64, 193).
# Flattening image 3489/6804 with shape (64, 64, 193).
# Flattening image 3490/6804 with shape (64, 64, 193).
# Flattening image 3491/6804 with shape (64, 64, 193).
# Flattening image 3492/6804 with shape (64, 64, 193).
# Flattening image 3493/6804 with shape (64, 64, 193).
# Flattening image 3494/6804 with shape (64, 64, 193).
# Flattening image 3495/6804 with shape (64, 64, 193).
# Flattening image 3496/6804 with shape (64, 64, 193).
# Flattening image 3497/6804 with shape (64, 64, 193).
# Flattening image 3498/6804 with shape (64, 64, 193).
# Flattening image 3499/6804 with shape (64, 64, 193).
# Flattening image 3500/6804 with shape (64, 64, 193).
# Flattening image 3501/6804 with shape (64, 64, 193).
# Flattening image 3502/6804 with shape (64, 64, 193).
# Flattening image 3503/6804 with shape (64, 64, 193).
# Flattening image 3504/6804 with shape (64, 64, 193).
# Flattening image 3505/6804 with shape (64, 64, 193).
# Flattening image 3506/6804 with shape (64, 64, 193).
# Flattening image 3507/6804 with shape (64, 64, 193).
# Flattening image 3508/6804 with shape (64, 64, 193).
# Flattening image 3509/6804 with shape (64, 64, 193).
# Flattening image 3510/6804 with shape (64, 64, 193).
# Flattening image 3511/6804 with shape (64, 64, 193).
# Flattening image 3512/6804 with shape (64, 64, 193).
# Flattening image 3513/6804 with shape (64, 64, 193).
# Flattening image 3514/6804 with shape (64, 64, 193).
# Flattening image 3515/6804 with shape (64, 64, 193).
# Flattening image 3516/6804 with shape (64, 64, 193).
# Flattening image 3517/6804 with shape (64, 64, 193).
# Flattening image 3518/6804 with shape (64, 64, 193).
# Flattening image 3519/6804 with shape (64, 64, 193).
# Flattening image 3520/6804 with shape (64, 64, 193).
# Flattening image 3521/6804 with shape (64, 64, 193).
# Flattening image 3522/6804 with shape (64, 64, 193).
# Flattening image 3523/6804 with shape (64, 64, 193).
# Flattening image 3524/6804 with shape (64, 64, 193).
# Flattening image 3525/6804 with shape (64, 64, 193).
# Flattening image 3526/6804 with shape (64, 64, 193).
# Flattening image 3527/6804 with shape (64, 64, 193).
# Flattening image 3528/6804 with shape (64, 64, 193).
# Flattening image 3529/6804 with shape (64, 64, 193).
# Flattening image 3530/6804 with shape (64, 64, 193).
# Flattening image 3531/6804 with shape (64, 64, 193).
# Flattening image 3532/6804 with shape (64, 64, 193).
# Flattening image 3533/6804 with shape (64, 64, 193).
# Flattening image 3534/6804 with shape (64, 64, 193).
# Flattening image 3535/6804 with shape (64, 64, 193).
# Flattening image 3536/6804 with shape (64, 64, 193).
# Flattening image 3537/6804 with shape (64, 64, 193).
# Flattening image 3538/6804 with shape (64, 64, 193).
# Flattening image 3539/6804 with shape (64, 64, 193).
# Flattening image 3540/6804 with shape (64, 64, 193).
# Flattening image 3541/6804 with shape (64, 64, 193).
# Flattening image 3542/6804 with shape (64, 64, 193).
# Flattening image 3543/6804 with shape (64, 64, 193).
# Flattening image 3544/6804 with shape (64, 64, 193).
# Flattening image 3545/6804 with shape (64, 64, 193).
# Flattening image 3546/6804 with shape (64, 64, 193).
# Flattening image 3547/6804 with shape (64, 64, 193).
# Flattening image 3548/6804 with shape (64, 64, 193).
# Flattening image 3549/6804 with shape (64, 64, 193).
# Flattening image 3550/6804 with shape (64, 64, 193).
# Flattening image 3551/6804 with shape (64, 64, 193).
# Flattening image 3552/6804 with shape (64, 64, 193).
# Flattening image 3553/6804 with shape (64, 64, 193).
# Flattening image 3554/6804 with shape (64, 64, 193).
# Flattening image 3555/6804 with shape (64, 64, 193).
# Flattening image 3556/6804 with shape (64, 64, 193).
# Flattening image 3557/6804 with shape (64, 64, 193).
# Flattening image 3558/6804 with shape (64, 64, 193).
# Flattening image 3559/6804 with shape (64, 64, 193).
# Flattening image 3560/6804 with shape (64, 64, 193).
# Flattening image 3561/6804 with shape (64, 64, 193).
# Flattening image 3562/6804 with shape (64, 64, 193).
# Flattening image 3563/6804 with shape (64, 64, 193).
# Flattening image 3564/6804 with shape (64, 64, 193).
# Flattening image 3565/6804 with shape (64, 64, 193).
# Flattening image 3566/6804 with shape (64, 64, 193).
# Flattening image 3567/6804 with shape (64, 64, 193).
# Flattening image 3568/6804 with shape (64, 64, 193).
# Flattening image 3569/6804 with shape (64, 64, 193).
# Flattening image 3570/6804 with shape (64, 64, 193).
# Flattening image 3571/6804 with shape (64, 64, 193).
# Flattening image 3572/6804 with shape (64, 64, 193).
# Flattening image 3573/6804 with shape (64, 64, 193).
# Flattening image 3574/6804 with shape (64, 64, 193).
# Flattening image 3575/6804 with shape (64, 64, 193).
# Flattening image 3576/6804 with shape (64, 64, 193).
# Flattening image 3577/6804 with shape (64, 64, 193).
# Flattening image 3578/6804 with shape (64, 64, 193).
# Flattening image 3579/6804 with shape (64, 64, 193).
# Flattening image 3580/6804 with shape (64, 64, 193).
# Flattening image 3581/6804 with shape (64, 64, 193).
# Flattening image 3582/6804 with shape (64, 64, 193).
# Flattening image 3583/6804 with shape (64, 64, 193).
# Flattening image 3584/6804 with shape (64, 64, 193).
# Flattening image 3585/6804 with shape (64, 64, 193).
# Flattening image 3586/6804 with shape (64, 64, 193).
# Flattening image 3587/6804 with shape (64, 64, 193).
# Flattening image 3588/6804 with shape (64, 64, 193).
# Flattening image 3589/6804 with shape (64, 64, 193).
# Flattening image 3590/6804 with shape (64, 64, 193).
# Flattening image 3591/6804 with shape (64, 64, 193).
# Flattening image 3592/6804 with shape (64, 64, 193).
# Flattening image 3593/6804 with shape (64, 64, 193).
# Flattening image 3594/6804 with shape (64, 64, 193).
# Flattening image 3595/6804 with shape (64, 64, 193).
# Flattening image 3596/6804 with shape (64, 64, 193).
# Flattening image 3597/6804 with shape (64, 64, 193).
# Flattening image 3598/6804 with shape (64, 64, 193).
# Flattening image 3599/6804 with shape (64, 64, 193).
# Flattening image 3600/6804 with shape (64, 64, 193).
# Flattening image 3601/6804 with shape (64, 64, 193).
# Flattening image 3602/6804 with shape (64, 64, 193).
# Flattening image 3603/6804 with shape (64, 64, 193).
# Flattening image 3604/6804 with shape (64, 64, 193).
# Flattening image 3605/6804 with shape (64, 64, 193).
# Flattening image 3606/6804 with shape (64, 64, 193).
# Flattening image 3607/6804 with shape (64, 64, 193).
# Flattening image 3608/6804 with shape (64, 64, 193).
# Flattening image 3609/6804 with shape (64, 64, 193).
# Flattening image 3610/6804 with shape (64, 64, 193).
# Flattening image 3611/6804 with shape (64, 64, 193).
# Flattening image 3612/6804 with shape (64, 64, 193).
# Flattening image 3613/6804 with shape (64, 64, 193).
# Flattening image 3614/6804 with shape (64, 64, 193).
# Flattening image 3615/6804 with shape (64, 64, 193).
# Flattening image 3616/6804 with shape (64, 64, 193).
# Flattening image 3617/6804 with shape (64, 64, 193).
# Flattening image 3618/6804 with shape (64, 64, 193).
# Flattening image 3619/6804 with shape (64, 64, 193).
# Flattening image 3620/6804 with shape (64, 64, 193).
# Flattening image 3621/6804 with shape (64, 64, 193).
# Flattening image 3622/6804 with shape (64, 64, 193).
# Flattening image 3623/6804 with shape (64, 64, 193).
# Flattening image 3624/6804 with shape (64, 64, 193).
# Flattening image 3625/6804 with shape (64, 64, 193).
# Flattening image 3626/6804 with shape (64, 64, 193).
# Flattening image 3627/6804 with shape (64, 64, 193).
# Flattening image 3628/6804 with shape (64, 64, 193).
# Flattening image 3629/6804 with shape (64, 64, 193).
# Flattening image 3630/6804 with shape (64, 64, 193).
# Flattening image 3631/6804 with shape (64, 64, 193).
# Flattening image 3632/6804 with shape (64, 64, 193).
# Flattening image 3633/6804 with shape (64, 64, 193).
# Flattening image 3634/6804 with shape (64, 64, 193).
# Flattening image 3635/6804 with shape (64, 64, 193).
# Flattening image 3636/6804 with shape (64, 64, 193).
# Flattening image 3637/6804 with shape (64, 64, 193).
# Flattening image 3638/6804 with shape (64, 64, 193).
# Flattening image 3639/6804 with shape (64, 64, 193).
# Flattening image 3640/6804 with shape (64, 64, 193).
# Flattening image 3641/6804 with shape (64, 64, 193).
# Flattening image 3642/6804 with shape (64, 64, 193).
# Flattening image 3643/6804 with shape (64, 64, 193).
# Flattening image 3644/6804 with shape (64, 64, 193).
# Flattening image 3645/6804 with shape (64, 64, 193).
# Flattening image 3646/6804 with shape (64, 64, 193).
# Flattening image 3647/6804 with shape (64, 64, 193).
# Flattening image 3648/6804 with shape (64, 64, 193).
# Flattening image 3649/6804 with shape (64, 64, 193).
# Flattening image 3650/6804 with shape (64, 64, 193).
# Flattening image 3651/6804 with shape (64, 64, 193).
# Flattening image 3652/6804 with shape (64, 64, 193).
# Flattening image 3653/6804 with shape (64, 64, 193).
# Flattening image 3654/6804 with shape (64, 64, 193).
# Flattening image 3655/6804 with shape (64, 64, 193).
# Flattening image 3656/6804 with shape (64, 64, 193).
# Flattening image 3657/6804 with shape (64, 64, 193).
# Flattening image 3658/6804 with shape (64, 64, 193).
# Flattening image 3659/6804 with shape (64, 64, 193).
# Flattening image 3660/6804 with shape (64, 64, 193).
# Flattening image 3661/6804 with shape (64, 64, 193).
# Flattening image 3662/6804 with shape (64, 64, 193).
# Flattening image 3663/6804 with shape (64, 64, 193).
# Flattening image 3664/6804 with shape (64, 64, 193).
# Flattening image 3665/6804 with shape (64, 64, 193).
# Flattening image 3666/6804 with shape (64, 64, 193).
# Flattening image 3667/6804 with shape (64, 64, 193).
# Flattening image 3668/6804 with shape (64, 64, 193).
# Flattening image 3669/6804 with shape (64, 64, 193).
# Flattening image 3670/6804 with shape (64, 64, 193).
# Flattening image 3671/6804 with shape (64, 64, 193).
# Flattening image 3672/6804 with shape (64, 64, 193).
# Flattening image 3673/6804 with shape (64, 64, 193).
# Flattening image 3674/6804 with shape (64, 64, 193).
# Flattening image 3675/6804 with shape (64, 64, 193).
# Flattening image 3676/6804 with shape (64, 64, 193).
# Flattening image 3677/6804 with shape (64, 64, 193).
# Flattening image 3678/6804 with shape (64, 64, 193).
# Flattening image 3679/6804 with shape (64, 64, 193).
# Flattening image 3680/6804 with shape (64, 64, 193).
# Flattening image 3681/6804 with shape (64, 64, 193).
# Flattening image 3682/6804 with shape (64, 64, 193).
# Flattening image 3683/6804 with shape (64, 64, 193).
# Flattening image 3684/6804 with shape (64, 64, 193).
# Flattening image 3685/6804 with shape (64, 64, 193).
# Flattening image 3686/6804 with shape (64, 64, 193).
# Flattening image 3687/6804 with shape (64, 64, 193).
# Flattening image 3688/6804 with shape (64, 64, 193).
# Flattening image 3689/6804 with shape (64, 64, 193).
# Flattening image 3690/6804 with shape (64, 64, 193).
# Flattening image 3691/6804 with shape (64, 64, 193).
# Flattening image 3692/6804 with shape (64, 64, 193).
# Flattening image 3693/6804 with shape (64, 64, 193).
# Flattening image 3694/6804 with shape (64, 64, 193).
# Flattening image 3695/6804 with shape (64, 64, 193).
# Flattening image 3696/6804 with shape (64, 64, 193).
# Flattening image 3697/6804 with shape (64, 64, 193).
# Flattening image 3698/6804 with shape (64, 64, 193).
# Flattening image 3699/6804 with shape (64, 64, 193).
# Flattening image 3700/6804 with shape (64, 64, 193).
# Flattening image 3701/6804 with shape (64, 64, 193).
# Flattening image 3702/6804 with shape (64, 64, 193).
# Flattening image 3703/6804 with shape (64, 64, 193).
# Flattening image 3704/6804 with shape (64, 64, 193).
# Flattening image 3705/6804 with shape (64, 64, 193).
# Flattening image 3706/6804 with shape (64, 64, 193).
# Flattening image 3707/6804 with shape (64, 64, 193).
# Flattening image 3708/6804 with shape (64, 64, 193).
# Flattening image 3709/6804 with shape (64, 64, 193).
# Flattening image 3710/6804 with shape (64, 64, 193).
# Flattening image 3711/6804 with shape (64, 64, 193).
# Flattening image 3712/6804 with shape (64, 64, 193).
# Flattening image 3713/6804 with shape (64, 64, 193).
# Flattening image 3714/6804 with shape (64, 64, 193).
# Flattening image 3715/6804 with shape (64, 64, 193).
# Flattening image 3716/6804 with shape (64, 64, 193).
# Flattening image 3717/6804 with shape (64, 64, 193).
# Flattening image 3718/6804 with shape (64, 64, 193).
# Flattening image 3719/6804 with shape (64, 64, 193).
# Flattening image 3720/6804 with shape (64, 64, 193).
# Flattening image 3721/6804 with shape (64, 64, 193).
# Flattening image 3722/6804 with shape (64, 64, 193).
# Flattening image 3723/6804 with shape (64, 64, 193).
# Flattening image 3724/6804 with shape (64, 64, 193).
# Flattening image 3725/6804 with shape (64, 64, 193).
# Flattening image 3726/6804 with shape (64, 64, 193).
# Flattening image 3727/6804 with shape (64, 64, 193).
# Flattening image 3728/6804 with shape (64, 64, 193).
# Flattening image 3729/6804 with shape (64, 64, 193).
# Flattening image 3730/6804 with shape (64, 64, 193).
# Flattening image 3731/6804 with shape (64, 64, 193).
# Flattening image 3732/6804 with shape (64, 64, 193).
# Flattening image 3733/6804 with shape (64, 64, 193).
# Flattening image 3734/6804 with shape (64, 64, 193).
# Flattening image 3735/6804 with shape (64, 64, 193).
# Flattening image 3736/6804 with shape (64, 64, 193).
# Flattening image 3737/6804 with shape (64, 64, 193).
# Flattening image 3738/6804 with shape (64, 64, 193).
# Flattening image 3739/6804 with shape (64, 64, 193).
# Flattening image 3740/6804 with shape (64, 64, 193).
# Flattening image 3741/6804 with shape (64, 64, 193).
# Flattening image 3742/6804 with shape (64, 64, 193).
# Flattening image 3743/6804 with shape (64, 64, 193).
# Flattening image 3744/6804 with shape (64, 64, 193).
# Flattening image 3745/6804 with shape (64, 64, 193).
# Flattening image 3746/6804 with shape (64, 64, 193).
# Flattening image 3747/6804 with shape (64, 64, 193).
# Flattening image 3748/6804 with shape (64, 64, 193).
# Flattening image 3749/6804 with shape (64, 64, 193).
# Flattening image 3750/6804 with shape (64, 64, 193).
# Flattening image 3751/6804 with shape (64, 64, 193).
# Flattening image 3752/6804 with shape (64, 64, 193).
# Flattening image 3753/6804 with shape (64, 64, 193).
# Flattening image 3754/6804 with shape (64, 64, 193).
# Flattening image 3755/6804 with shape (64, 64, 193).
# Flattening image 3756/6804 with shape (64, 64, 193).
# Flattening image 3757/6804 with shape (64, 64, 193).
# Flattening image 3758/6804 with shape (64, 64, 193).
# Flattening image 3759/6804 with shape (64, 64, 193).
# Flattening image 3760/6804 with shape (64, 64, 193).
# Flattening image 3761/6804 with shape (64, 64, 193).
# Flattening image 3762/6804 with shape (64, 64, 193).
# Flattening image 3763/6804 with shape (64, 64, 193).
# Flattening image 3764/6804 with shape (64, 64, 193).
# Flattening image 3765/6804 with shape (64, 64, 193).
# Flattening image 3766/6804 with shape (64, 64, 193).
# Flattening image 3767/6804 with shape (64, 64, 193).
# Flattening image 3768/6804 with shape (64, 64, 193).
# Flattening image 3769/6804 with shape (64, 64, 193).
# Flattening image 3770/6804 with shape (64, 64, 193).
# Flattening image 3771/6804 with shape (64, 64, 193).
# Flattening image 3772/6804 with shape (64, 64, 193).
# Flattening image 3773/6804 with shape (64, 64, 193).
# Flattening image 3774/6804 with shape (64, 64, 193).
# Flattening image 3775/6804 with shape (64, 64, 193).
# Flattening image 3776/6804 with shape (64, 64, 193).
# Flattening image 3777/6804 with shape (64, 64, 193).
# Flattening image 3778/6804 with shape (64, 64, 193).
# Flattening image 3779/6804 with shape (64, 64, 193).
# Flattening image 3780/6804 with shape (64, 64, 193).
# Flattening image 3781/6804 with shape (64, 64, 193).
# Flattening image 3782/6804 with shape (64, 64, 193).
# Flattening image 3783/6804 with shape (64, 64, 193).
# Flattening image 3784/6804 with shape (64, 64, 193).
# Flattening image 3785/6804 with shape (64, 64, 193).
# Flattening image 3786/6804 with shape (64, 64, 193).
# Flattening image 3787/6804 with shape (64, 64, 193).
# Flattening image 3788/6804 with shape (64, 64, 193).
# Flattening image 3789/6804 with shape (64, 64, 193).
# Flattening image 3790/6804 with shape (64, 64, 193).
# Flattening image 3791/6804 with shape (64, 64, 193).
# Flattening image 3792/6804 with shape (64, 64, 193).
# Flattening image 3793/6804 with shape (64, 64, 193).
# Flattening image 3794/6804 with shape (64, 64, 193).
# Flattening image 3795/6804 with shape (64, 64, 193).
# Flattening image 3796/6804 with shape (64, 64, 193).
# Flattening image 3797/6804 with shape (64, 64, 193).
# Flattening image 3798/6804 with shape (64, 64, 193).
# Flattening image 3799/6804 with shape (64, 64, 193).
# Flattening image 3800/6804 with shape (64, 64, 193).
# Flattening image 3801/6804 with shape (64, 64, 193).
# Flattening image 3802/6804 with shape (64, 64, 193).
# Flattening image 3803/6804 with shape (64, 64, 193).
# Flattening image 3804/6804 with shape (64, 64, 193).
# Flattening image 3805/6804 with shape (64, 64, 193).
# Flattening image 3806/6804 with shape (64, 64, 193).
# Flattening image 3807/6804 with shape (64, 64, 193).
# Flattening image 3808/6804 with shape (64, 64, 193).
# Flattening image 3809/6804 with shape (64, 64, 193).
# Flattening image 3810/6804 with shape (64, 64, 193).
# Flattening image 3811/6804 with shape (64, 64, 193).
# Flattening image 3812/6804 with shape (64, 64, 193).
# Flattening image 3813/6804 with shape (64, 64, 193).
# Flattening image 3814/6804 with shape (64, 64, 193).
# Flattening image 3815/6804 with shape (64, 64, 193).
# Flattening image 3816/6804 with shape (64, 64, 193).
# Flattening image 3817/6804 with shape (64, 64, 193).
# Flattening image 3818/6804 with shape (64, 64, 193).
# Flattening image 3819/6804 with shape (64, 64, 193).
# Flattening image 3820/6804 with shape (64, 64, 193).
# Flattening image 3821/6804 with shape (64, 64, 193).
# Flattening image 3822/6804 with shape (64, 64, 193).
# Flattening image 3823/6804 with shape (64, 64, 193).
# Flattening image 3824/6804 with shape (64, 64, 193).
# Flattening image 3825/6804 with shape (64, 64, 193).
# Flattening image 3826/6804 with shape (64, 64, 193).
# Flattening image 3827/6804 with shape (64, 64, 193).
# Flattening image 3828/6804 with shape (64, 64, 193).
# Flattening image 3829/6804 with shape (64, 64, 193).
# Flattening image 3830/6804 with shape (64, 64, 193).
# Flattening image 3831/6804 with shape (64, 64, 193).
# Flattening image 3832/6804 with shape (64, 64, 193).
# Flattening image 3833/6804 with shape (64, 64, 193).
# Flattening image 3834/6804 with shape (64, 64, 193).
# Flattening image 3835/6804 with shape (64, 64, 193).
# Flattening image 3836/6804 with shape (64, 64, 193).
# Flattening image 3837/6804 with shape (64, 64, 193).
# Flattening image 3838/6804 with shape (64, 64, 193).
# Flattening image 3839/6804 with shape (64, 64, 193).
# Flattening image 3840/6804 with shape (64, 64, 193).
# Flattening image 3841/6804 with shape (64, 64, 193).
# Flattening image 3842/6804 with shape (64, 64, 193).
# Flattening image 3843/6804 with shape (64, 64, 193).
# Flattening image 3844/6804 with shape (64, 64, 193).
# Flattening image 3845/6804 with shape (64, 64, 193).
# Flattening image 3846/6804 with shape (64, 64, 193).
# Flattening image 3847/6804 with shape (64, 64, 193).
# Flattening image 3848/6804 with shape (64, 64, 193).
# Flattening image 3849/6804 with shape (64, 64, 193).
# Flattening image 3850/6804 with shape (64, 64, 193).
# Flattening image 3851/6804 with shape (64, 64, 193).
# Flattening image 3852/6804 with shape (64, 64, 193).
# Flattening image 3853/6804 with shape (64, 64, 193).
# Flattening image 3854/6804 with shape (64, 64, 193).
# Flattening image 3855/6804 with shape (64, 64, 193).
# Flattening image 3856/6804 with shape (64, 64, 193).
# Flattening image 3857/6804 with shape (64, 64, 193).
# Flattening image 3858/6804 with shape (64, 64, 193).
# Flattening image 3859/6804 with shape (64, 64, 193).
# Flattening image 3860/6804 with shape (64, 64, 193).
# Flattening image 3861/6804 with shape (64, 64, 193).
# Flattening image 3862/6804 with shape (64, 64, 193).
# Flattening image 3863/6804 with shape (64, 64, 193).
# Flattening image 3864/6804 with shape (64, 64, 193).
# Flattening image 3865/6804 with shape (64, 64, 193).
# Flattening image 3866/6804 with shape (64, 64, 193).
# Flattening image 3867/6804 with shape (64, 64, 193).
# Flattening image 3868/6804 with shape (64, 64, 193).
# Flattening image 3869/6804 with shape (64, 64, 193).
# Flattening image 3870/6804 with shape (64, 64, 193).
# Flattening image 3871/6804 with shape (64, 64, 193).
# Flattening image 3872/6804 with shape (64, 64, 193).
# Flattening image 3873/6804 with shape (64, 64, 193).
# Flattening image 3874/6804 with shape (64, 64, 193).
# Flattening image 3875/6804 with shape (64, 64, 193).
# Flattening image 3876/6804 with shape (64, 64, 193).
# Flattening image 3877/6804 with shape (64, 64, 193).
# Flattening image 3878/6804 with shape (64, 64, 193).
# Flattening image 3879/6804 with shape (64, 64, 193).
# Flattening image 3880/6804 with shape (64, 64, 193).
# Flattening image 3881/6804 with shape (64, 64, 193).
# Flattening image 3882/6804 with shape (64, 64, 193).
# Flattening image 3883/6804 with shape (64, 64, 193).
# Flattening image 3884/6804 with shape (64, 64, 193).
# Flattening image 3885/6804 with shape (64, 64, 193).
# Flattening image 3886/6804 with shape (64, 64, 193).
# Flattening image 3887/6804 with shape (64, 64, 193).
# Flattening image 3888/6804 with shape (64, 64, 193).
# Flattening image 3889/6804 with shape (64, 64, 193).
# Flattening image 3890/6804 with shape (64, 64, 193).
# Flattening image 3891/6804 with shape (64, 64, 193).
# Flattening image 3892/6804 with shape (64, 64, 193).
# Flattening image 3893/6804 with shape (64, 64, 193).
# Flattening image 3894/6804 with shape (64, 64, 193).
# Flattening image 3895/6804 with shape (64, 64, 193).
# Flattening image 3896/6804 with shape (64, 64, 193).
# Flattening image 3897/6804 with shape (64, 64, 193).
# Flattening image 3898/6804 with shape (64, 64, 193).
# Flattening image 3899/6804 with shape (64, 64, 193).
# Flattening image 3900/6804 with shape (64, 64, 193).
# Flattening image 3901/6804 with shape (64, 64, 193).
# Flattening image 3902/6804 with shape (64, 64, 193).
# Flattening image 3903/6804 with shape (64, 64, 193).
# Flattening image 3904/6804 with shape (64, 64, 193).
# Flattening image 3905/6804 with shape (64, 64, 193).
# Flattening image 3906/6804 with shape (64, 64, 193).
# Flattening image 3907/6804 with shape (64, 64, 193).
# Flattening image 3908/6804 with shape (64, 64, 193).
# Flattening image 3909/6804 with shape (64, 64, 193).
# Flattening image 3910/6804 with shape (64, 64, 193).
# Flattening image 3911/6804 with shape (64, 64, 193).
# Flattening image 3912/6804 with shape (64, 64, 193).
# Flattening image 3913/6804 with shape (64, 64, 193).
# Flattening image 3914/6804 with shape (64, 64, 193).
# Flattening image 3915/6804 with shape (64, 64, 193).
# Flattening image 3916/6804 with shape (64, 64, 193).
# Flattening image 3917/6804 with shape (64, 64, 193).
# Flattening image 3918/6804 with shape (64, 64, 193).
# Flattening image 3919/6804 with shape (64, 64, 193).
# Flattening image 3920/6804 with shape (64, 64, 193).
# Flattening image 3921/6804 with shape (64, 64, 193).
# Flattening image 3922/6804 with shape (64, 64, 193).
# Flattening image 3923/6804 with shape (64, 64, 193).
# Flattening image 3924/6804 with shape (64, 64, 193).
# Flattening image 3925/6804 with shape (64, 64, 193).
# Flattening image 3926/6804 with shape (64, 64, 193).
# Flattening image 3927/6804 with shape (64, 64, 193).
# Flattening image 3928/6804 with shape (64, 64, 193).
# Flattening image 3929/6804 with shape (64, 64, 193).
# Flattening image 3930/6804 with shape (64, 64, 193).
# Flattening image 3931/6804 with shape (64, 64, 193).
# Flattening image 3932/6804 with shape (64, 64, 193).
# Flattening image 3933/6804 with shape (64, 64, 193).
# Flattening image 3934/6804 with shape (64, 64, 193).
# Flattening image 3935/6804 with shape (64, 64, 193).
# Flattening image 3936/6804 with shape (64, 64, 193).
# Flattening image 3937/6804 with shape (64, 64, 193).
# Flattening image 3938/6804 with shape (64, 64, 193).
# Flattening image 3939/6804 with shape (64, 64, 193).
# Flattening image 3940/6804 with shape (64, 64, 193).
# Flattening image 3941/6804 with shape (64, 64, 193).
# Flattening image 3942/6804 with shape (64, 64, 193).
# Flattening image 3943/6804 with shape (64, 64, 193).
# Flattening image 3944/6804 with shape (64, 64, 193).
# Flattening image 3945/6804 with shape (64, 64, 193).
# Flattening image 3946/6804 with shape (64, 64, 193).
# Flattening image 3947/6804 with shape (64, 64, 193).
# Flattening image 3948/6804 with shape (64, 64, 193).
# Flattening image 3949/6804 with shape (64, 64, 193).
# Flattening image 3950/6804 with shape (64, 64, 193).
# Flattening image 3951/6804 with shape (64, 64, 193).
# Flattening image 3952/6804 with shape (64, 64, 193).
# Flattening image 3953/6804 with shape (64, 64, 193).
# Flattening image 3954/6804 with shape (64, 64, 193).
# Flattening image 3955/6804 with shape (64, 64, 193).
# Flattening image 3956/6804 with shape (64, 64, 193).
# Flattening image 3957/6804 with shape (64, 64, 193).
# Flattening image 3958/6804 with shape (64, 64, 193).
# Flattening image 3959/6804 with shape (64, 64, 193).
# Flattening image 3960/6804 with shape (64, 64, 193).
# Flattening image 3961/6804 with shape (64, 64, 193).
# Flattening image 3962/6804 with shape (64, 64, 193).
# Flattening image 3963/6804 with shape (64, 64, 193).
# Flattening image 3964/6804 with shape (64, 64, 193).
# Flattening image 3965/6804 with shape (64, 64, 193).
# Flattening image 3966/6804 with shape (64, 64, 193).
# Flattening image 3967/6804 with shape (64, 64, 193).
# Flattening image 3968/6804 with shape (64, 64, 193).
# Flattening image 3969/6804 with shape (64, 64, 193).
# Flattening image 3970/6804 with shape (64, 64, 193).
# Flattening image 3971/6804 with shape (64, 64, 193).
# Flattening image 3972/6804 with shape (64, 64, 193).
# Flattening image 3973/6804 with shape (64, 64, 193).
# Flattening image 3974/6804 with shape (64, 64, 193).
# Flattening image 3975/6804 with shape (64, 64, 193).
# Flattening image 3976/6804 with shape (64, 64, 193).
# Flattening image 3977/6804 with shape (64, 64, 193).
# Flattening image 3978/6804 with shape (64, 64, 193).
# Flattening image 3979/6804 with shape (64, 64, 193).
# Flattening image 3980/6804 with shape (64, 64, 193).
# Flattening image 3981/6804 with shape (64, 64, 193).
# Flattening image 3982/6804 with shape (64, 64, 193).
# Flattening image 3983/6804 with shape (64, 64, 193).
# Flattening image 3984/6804 with shape (64, 64, 193).
# Flattening image 3985/6804 with shape (64, 64, 193).
# Flattening image 3986/6804 with shape (64, 64, 193).
# Flattening image 3987/6804 with shape (64, 64, 193).
# Flattening image 3988/6804 with shape (64, 64, 193).
# Flattening image 3989/6804 with shape (64, 64, 193).
# Flattening image 3990/6804 with shape (64, 64, 193).
# Flattening image 3991/6804 with shape (64, 64, 193).
# Flattening image 3992/6804 with shape (64, 64, 193).
# Flattening image 3993/6804 with shape (64, 64, 193).
# Flattening image 3994/6804 with shape (64, 64, 193).
# Flattening image 3995/6804 with shape (64, 64, 193).
# Flattening image 3996/6804 with shape (64, 64, 193).
# Flattening image 3997/6804 with shape (64, 64, 193).
# Flattening image 3998/6804 with shape (64, 64, 193).
# Flattening image 3999/6804 with shape (64, 64, 193).
# Flattening image 4000/6804 with shape (64, 64, 193).
# Flattening image 4001/6804 with shape (64, 64, 193).
# Flattening image 4002/6804 with shape (64, 64, 193).
# Flattening image 4003/6804 with shape (64, 64, 193).
# Flattening image 4004/6804 with shape (64, 64, 193).
# Flattening image 4005/6804 with shape (64, 64, 193).
# Flattening image 4006/6804 with shape (64, 64, 193).
# Flattening image 4007/6804 with shape (64, 64, 193).
# Flattening image 4008/6804 with shape (64, 64, 193).
# Flattening image 4009/6804 with shape (64, 64, 193).
# Flattening image 4010/6804 with shape (64, 64, 193).
# Flattening image 4011/6804 with shape (64, 64, 193).
# Flattening image 4012/6804 with shape (64, 64, 193).
# Flattening image 4013/6804 with shape (64, 64, 193).
# Flattening image 4014/6804 with shape (64, 64, 193).
# Flattening image 4015/6804 with shape (64, 64, 193).
# Flattening image 4016/6804 with shape (64, 64, 193).
# Flattening image 4017/6804 with shape (64, 64, 193).
# Flattening image 4018/6804 with shape (64, 64, 193).
# Flattening image 4019/6804 with shape (64, 64, 193).
# Flattening image 4020/6804 with shape (64, 64, 193).
# Flattening image 4021/6804 with shape (64, 64, 193).
# Flattening image 4022/6804 with shape (64, 64, 193).
# Flattening image 4023/6804 with shape (64, 64, 193).
# Flattening image 4024/6804 with shape (64, 64, 193).
# Flattening image 4025/6804 with shape (64, 64, 193).
# Flattening image 4026/6804 with shape (64, 64, 193).
# Flattening image 4027/6804 with shape (64, 64, 193).
# Flattening image 4028/6804 with shape (64, 64, 193).
# Flattening image 4029/6804 with shape (64, 64, 193).
# Flattening image 4030/6804 with shape (64, 64, 193).
# Flattening image 4031/6804 with shape (64, 64, 193).
# Flattening image 4032/6804 with shape (64, 64, 193).
# Flattening image 4033/6804 with shape (64, 64, 193).
# Flattening image 4034/6804 with shape (64, 64, 193).
# Flattening image 4035/6804 with shape (64, 64, 193).
# Flattening image 4036/6804 with shape (64, 64, 193).
# Flattening image 4037/6804 with shape (64, 64, 193).
# Flattening image 4038/6804 with shape (64, 64, 193).
# Flattening image 4039/6804 with shape (64, 64, 193).
# Flattening image 4040/6804 with shape (64, 64, 193).
# Flattening image 4041/6804 with shape (64, 64, 193).
# Flattening image 4042/6804 with shape (64, 64, 193).
# Flattening image 4043/6804 with shape (64, 64, 193).
# Flattening image 4044/6804 with shape (64, 64, 193).
# Flattening image 4045/6804 with shape (64, 64, 193).
# Flattening image 4046/6804 with shape (64, 64, 193).
# Flattening image 4047/6804 with shape (64, 64, 193).
# Flattening image 4048/6804 with shape (64, 64, 193).
# Flattening image 4049/6804 with shape (64, 64, 193).
# Flattening image 4050/6804 with shape (64, 64, 193).
# Flattening image 4051/6804 with shape (64, 64, 193).
# Flattening image 4052/6804 with shape (64, 64, 193).
# Flattening image 4053/6804 with shape (64, 64, 193).
# Flattening image 4054/6804 with shape (64, 64, 193).
# Flattening image 4055/6804 with shape (64, 64, 193).
# Flattening image 4056/6804 with shape (64, 64, 193).
# Flattening image 4057/6804 with shape (64, 64, 193).
# Flattening image 4058/6804 with shape (64, 64, 193).
# Flattening image 4059/6804 with shape (64, 64, 193).
# Flattening image 4060/6804 with shape (64, 64, 193).
# Flattening image 4061/6804 with shape (64, 64, 193).
# Flattening image 4062/6804 with shape (64, 64, 193).
# Flattening image 4063/6804 with shape (64, 64, 193).
# Flattening image 4064/6804 with shape (64, 64, 193).
# Flattening image 4065/6804 with shape (64, 64, 193).
# Flattening image 4066/6804 with shape (64, 64, 193).
# Flattening image 4067/6804 with shape (64, 64, 193).
# Flattening image 4068/6804 with shape (64, 64, 193).
# Flattening image 4069/6804 with shape (64, 64, 193).
# Flattening image 4070/6804 with shape (64, 64, 193).
# Flattening image 4071/6804 with shape (64, 64, 193).
# Flattening image 4072/6804 with shape (64, 64, 193).
# Flattening image 4073/6804 with shape (64, 64, 193).
# Flattening image 4074/6804 with shape (64, 64, 193).
# Flattening image 4075/6804 with shape (64, 64, 193).
# Flattening image 4076/6804 with shape (64, 64, 193).
# Flattening image 4077/6804 with shape (64, 64, 193).
# Flattening image 4078/6804 with shape (64, 64, 193).
# Flattening image 4079/6804 with shape (64, 64, 193).
# Flattening image 4080/6804 with shape (64, 64, 193).
# Flattening image 4081/6804 with shape (64, 64, 193).
# Flattening image 4082/6804 with shape (64, 64, 193).
# Flattening image 4083/6804 with shape (64, 64, 193).
# Flattening image 4084/6804 with shape (64, 64, 193).
# Flattening image 4085/6804 with shape (64, 64, 193).
# Flattening image 4086/6804 with shape (64, 64, 193).
# Flattening image 4087/6804 with shape (64, 64, 193).
# Flattening image 4088/6804 with shape (64, 64, 193).
# Flattening image 4089/6804 with shape (64, 64, 193).
# Flattening image 4090/6804 with shape (64, 64, 193).
# Flattening image 4091/6804 with shape (64, 64, 193).
# Flattening image 4092/6804 with shape (64, 64, 193).
# Flattening image 4093/6804 with shape (64, 64, 193).
# Flattening image 4094/6804 with shape (64, 64, 193).
# Flattening image 4095/6804 with shape (64, 64, 193).
# Flattening image 4096/6804 with shape (64, 64, 193).
# Flattening image 4097/6804 with shape (64, 64, 193).
# Flattening image 4098/6804 with shape (64, 64, 193).
# Flattening image 4099/6804 with shape (64, 64, 193).
# Flattening image 4100/6804 with shape (64, 64, 193).
# Flattening image 4101/6804 with shape (64, 64, 193).
# Flattening image 4102/6804 with shape (64, 64, 193).
# Flattening image 4103/6804 with shape (64, 64, 193).
# Flattening image 4104/6804 with shape (64, 64, 193).
# Flattening image 4105/6804 with shape (64, 64, 193).
# Flattening image 4106/6804 with shape (64, 64, 193).
# Flattening image 4107/6804 with shape (64, 64, 193).
# Flattening image 4108/6804 with shape (64, 64, 193).
# Flattening image 4109/6804 with shape (64, 64, 193).
# Flattening image 4110/6804 with shape (64, 64, 193).
# Flattening image 4111/6804 with shape (64, 64, 193).
# Flattening image 4112/6804 with shape (64, 64, 193).
# Flattening image 4113/6804 with shape (64, 64, 193).
# Flattening image 4114/6804 with shape (64, 64, 193).
# Flattening image 4115/6804 with shape (64, 64, 193).
# Flattening image 4116/6804 with shape (64, 64, 193).
# Flattening image 4117/6804 with shape (64, 64, 193).
# Flattening image 4118/6804 with shape (64, 64, 193).
# Flattening image 4119/6804 with shape (64, 64, 193).
# Flattening image 4120/6804 with shape (64, 64, 193).
# Flattening image 4121/6804 with shape (64, 64, 193).
# Flattening image 4122/6804 with shape (64, 64, 193).
# Flattening image 4123/6804 with shape (64, 64, 193).
# Flattening image 4124/6804 with shape (64, 64, 193).
# Flattening image 4125/6804 with shape (64, 64, 193).
# Flattening image 4126/6804 with shape (64, 64, 193).
# Flattening image 4127/6804 with shape (64, 64, 193).
# Flattening image 4128/6804 with shape (64, 64, 193).
# Flattening image 4129/6804 with shape (64, 64, 193).
# Flattening image 4130/6804 with shape (64, 64, 193).
# Flattening image 4131/6804 with shape (64, 64, 193).
# Flattening image 4132/6804 with shape (64, 64, 193).
# Flattening image 4133/6804 with shape (64, 64, 193).
# Flattening image 4134/6804 with shape (64, 64, 193).
# Flattening image 4135/6804 with shape (64, 64, 193).
# Flattening image 4136/6804 with shape (64, 64, 193).
# Flattening image 4137/6804 with shape (64, 64, 193).
# Flattening image 4138/6804 with shape (64, 64, 193).
# Flattening image 4139/6804 with shape (64, 64, 193).
# Flattening image 4140/6804 with shape (64, 64, 193).
# Flattening image 4141/6804 with shape (64, 64, 193).
# Flattening image 4142/6804 with shape (64, 64, 193).
# Flattening image 4143/6804 with shape (64, 64, 193).
# Flattening image 4144/6804 with shape (64, 64, 193).
# Flattening image 4145/6804 with shape (64, 64, 193).
# Flattening image 4146/6804 with shape (64, 64, 193).
# Flattening image 4147/6804 with shape (64, 64, 193).
# Flattening image 4148/6804 with shape (64, 64, 193).
# Flattening image 4149/6804 with shape (64, 64, 193).
# Flattening image 4150/6804 with shape (64, 64, 193).
# Flattening image 4151/6804 with shape (64, 64, 193).
# Flattening image 4152/6804 with shape (64, 64, 193).
# Flattening image 4153/6804 with shape (64, 64, 193).
# Flattening image 4154/6804 with shape (64, 64, 193).
# Flattening image 4155/6804 with shape (64, 64, 193).
# Flattening image 4156/6804 with shape (64, 64, 193).
# Flattening image 4157/6804 with shape (64, 64, 193).
# Flattening image 4158/6804 with shape (64, 64, 193).
# Flattening image 4159/6804 with shape (64, 64, 193).
# Flattening image 4160/6804 with shape (64, 64, 193).
# Flattening image 4161/6804 with shape (64, 64, 193).
# Flattening image 4162/6804 with shape (64, 64, 193).
# Flattening image 4163/6804 with shape (64, 64, 193).
# Flattening image 4164/6804 with shape (64, 64, 193).
# Flattening image 4165/6804 with shape (64, 64, 193).
# Flattening image 4166/6804 with shape (64, 64, 193).
# Flattening image 4167/6804 with shape (64, 64, 193).
# Flattening image 4168/6804 with shape (64, 64, 193).
# Flattening image 4169/6804 with shape (64, 64, 193).
# Flattening image 4170/6804 with shape (64, 64, 193).
# Flattening image 4171/6804 with shape (64, 64, 193).
# Flattening image 4172/6804 with shape (64, 64, 193).
# Flattening image 4173/6804 with shape (64, 64, 193).
# Flattening image 4174/6804 with shape (64, 64, 193).
# Flattening image 4175/6804 with shape (64, 64, 193).
# Flattening image 4176/6804 with shape (64, 64, 193).
# Flattening image 4177/6804 with shape (64, 64, 193).
# Flattening image 4178/6804 with shape (64, 64, 193).
# Flattening image 4179/6804 with shape (64, 64, 193).
# Flattening image 4180/6804 with shape (64, 64, 193).
# Flattening image 4181/6804 with shape (64, 64, 193).
# Flattening image 4182/6804 with shape (64, 64, 193).
# Flattening image 4183/6804 with shape (64, 64, 193).
# Flattening image 4184/6804 with shape (64, 64, 193).
# Flattening image 4185/6804 with shape (64, 64, 193).
# Flattening image 4186/6804 with shape (64, 64, 193).
# Flattening image 4187/6804 with shape (64, 64, 193).
# Flattening image 4188/6804 with shape (64, 64, 193).
# Flattening image 4189/6804 with shape (64, 64, 193).
# Flattening image 4190/6804 with shape (64, 64, 193).
# Flattening image 4191/6804 with shape (64, 64, 193).
# Flattening image 4192/6804 with shape (64, 64, 193).
# Flattening image 4193/6804 with shape (64, 64, 193).
# Flattening image 4194/6804 with shape (64, 64, 193).
# Flattening image 4195/6804 with shape (64, 64, 193).
# Flattening image 4196/6804 with shape (64, 64, 193).
# Flattening image 4197/6804 with shape (64, 64, 193).
# Flattening image 4198/6804 with shape (64, 64, 193).
# Flattening image 4199/6804 with shape (64, 64, 193).
# Flattening image 4200/6804 with shape (64, 64, 193).
# Flattening image 4201/6804 with shape (64, 64, 193).
# Flattening image 4202/6804 with shape (64, 64, 193).
# Flattening image 4203/6804 with shape (64, 64, 193).
# Flattening image 4204/6804 with shape (64, 64, 193).
# Flattening image 4205/6804 with shape (64, 64, 193).
# Flattening image 4206/6804 with shape (64, 64, 193).
# Flattening image 4207/6804 with shape (64, 64, 193).
# Flattening image 4208/6804 with shape (64, 64, 193).
# Flattening image 4209/6804 with shape (64, 64, 193).
# Flattening image 4210/6804 with shape (64, 64, 193).
# Flattening image 4211/6804 with shape (64, 64, 193).
# Flattening image 4212/6804 with shape (64, 64, 193).
# Flattening image 4213/6804 with shape (64, 64, 193).
# Flattening image 4214/6804 with shape (64, 64, 193).
# Flattening image 4215/6804 with shape (64, 64, 193).
# Flattening image 4216/6804 with shape (64, 64, 193).
# Flattening image 4217/6804 with shape (64, 64, 193).
# Flattening image 4218/6804 with shape (64, 64, 193).
# Flattening image 4219/6804 with shape (64, 64, 193).
# Flattening image 4220/6804 with shape (64, 64, 193).
# Flattening image 4221/6804 with shape (64, 64, 193).
# Flattening image 4222/6804 with shape (64, 64, 193).
# Flattening image 4223/6804 with shape (64, 64, 193).
# Flattening image 4224/6804 with shape (64, 64, 193).
# Flattening image 4225/6804 with shape (64, 64, 193).
# Flattening image 4226/6804 with shape (64, 64, 193).
# Flattening image 4227/6804 with shape (64, 64, 193).
# Flattening image 4228/6804 with shape (64, 64, 193).
# Flattening image 4229/6804 with shape (64, 64, 193).
# Flattening image 4230/6804 with shape (64, 64, 193).
# Flattening image 4231/6804 with shape (64, 64, 193).
# Flattening image 4232/6804 with shape (64, 64, 193).
# Flattening image 4233/6804 with shape (64, 64, 193).
# Flattening image 4234/6804 with shape (64, 64, 193).
# Flattening image 4235/6804 with shape (64, 64, 193).
# Flattening image 4236/6804 with shape (64, 64, 193).
# Flattening image 4237/6804 with shape (64, 64, 193).
# Flattening image 4238/6804 with shape (64, 64, 193).
# Flattening image 4239/6804 with shape (64, 64, 193).
# Flattening image 4240/6804 with shape (64, 64, 193).
# Flattening image 4241/6804 with shape (64, 64, 193).
# Flattening image 4242/6804 with shape (64, 64, 193).
# Flattening image 4243/6804 with shape (64, 64, 193).
# Flattening image 4244/6804 with shape (64, 64, 193).
# Flattening image 4245/6804 with shape (64, 64, 193).
# Flattening image 4246/6804 with shape (64, 64, 193).
# Flattening image 4247/6804 with shape (64, 64, 193).
# Flattening image 4248/6804 with shape (64, 64, 193).
# Flattening image 4249/6804 with shape (64, 64, 193).
# Flattening image 4250/6804 with shape (64, 64, 193).
# Flattening image 4251/6804 with shape (64, 64, 193).
# Flattening image 4252/6804 with shape (64, 64, 193).
# Flattening image 4253/6804 with shape (64, 64, 193).
# Flattening image 4254/6804 with shape (64, 64, 193).
# Flattening image 4255/6804 with shape (64, 64, 193).
# Flattening image 4256/6804 with shape (64, 64, 193).
# Flattening image 4257/6804 with shape (64, 64, 193).
# Flattening image 4258/6804 with shape (64, 64, 193).
# Flattening image 4259/6804 with shape (64, 64, 193).
# Flattening image 4260/6804 with shape (64, 64, 193).
# Flattening image 4261/6804 with shape (64, 64, 193).
# Flattening image 4262/6804 with shape (64, 64, 193).
# ...
# Flattening image 473/780 with shape (64, 64, 193).
# Flattening image 474/780 with shape (64, 64, 193).
# Flattening image 475/780 with shape (64, 64, 193).
# Flattening image 476/780 with shape (64, 64, 193).
# Flattening image 477/780 with shape (64, 64, 193).
# Flattening image 478/780 with shape (64, 64, 193).
# Flattening image 479/780 with shape (64, 64, 193).
# Flattening image 480/780 with shape (64, 64, 193).
# Flattening image 481/780 with shape (64, 64, 193).
# Flattening image 482/780 with shape (64, 64, 193).
# Flattening image 483/780 with shape (64, 64, 193).
# Flattening image 484/780 with shape (64, 64, 193).
# Flattening image 485/780 with shape (64, 64, 193).
# Flattening image 486/780 with shape (64, 64, 193).
# Flattening image 487/780 with shape (64, 64, 193).
# Flattening image 488/780 with shape (64, 64, 193).
# Flattening image 489/780 with shape (64, 64, 193).
# Flattening image 490/780 with shape (64, 64, 193).
# Flattening image 491/780 with shape (64, 64, 193).
# Flattening image 492/780 with shape (64, 64, 193).
# Flattening image 493/780 with shape (64, 64, 193).
# Flattening image 494/780 with shape (64, 64, 193).
# Flattening image 495/780 with shape (64, 64, 193).
# Flattening image 496/780 with shape (64, 64, 193).
# Flattening image 497/780 with shape (64, 64, 193).
# Flattening image 498/780 with shape (64, 64, 193).
# Flattening image 499/780 with shape (64, 64, 193).
# Flattening image 500/780 with shape (64, 64, 193).
# Flattening image 501/780 with shape (64, 64, 193).
# Flattening image 502/780 with shape (64, 64, 193).
# Flattening image 503/780 with shape (64, 64, 193).
# Flattening image 504/780 with shape (64, 64, 193).
# Flattening image 505/780 with shape (64, 64, 193).
# Flattening image 506/780 with shape (64, 64, 193).
# Flattening image 507/780 with shape (64, 64, 193).
# Flattening image 508/780 with shape (64, 64, 193).
# Flattening image 509/780 with shape (64, 64, 193).
# Flattening image 510/780 with shape (64, 64, 193).
# Flattening image 511/780 with shape (64, 64, 193).
# Flattening image 512/780 with shape (64, 64, 193).
# Flattening image 513/780 with shape (64, 64, 193).
# Flattening image 514/780 with shape (64, 64, 193).
# Flattening image 515/780 with shape (64, 64, 193).
# Flattening image 516/780 with shape (64, 64, 193).
# Flattening image 517/780 with shape (64, 64, 193).
# Flattening image 518/780 with shape (64, 64, 193).
# Flattening image 519/780 with shape (64, 64, 193).
# Flattening image 520/780 with shape (64, 64, 193).
# Flattening image 521/780 with shape (64, 64, 193).
# Flattening image 522/780 with shape (64, 64, 193).
# Flattening image 523/780 with shape (64, 64, 193).
# Flattening image 524/780 with shape (64, 64, 193).
# Flattening image 525/780 with shape (64, 64, 193).
# Flattening image 526/780 with shape (64, 64, 193).
# Flattening image 527/780 with shape (64, 64, 193).
# Flattening image 528/780 with shape (64, 64, 193).
# Flattening image 529/780 with shape (64, 64, 193).
# Flattening image 530/780 with shape (64, 64, 193).
# Flattening image 531/780 with shape (64, 64, 193).
# Flattening image 532/780 with shape (64, 64, 193).
# Flattening image 533/780 with shape (64, 64, 193).
# Flattening image 534/780 with shape (64, 64, 193).
# Flattening image 535/780 with shape (64, 64, 193).
# Flattening image 536/780 with shape (64, 64, 193).
# Flattening image 537/780 with shape (64, 64, 193).
# Flattening image 538/780 with shape (64, 64, 193).
# Flattening image 539/780 with shape (64, 64, 193).
# Flattening image 540/780 with shape (64, 64, 193).
# Flattening image 541/780 with shape (64, 64, 193).
# Flattening image 542/780 with shape (64, 64, 193).
# Flattening image 543/780 with shape (64, 64, 193).
# Flattening image 544/780 with shape (64, 64, 193).
# Flattening image 545/780 with shape (64, 64, 193).
# Flattening image 546/780 with shape (64, 64, 193).
# Flattening image 547/780 with shape (64, 64, 193).
# Flattening image 548/780 with shape (64, 64, 193).
# Flattening image 549/780 with shape (64, 64, 193).
# Flattening image 550/780 with shape (64, 64, 193).
# Flattening image 551/780 with shape (64, 64, 193).
# Flattening image 552/780 with shape (64, 64, 193).
# Flattening image 553/780 with shape (64, 64, 193).
# Flattening image 554/780 with shape (64, 64, 193).
# Flattening image 555/780 with shape (64, 64, 193).
# Flattening image 556/780 with shape (64, 64, 193).
# Flattening image 557/780 with shape (64, 64, 193).
# Flattening image 558/780 with shape (64, 64, 193).
# Flattening image 559/780 with shape (64, 64, 193).
# Flattening image 560/780 with shape (64, 64, 193).
# Flattening image 561/780 with shape (64, 64, 193).
# Flattening image 562/780 with shape (64, 64, 193).
# Flattening image 563/780 with shape (64, 64, 193).
# Flattening image 564/780 with shape (64, 64, 193).
# Flattening image 565/780 with shape (64, 64, 193).
# Flattening image 566/780 with shape (64, 64, 193).
# Flattening image 567/780 with shape (64, 64, 193).
# Flattening image 568/780 with shape (64, 64, 193).
# Flattening image 569/780 with shape (64, 64, 193).
# Flattening image 570/780 with shape (64, 64, 193).
# Flattening image 571/780 with shape (64, 64, 193).
# Flattening image 572/780 with shape (64, 64, 193).
# Flattening image 573/780 with shape (64, 64, 193).
# Flattening image 574/780 with shape (64, 64, 193).
# Flattening image 575/780 with shape (64, 64, 193).
# Flattening image 576/780 with shape (64, 64, 193).
# Flattening image 577/780 with shape (64, 64, 193).
# Flattening image 578/780 with shape (64, 64, 193).
# Flattening image 579/780 with shape (64, 64, 193).
# Flattening image 580/780 with shape (64, 64, 193).
# Flattening image 581/780 with shape (64, 64, 193).
# Flattening image 582/780 with shape (64, 64, 193).
# Flattening image 583/780 with shape (64, 64, 193).
# Flattening image 584/780 with shape (64, 64, 193).
# Flattening image 585/780 with shape (64, 64, 193).
# Flattening image 586/780 with shape (64, 64, 193).
# Flattening image 587/780 with shape (64, 64, 193).
# Flattening image 588/780 with shape (64, 64, 193).
# Flattening image 589/780 with shape (64, 64, 193).
# Flattening image 590/780 with shape (64, 64, 193).
# Flattening image 591/780 with shape (64, 64, 193).
# Flattening image 592/780 with shape (64, 64, 193).
# Flattening image 593/780 with shape (64, 64, 193).
# Flattening image 594/780 with shape (64, 64, 193).
# Flattening image 595/780 with shape (64, 64, 193).
# Flattening image 596/780 with shape (64, 64, 193).
# Flattening image 597/780 with shape (64, 64, 193).
# Flattening image 598/780 with shape (64, 64, 193).
# Flattening image 599/780 with shape (64, 64, 193).
# Flattening image 600/780 with shape (64, 64, 193).
# Flattening image 601/780 with shape (64, 64, 193).
# Flattening image 602/780 with shape (64, 64, 193).
# Flattening image 603/780 with shape (64, 64, 193).
# Flattening image 604/780 with shape (64, 64, 193).
# Flattening image 605/780 with shape (64, 64, 193).
# Flattening image 606/780 with shape (64, 64, 193).
# Flattening image 607/780 with shape (64, 64, 193).
# Flattening image 608/780 with shape (64, 64, 193).
# Flattening image 609/780 with shape (64, 64, 193).
# Flattening image 610/780 with shape (64, 64, 193).
# Flattening image 611/780 with shape (64, 64, 193).
# Flattening image 612/780 with shape (64, 64, 193).
# Flattening image 613/780 with shape (64, 64, 193).
# Flattening image 614/780 with shape (64, 64, 193).
# Flattening image 615/780 with shape (64, 64, 193).
# Flattening image 616/780 with shape (64, 64, 193).
# Flattening image 617/780 with shape (64, 64, 193).
# Flattening image 618/780 with shape (64, 64, 193).
# Flattening image 619/780 with shape (64, 64, 193).
# Flattening image 620/780 with shape (64, 64, 193).
# Flattening image 621/780 with shape (64, 64, 193).
# Flattening image 622/780 with shape (64, 64, 193).
# Flattening image 623/780 with shape (64, 64, 193).
# Flattening image 624/780 with shape (64, 64, 193).
# Flattening image 625/780 with shape (64, 64, 193).
# Flattening image 626/780 with shape (64, 64, 193).
# Flattening image 627/780 with shape (64, 64, 193).
# Flattening image 628/780 with shape (64, 64, 193).
# Flattening image 629/780 with shape (64, 64, 193).
# Flattening image 630/780 with shape (64, 64, 193).
# Flattening image 631/780 with shape (64, 64, 193).
# Flattening image 632/780 with shape (64, 64, 193).
# Flattening image 633/780 with shape (64, 64, 193).
# Flattening image 634/780 with shape (64, 64, 193).
# Flattening image 635/780 with shape (64, 64, 193).
# Flattening image 636/780 with shape (64, 64, 193).
# Flattening image 637/780 with shape (64, 64, 193).
# Flattening image 638/780 with shape (64, 64, 193).
# Flattening image 639/780 with shape (64, 64, 193).
# Flattening image 640/780 with shape (64, 64, 193).
# Flattening image 641/780 with shape (64, 64, 193).
# Flattening image 642/780 with shape (64, 64, 193).
# Flattening image 643/780 with shape (64, 64, 193).
# Flattening image 644/780 with shape (64, 64, 193).
# Flattening image 645/780 with shape (64, 64, 193).
# Flattening image 646/780 with shape (64, 64, 193).
# Flattening image 647/780 with shape (64, 64, 193).
# Flattening image 648/780 with shape (64, 64, 193).
# Flattening image 649/780 with shape (64, 64, 193).
# Flattening image 650/780 with shape (64, 64, 193).
# Flattening image 651/780 with shape (64, 64, 193).
# Flattening image 652/780 with shape (64, 64, 193).
# Flattening image 653/780 with shape (64, 64, 193).
# Flattening image 654/780 with shape (64, 64, 193).
# Flattening image 655/780 with shape (64, 64, 193).
# Flattening image 656/780 with shape (64, 64, 193).
# Flattening image 657/780 with shape (64, 64, 193).
# Flattening image 658/780 with shape (64, 64, 193).
# Flattening image 659/780 with shape (64, 64, 193).
# Flattening image 660/780 with shape (64, 64, 193).
# Flattening image 661/780 with shape (64, 64, 193).
# Flattening image 662/780 with shape (64, 64, 193).
# Flattening image 663/780 with shape (64, 64, 193).
# Flattening image 664/780 with shape (64, 64, 193).
# Flattening image 665/780 with shape (64, 64, 193).
# Flattening image 666/780 with shape (64, 64, 193).
# Flattening image 667/780 with shape (64, 64, 193).
# Flattening image 668/780 with shape (64, 64, 193).
# Flattening image 669/780 with shape (64, 64, 193).
# Flattening image 670/780 with shape (64, 64, 193).
# Flattening image 671/780 with shape (64, 64, 193).
# Flattening image 672/780 with shape (64, 64, 193).
# Flattening image 673/780 with shape (64, 64, 193).
# Flattening image 674/780 with shape (64, 64, 193).
# Flattening image 675/780 with shape (64, 64, 193).
# Flattening image 676/780 with shape (64, 64, 193).
# Flattening image 677/780 with shape (64, 64, 193).
# Flattening image 678/780 with shape (64, 64, 193).
# Flattening image 679/780 with shape (64, 64, 193).
# Flattening image 680/780 with shape (64, 64, 193).
# Flattening image 681/780 with shape (64, 64, 193).
# Flattening image 682/780 with shape (64, 64, 193).
# Flattening image 683/780 with shape (64, 64, 193).
# Flattening image 684/780 with shape (64, 64, 193).
# Flattening image 685/780 with shape (64, 64, 193).
# Flattening image 686/780 with shape (64, 64, 193).
# Flattening image 687/780 with shape (64, 64, 193).
# Flattening image 688/780 with shape (64, 64, 193).
# Flattening image 689/780 with shape (64, 64, 193).
# Flattening image 690/780 with shape (64, 64, 193).
# Flattening image 691/780 with shape (64, 64, 193).
# Flattening image 692/780 with shape (64, 64, 193).
# Flattening image 693/780 with shape (64, 64, 193).
# Flattening image 694/780 with shape (64, 64, 193).
# Flattening image 695/780 with shape (64, 64, 193).
# Flattening image 696/780 with shape (64, 64, 193).
# Flattening image 697/780 with shape (64, 64, 193).
# Flattening image 698/780 with shape (64, 64, 193).
# Flattening image 699/780 with shape (64, 64, 193).
# Flattening image 700/780 with shape (64, 64, 193).
# Flattening image 701/780 with shape (64, 64, 193).
# Flattening image 702/780 with shape (64, 64, 193).
# Flattening image 703/780 with shape (64, 64, 193).
# Flattening image 704/780 with shape (64, 64, 193).
# Flattening image 705/780 with shape (64, 64, 193).
# Flattening image 706/780 with shape (64, 64, 193).
# Flattening image 707/780 with shape (64, 64, 193).
# Flattening image 708/780 with shape (64, 64, 193).
# Flattening image 709/780 with shape (64, 64, 193).
# Flattening image 710/780 with shape (64, 64, 193).
# Flattening image 711/780 with shape (64, 64, 193).
# Flattening image 712/780 with shape (64, 64, 193).
# Flattening image 713/780 with shape (64, 64, 193).
# Flattening image 714/780 with shape (64, 64, 193).
# Flattening image 715/780 with shape (64, 64, 193).
# Flattening image 716/780 with shape (64, 64, 193).
# Flattening image 717/780 with shape (64, 64, 193).
# Flattening image 718/780 with shape (64, 64, 193).
# Flattening image 719/780 with shape (64, 64, 193).
# Flattening image 720/780 with shape (64, 64, 193).
# Flattening image 721/780 with shape (64, 64, 193).
# Flattening image 722/780 with shape (64, 64, 193).
# Flattening image 723/780 with shape (64, 64, 193).
# Flattening image 724/780 with shape (64, 64, 193).
# Flattening image 725/780 with shape (64, 64, 193).
# Flattening image 726/780 with shape (64, 64, 193).
# Flattening image 727/780 with shape (64, 64, 193).
# Flattening image 728/780 with shape (64, 64, 193).
# Flattening image 729/780 with shape (64, 64, 193).
# Flattening image 730/780 with shape (64, 64, 193).
# Flattening image 731/780 with shape (64, 64, 193).
# Flattening image 732/780 with shape (64, 64, 193).
# Flattening image 733/780 with shape (64, 64, 193).
# Flattening image 734/780 with shape (64, 64, 193).
# Flattening image 735/780 with shape (64, 64, 193).
# Flattening image 736/780 with shape (64, 64, 193).
# Flattening image 737/780 with shape (64, 64, 193).
# Flattening image 738/780 with shape (64, 64, 193).
# Flattening image 739/780 with shape (64, 64, 193).
# Flattening image 740/780 with shape (64, 64, 193).
# Flattening image 741/780 with shape (64, 64, 193).
# Flattening image 742/780 with shape (64, 64, 193).
# Flattening image 743/780 with shape (64, 64, 193).
# Flattening image 744/780 with shape (64, 64, 193).
# Flattening image 745/780 with shape (64, 64, 193).
# Flattening image 746/780 with shape (64, 64, 193).
# Flattening image 747/780 with shape (64, 64, 193).
# Flattening image 748/780 with shape (64, 64, 193).
# Flattening image 749/780 with shape (64, 64, 193).
# Flattening image 750/780 with shape (64, 64, 193).
# Flattening image 751/780 with shape (64, 64, 193).
# Flattening image 752/780 with shape (64, 64, 193).
# Flattening image 753/780 with shape (64, 64, 193).
# Flattening image 754/780 with shape (64, 64, 193).
# Flattening image 755/780 with shape (64, 64, 193).
# Flattening image 756/780 with shape (64, 64, 193).
# Flattening image 757/780 with shape (64, 64, 193).
# Flattening image 758/780 with shape (64, 64, 193).
# Flattening image 759/780 with shape (64, 64, 193).
# Flattening image 760/780 with shape (64, 64, 193).
# Flattening image 761/780 with shape (64, 64, 193).
# Flattening image 762/780 with shape (64, 64, 193).
# Flattening image 763/780 with shape (64, 64, 193).
# Flattening image 764/780 with shape (64, 64, 193).
# Flattening image 765/780 with shape (64, 64, 193).
# Flattening image 766/780 with shape (64, 64, 193).
# Flattening image 767/780 with shape (64, 64, 193).
# Flattening image 768/780 with shape (64, 64, 193).
# Flattening image 769/780 with shape (64, 64, 193).
# Flattening image 770/780 with shape (64, 64, 193).
# Flattening image 771/780 with shape (64, 64, 193).
# Flattening image 772/780 with shape (64, 64, 193).
# Flattening image 773/780 with shape (64, 64, 193).
# Flattening image 774/780 with shape (64, 64, 193).
# Flattening image 775/780 with shape (64, 64, 193).
# Flattening image 776/780 with shape (64, 64, 193).
# Flattening image 777/780 with shape (64, 64, 193).
# Flattening image 778/780 with shape (64, 64, 193).
# Flattening image 779/780 with shape (64, 64, 193).
# Flattening image 780/780 with shape (64, 64, 193).
# Flattened images shape: (3194880, 193)
# Flattened labels shape: (3194880,)
#
# Final Flattened Data Shapes:
# Train Data: (27869184, 193), Train Labels: (27869184,)
# Validation Data: (3108864, 193), Validation Labels: (3108864,)
# Test Data: (3194880, 193), Test Labels: (3194880,)

# %%
gc.collect()
# Out:
# 0

# %% [markdown]
# ## 8. Normalization: Channel Ranges Value

# %%
def analyze_feature_scaling(data):
    """
    Analyze the scale of features in the dataset to determine if normalization is necessary.

    Parameters:
    - data: 2D array (n_samples, n_features)

    Returns:
    - A summary table with statistics for each feature.
    - Visualization of feature ranges and variances using default Matplotlib light blue color and large font sizes.
    """
    # Calculate min, max, mean, standard deviation, and variance for each feature
    feature_stats = {
        "Feature Index": np.arange(data.shape[1]),
        "Min": np.min(data, axis=0),
        "Max": np.max(data, axis=0),
        "Mean": np.mean(data, axis=0),
        "Std Dev": np.std(data, axis=0),
        "Variance": np.var(data, axis=0)
    }

    # Create a DataFrame for better visualization
    stats_df = pd.DataFrame(feature_stats)

    # Print the summary table
    print("\nFeature Statistics:")
    print(stats_df.head(len(stats_df)))  # Display all features

    # Plot feature ranges and variances
    plt.figure(figsize=(15, 4))  # Larger figure size for clarity

    # Plot ranges (Min-Max)
    plt.subplot(1, 2, 1)
    plt.bar(stats_df["Feature Index"], stats_df["Max"] - stats_df["Min"], alpha=0.9)
    plt.title("Channel Ranges (Max - Min)", fontsize=20)
    plt.xlabel("Channel Index", fontsize=16)
    plt.ylabel("Range (Max - Min)", fontsize=16)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.grid(True)

    # Plot variances
    plt.subplot(1, 2, 2)
    plt.bar(stats_df["Feature Index"], stats_df["Variance"], alpha=0.9)
    plt.title("Channel Variances", fontsize=20)
    plt.xlabel("Channel Index", fontsize=16)
    plt.ylabel("Variance", fontsize=16)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.grid(True)

    # Adjust layout for readability
    plt.tight_layout()
    plt.show()

    return stats_df

# Analyze the scaling of features in the dataset
feature_summary = analyze_feature_scaling(all_data)
# Out:
# Feature Statistics:
#      Feature Index    Min    Max        Mean     Std Dev       Variance
# 0                0  -1736    884   27.458890  417.290602  174131.446378
# 1                1  -2351   3495   58.454955  504.095531  254112.304444
# 2                2  -2354   3499  424.641037  300.503027   90302.069384
# 3                3    -77   3034  559.180598  261.296415   68275.816654
# 4                4      0   4170  728.762951  414.112021  171488.766066
# ..             ...    ...    ...         ...         ...            ...
# 219            219 -26781  32202   -5.822035   24.612059     605.753473
# 220            220 -24340  27418   -9.196870   25.274151     638.782725
# 221            221 -10604  24237  -12.860256   33.236749    1104.681506
# 222            222   -931   1046   -6.672494   25.970198     674.451176
# 223            223  -1105   1234   -9.159716   30.360321     921.749090
#
# [224 rows x 6 columns]

# %% [markdown]
# ## 9. PCA: Plot Variance Explanation vs. Number of Components

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import gc

gc.collect()
scaler = StandardScaler()

# Scale the entire dataset
all_data_scaled = scaler.fit_transform(all_data)

# Perform PCA on the full dataset (all channels)
n_components_all = min(all_data.shape)
pca_all = PCA(n_components=n_components_all)
pca_all.fit(all_data_scaled)
cumulative_variance_all = np.cumsum(pca_all.explained_variance_ratio_)
n_components_99_all = np.argmax(cumulative_variance_all >= 0.99) + 1

# Scale the dataset without noisy channels
cleaned_data_scaled = scaler.fit_transform(all_data_filtered)  # Assuming `all_data_filtered` is your dataset without noisy channels
n_components_cleaned = min(all_data_filtered.shape)
pca_cleaned = PCA(n_components=n_components_cleaned)
pca_cleaned.fit(cleaned_data_scaled)
cumulative_variance_cleaned = np.cumsum(pca_cleaned.explained_variance_ratio_)
n_components_99_cleaned = np.argmax(cumulative_variance_cleaned >= 0.99) + 1


# Plot cumulative variance for both cases with enhanced readability and x-axis labels for components
plt.figure(figsize=(10, 6))

# Plot for all channels
plt.plot(range(1, len(cumulative_variance_all) + 1),
         cumulative_variance_all * 100,
         color='#1f77b4', linewidth=3, label='All Channels')
plt.axvline(x=n_components_99_all, color='#1f77b4', linestyle='--', linewidth=2.5)
plt.scatter([n_components_99_all], [cumulative_variance_all[n_components_99_all - 1] * 100],
            color='#1f77b4', s=100, edgecolor='#1f77b4', zorder=5)  # Match edgecolor to line color
plt.text(n_components_99_all - 3, 47.5, str(n_components_99_all), color='#1f77b4', fontsize=20, fontweight='bold')

# Plot for cleaned channels
plt.plot(range(1, len(cumulative_variance_cleaned) + 1),
         cumulative_variance_cleaned * 100,
         color='#ff7f0e', linewidth=3, label='Without Noisy Channels')
plt.axvline(x=n_components_99_cleaned, color='#ff7f0e', linestyle='--', linewidth=2.5)
plt.scatter([n_components_99_cleaned], [cumulative_variance_cleaned[n_components_99_cleaned - 1] * 100],
            color='#ff7f0e', s=100, edgecolor='#ff7f0e', zorder=5)  # Match edgecolor to line color
plt.text(n_components_99_cleaned - 3, 47.5, str(n_components_99_cleaned), color='#ff7f0e', fontsize=20, fontweight='bold')

# Horizontal line for 99% variance
plt.axhline(y=99, color='red', linestyle=':', linewidth=2.5, label='99% Target Threshold')

# Set larger fonts for labels and title
plt.xlabel('Number of Components', fontsize=22,  labelpad=22)
plt.ylabel('Cumulative Explained Variance (%)', fontsize=22)
plt.title('Explained Variance vs Number of PCA Components', fontsize=24, pad=30)

# Customize ticks
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

# Customize legend
plt.legend(fontsize=22, loc='lower right', frameon=True)

# Enable grid for better readability
plt.grid(True, which='both', linestyle='--', linewidth=1)

# Adjust layout for clarity
plt.tight_layout()

# Display the plot
plt.show()

# Print detailed variance information for both cases
print("\nVariance Information:")
print(f"All Channels: {n_components_99_all} components needed for 99% variance.")
print(f"Without Noisy Channels: {n_components_99_cleaned} components needed for 99% variance.")

gc.collect()

# Display the plot
plt.show()

# Print detailed variance information for both cases
print("\nVariance Information:")
print(f"All Channels: {n_components_99_all} components needed for 99% variance.")
print(f"Without Noisy Channels: {n_components_99_cleaned} components needed for 99% variance.")

gc.collect()
# Out:
# Variance Information:
# All Channels: 60 components needed for 99% variance.
# Without Noisy Channels: 32 components needed for 99% variance.
#
# Variance Information:
# All Channels: 60 components needed for 99% variance.
# Without Noisy Channels: 32 components needed for 99% variance.
# 0

# %%
# Plot cumulative variance for both cases with enhanced readability and x-axis labels for components
plt.figure(figsize=(10, 6))

# Plot for all channels
plt.plot(range(1, len(cumulative_variance_all) + 1),
         cumulative_variance_all * 100,
         color='#1f77b4', linewidth=3, label='All Channels')
plt.axvline(x=n_components_99_all, color='#1f77b4', linestyle='--', linewidth=2.5)
plt.scatter([n_components_99_all], [cumulative_variance_all[n_components_99_all - 1] * 100],
            color='#1f77b4', s=100, edgecolor='#1f77b4', zorder=5)  # Match edgecolor to line color
plt.text(n_components_99_all - 3, 46, str(n_components_99_all), color='#1f77b4', fontsize=20, fontweight='bold')

# Plot for cleaned channels
plt.plot(range(1, len(cumulative_variance_cleaned) + 1),
         cumulative_variance_cleaned * 100,
         color='#ff7f0e', linewidth=3, label='Without Noisy Channels')
plt.axvline(x=n_components_99_cleaned, color='#ff7f0e', linestyle='--', linewidth=2.5)
plt.scatter([n_components_99_cleaned], [cumulative_variance_cleaned[n_components_99_cleaned - 1] * 100],
            color='#ff7f0e', s=100, edgecolor='#ff7f0e', zorder=5)  # Match edgecolor to line color
plt.text(n_components_99_cleaned - 3, 46, str(n_components_99_cleaned), color='#ff7f0e', fontsize=20, fontweight='bold')

# Horizontal line for 99% variance
plt.axhline(y=99, color='red', linestyle=':', linewidth=2.5, label='99% Target Threshold')

# Set larger fonts for labels and title
plt.xlabel('Number of Components', fontsize=22,  labelpad=22)
plt.ylabel('Cumulative Explained Variance (%)', fontsize=20)

# Customize ticks
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

# Customize legend
plt.legend(fontsize=22, loc='lower right', frameon=True)

# Enable grid for better readability
plt.grid(True, which='both', linestyle='--', linewidth=1)

# Adjust layout for clarity
plt.tight_layout()

# Display the plot
plt.show()

# Print detailed variance information for both cases
print("\nVariance Information:")
print(f"All Channels: {n_components_99_all} components needed for 99% variance.")
print(f"Without Noisy Channels: {n_components_99_cleaned} components needed for 99% variance.")

gc.collect()

# Display the plot
plt.show()

# Print detailed variance information for both cases
print("\nVariance Information:")
print(f"All Channels: {n_components_99_all} components needed for 99% variance.")
print(f"Without Noisy Channels: {n_components_99_cleaned} components needed for 99% variance.")

gc.collect()
# Out:
# Variance Information:
# All Channels: 60 components needed for 99% variance.
# Without Noisy Channels: 32 components needed for 99% variance.
#
# Variance Information:
# All Channels: 60 components needed for 99% variance.
# Without Noisy Channels: 32 components needed for 99% variance.
# 0

# %% [markdown]
# ## 10. Apply PCA

# %%
# Initialize the scaler
scaler = StandardScaler()

# Fit on the training data
scaler.fit(train_data_flattened)

# Transform train, validation, and test sets
train_data_normalized = scaler.transform(train_data_flattened)
val_data_normalized = scaler.transform(val_data_flattened)
test_data_normalized = scaler.transform(test_data_flattened)

# %%
n_components = 32
# Apply PCA to reduce to n features
pca = PCA(n_components)
reduced_Train_data_flat = pca.fit_transform(train_data_normalized)
reduced_Val_data_flat = pca.transform(val_data_normalized)
reduced_Test_data_flat = pca.transform(test_data_normalized)

# %% [markdown]
# ## 11. Save the Processed Dataset

# %%
gc.collect()
# Define the number of PCA components dynamically
base_save_path = "/content/drive/MyDrive/DataSets/HSI-Augmented-Splitted"

# Function to reshape reduced data back to original image sizes
def reshape_reduced_data(reduced_data_flat, original_images, n_components):
    """
    Reshape the flattened reduced data back to the original image sizes.

    Parameters:
    - reduced_data_flat (np.ndarray): Flattened reduced data of shape (num_pixels, n_components).
    - original_images (list): List of original images for size reference.
    - n_components (int): Number of PCA components.

    Returns:
    - reshaped_data (list): List of reshaped images with reduced dimensions.
    """
    reshaped_data = []
    start_idx = 0

    for idx, image in enumerate(original_images):
        original_shape = image.shape
        num_pixels = original_shape[0] * original_shape[1]
        reshaped_image = reduced_data_flat[start_idx:start_idx + num_pixels].reshape(
            original_shape[0], original_shape[1], n_components
        )
        reshaped_data.append(reshaped_image)
        start_idx += num_pixels

    return reshaped_data


# Reshape reduced train, validation, and test data
print("\nReshaping training data...")
reduced_Train_data = reshape_reduced_data(reduced_Train_data_flat, train_images, n_components)

print("\nReshaping validation data...")
reduced_Val_data = reshape_reduced_data(reduced_Val_data_flat, val_images, n_components)

print("\nReshaping test data...")
reduced_Test_data = reshape_reduced_data(reduced_Test_data_flat, test_images, n_components)


# Function to save reduced data and labels to .npz format
def save_to_npz(data, save_path, label="data"):
    """
    Save data to a compressed .npz format.

    Parameters:
    - data (list): List of data to save (images or labels).
    - save_path (str): Path to save the .npz file.
    - label (str): Base label name for each item.
    """
    save_dict = {f"{label}_{i}": item for i, item in enumerate(data)}
    np.savez_compressed(save_path, **save_dict)
    print(f"Saved {len(data)} items to {save_path}")


# Generate save paths dynamically
save_path_Tr_Data = f"{base_save_path}/TrainTiles_{n_components}PCA_normalized.npz"
save_path_Val_Data = f"{base_save_path}/ValTiles_{n_components}PCA_normalized.npz"
save_path_Test_Data = f"{base_save_path}/TestTiles_{n_components}PCA_normalized.npz"

save_path_Tr_Labels = f"{base_save_path}/TrainLabels_{n_components}PCA_normalized.npz"
save_path_Val_Labels = f"{base_save_path}/ValLabels_{n_components}PCA_normalized.npz"
save_path_Test_Labels = f"{base_save_path}/TestLabels_{n_components}PCA_normalized.npz"

save_path_TestMask = f"{base_save_path}/TestMasks_{n_components}PCA_normalized.npz"

# Save PCA-reduced data and labels
print("\nSaving reduced training data...")
save_to_npz(reduced_Train_data, save_path_Tr_Data, label="train_tile")

print("\nSaving reduced validation data...")
save_to_npz(reduced_Val_data, save_path_Val_Data, label="val_tile")

print("\nSaving reduced test data...")
save_to_npz(reduced_Test_data, save_path_Test_Data, label="test_tile")

print("\nSaving training labels...")
save_to_npz(train_labels, save_path_Tr_Labels, label="train_label")

print("\nSaving validation labels...")
save_to_npz(val_labels, save_path_Val_Labels, label="val_label")

print("\nSaving test labels...")
save_to_npz(test_labels, save_path_Test_Labels, label="test_label")

# Save test masks
print("\nSaving test masks...")
np.savez_compressed(save_path_TestMask, test_masks=test_masks)
print(f"Test masks saved to {save_path_TestMask}")

gc.collect()
# Out:
# Streaming output truncated to the last 5000 lines.
# Image 3369/6804 reshaped to (64, 64, 32) with 32 components
# Image 3370/6804 reshaped to (64, 64, 32) with 32 components
# Image 3371/6804 reshaped to (64, 64, 32) with 32 components
# Image 3372/6804 reshaped to (64, 64, 32) with 32 components
# Image 3373/6804 reshaped to (64, 64, 32) with 32 components
# Image 3374/6804 reshaped to (64, 64, 32) with 32 components
# Image 3375/6804 reshaped to (64, 64, 32) with 32 components
# Image 3376/6804 reshaped to (64, 64, 32) with 32 components
# Image 3377/6804 reshaped to (64, 64, 32) with 32 components
# Image 3378/6804 reshaped to (64, 64, 32) with 32 components
# Image 3379/6804 reshaped to (64, 64, 32) with 32 components
# Image 3380/6804 reshaped to (64, 64, 32) with 32 components
# Image 3381/6804 reshaped to (64, 64, 32) with 32 components
# Image 3382/6804 reshaped to (64, 64, 32) with 32 components
# Image 3383/6804 reshaped to (64, 64, 32) with 32 components
# Image 3384/6804 reshaped to (64, 64, 32) with 32 components
# Image 3385/6804 reshaped to (64, 64, 32) with 32 components
# Image 3386/6804 reshaped to (64, 64, 32) with 32 components
# Image 3387/6804 reshaped to (64, 64, 32) with 32 components
# Image 3388/6804 reshaped to (64, 64, 32) with 32 components
# Image 3389/6804 reshaped to (64, 64, 32) with 32 components
# Image 3390/6804 reshaped to (64, 64, 32) with 32 components
# Image 3391/6804 reshaped to (64, 64, 32) with 32 components
# Image 3392/6804 reshaped to (64, 64, 32) with 32 components
# Image 3393/6804 reshaped to (64, 64, 32) with 32 components
# Image 3394/6804 reshaped to (64, 64, 32) with 32 components
# Image 3395/6804 reshaped to (64, 64, 32) with 32 components
# Image 3396/6804 reshaped to (64, 64, 32) with 32 components
# Image 3397/6804 reshaped to (64, 64, 32) with 32 components
# Image 3398/6804 reshaped to (64, 64, 32) with 32 components
# Image 3399/6804 reshaped to (64, 64, 32) with 32 components
# Image 3400/6804 reshaped to (64, 64, 32) with 32 components
# Image 3401/6804 reshaped to (64, 64, 32) with 32 components
# Image 3402/6804 reshaped to (64, 64, 32) with 32 components
# Image 3403/6804 reshaped to (64, 64, 32) with 32 components
# Image 3404/6804 reshaped to (64, 64, 32) with 32 components
# Image 3405/6804 reshaped to (64, 64, 32) with 32 components
# Image 3406/6804 reshaped to (64, 64, 32) with 32 components
# Image 3407/6804 reshaped to (64, 64, 32) with 32 components
# Image 3408/6804 reshaped to (64, 64, 32) with 32 components
# Image 3409/6804 reshaped to (64, 64, 32) with 32 components
# Image 3410/6804 reshaped to (64, 64, 32) with 32 components
# Image 3411/6804 reshaped to (64, 64, 32) with 32 components
# Image 3412/6804 reshaped to (64, 64, 32) with 32 components
# Image 3413/6804 reshaped to (64, 64, 32) with 32 components
# Image 3414/6804 reshaped to (64, 64, 32) with 32 components
# Image 3415/6804 reshaped to (64, 64, 32) with 32 components
# Image 3416/6804 reshaped to (64, 64, 32) with 32 components
# Image 3417/6804 reshaped to (64, 64, 32) with 32 components
# Image 3418/6804 reshaped to (64, 64, 32) with 32 components
# Image 3419/6804 reshaped to (64, 64, 32) with 32 components
# Image 3420/6804 reshaped to (64, 64, 32) with 32 components
# Image 3421/6804 reshaped to (64, 64, 32) with 32 components
# Image 3422/6804 reshaped to (64, 64, 32) with 32 components
# Image 3423/6804 reshaped to (64, 64, 32) with 32 components
# Image 3424/6804 reshaped to (64, 64, 32) with 32 components
# Image 3425/6804 reshaped to (64, 64, 32) with 32 components
# Image 3426/6804 reshaped to (64, 64, 32) with 32 components
# Image 3427/6804 reshaped to (64, 64, 32) with 32 components
# Image 3428/6804 reshaped to (64, 64, 32) with 32 components
# Image 3429/6804 reshaped to (64, 64, 32) with 32 components
# Image 3430/6804 reshaped to (64, 64, 32) with 32 components
# Image 3431/6804 reshaped to (64, 64, 32) with 32 components
# Image 3432/6804 reshaped to (64, 64, 32) with 32 components
# Image 3433/6804 reshaped to (64, 64, 32) with 32 components
# Image 3434/6804 reshaped to (64, 64, 32) with 32 components
# Image 3435/6804 reshaped to (64, 64, 32) with 32 components
# Image 3436/6804 reshaped to (64, 64, 32) with 32 components
# Image 3437/6804 reshaped to (64, 64, 32) with 32 components
# Image 3438/6804 reshaped to (64, 64, 32) with 32 components
# Image 3439/6804 reshaped to (64, 64, 32) with 32 components
# Image 3440/6804 reshaped to (64, 64, 32) with 32 components
# Image 3441/6804 reshaped to (64, 64, 32) with 32 components
# Image 3442/6804 reshaped to (64, 64, 32) with 32 components
# Image 3443/6804 reshaped to (64, 64, 32) with 32 components
# Image 3444/6804 reshaped to (64, 64, 32) with 32 components
# Image 3445/6804 reshaped to (64, 64, 32) with 32 components
# Image 3446/6804 reshaped to (64, 64, 32) with 32 components
# Image 3447/6804 reshaped to (64, 64, 32) with 32 components
# Image 3448/6804 reshaped to (64, 64, 32) with 32 components
# Image 3449/6804 reshaped to (64, 64, 32) with 32 components
# Image 3450/6804 reshaped to (64, 64, 32) with 32 components
# Image 3451/6804 reshaped to (64, 64, 32) with 32 components
# Image 3452/6804 reshaped to (64, 64, 32) with 32 components
# Image 3453/6804 reshaped to (64, 64, 32) with 32 components
# Image 3454/6804 reshaped to (64, 64, 32) with 32 components
# Image 3455/6804 reshaped to (64, 64, 32) with 32 components
# Image 3456/6804 reshaped to (64, 64, 32) with 32 components
# Image 3457/6804 reshaped to (64, 64, 32) with 32 components
# Image 3458/6804 reshaped to (64, 64, 32) with 32 components
# Image 3459/6804 reshaped to (64, 64, 32) with 32 components
# Image 3460/6804 reshaped to (64, 64, 32) with 32 components
# Image 3461/6804 reshaped to (64, 64, 32) with 32 components
# Image 3462/6804 reshaped to (64, 64, 32) with 32 components
# Image 3463/6804 reshaped to (64, 64, 32) with 32 components
# Image 3464/6804 reshaped to (64, 64, 32) with 32 components
# Image 3465/6804 reshaped to (64, 64, 32) with 32 components
# Image 3466/6804 reshaped to (64, 64, 32) with 32 components
# Image 3467/6804 reshaped to (64, 64, 32) with 32 components
# Image 3468/6804 reshaped to (64, 64, 32) with 32 components
# Image 3469/6804 reshaped to (64, 64, 32) with 32 components
# Image 3470/6804 reshaped to (64, 64, 32) with 32 components
# Image 3471/6804 reshaped to (64, 64, 32) with 32 components
# Image 3472/6804 reshaped to (64, 64, 32) with 32 components
# Image 3473/6804 reshaped to (64, 64, 32) with 32 components
# Image 3474/6804 reshaped to (64, 64, 32) with 32 components
# Image 3475/6804 reshaped to (64, 64, 32) with 32 components
# Image 3476/6804 reshaped to (64, 64, 32) with 32 components
# Image 3477/6804 reshaped to (64, 64, 32) with 32 components
# Image 3478/6804 reshaped to (64, 64, 32) with 32 components
# Image 3479/6804 reshaped to (64, 64, 32) with 32 components
# Image 3480/6804 reshaped to (64, 64, 32) with 32 components
# Image 3481/6804 reshaped to (64, 64, 32) with 32 components
# Image 3482/6804 reshaped to (64, 64, 32) with 32 components
# Image 3483/6804 reshaped to (64, 64, 32) with 32 components
# Image 3484/6804 reshaped to (64, 64, 32) with 32 components
# Image 3485/6804 reshaped to (64, 64, 32) with 32 components
# Image 3486/6804 reshaped to (64, 64, 32) with 32 components
# Image 3487/6804 reshaped to (64, 64, 32) with 32 components
# Image 3488/6804 reshaped to (64, 64, 32) with 32 components
# Image 3489/6804 reshaped to (64, 64, 32) with 32 components
# Image 3490/6804 reshaped to (64, 64, 32) with 32 components
# Image 3491/6804 reshaped to (64, 64, 32) with 32 components
# Image 3492/6804 reshaped to (64, 64, 32) with 32 components
# Image 3493/6804 reshaped to (64, 64, 32) with 32 components
# Image 3494/6804 reshaped to (64, 64, 32) with 32 components
# Image 3495/6804 reshaped to (64, 64, 32) with 32 components
# Image 3496/6804 reshaped to (64, 64, 32) with 32 components
# Image 3497/6804 reshaped to (64, 64, 32) with 32 components
# Image 3498/6804 reshaped to (64, 64, 32) with 32 components
# Image 3499/6804 reshaped to (64, 64, 32) with 32 components
# Image 3500/6804 reshaped to (64, 64, 32) with 32 components
# Image 3501/6804 reshaped to (64, 64, 32) with 32 components
# Image 3502/6804 reshaped to (64, 64, 32) with 32 components
# Image 3503/6804 reshaped to (64, 64, 32) with 32 components
# Image 3504/6804 reshaped to (64, 64, 32) with 32 components
# Image 3505/6804 reshaped to (64, 64, 32) with 32 components
# Image 3506/6804 reshaped to (64, 64, 32) with 32 components
# Image 3507/6804 reshaped to (64, 64, 32) with 32 components
# Image 3508/6804 reshaped to (64, 64, 32) with 32 components
# Image 3509/6804 reshaped to (64, 64, 32) with 32 components
# Image 3510/6804 reshaped to (64, 64, 32) with 32 components
# Image 3511/6804 reshaped to (64, 64, 32) with 32 components
# Image 3512/6804 reshaped to (64, 64, 32) with 32 components
# Image 3513/6804 reshaped to (64, 64, 32) with 32 components
# Image 3514/6804 reshaped to (64, 64, 32) with 32 components
# Image 3515/6804 reshaped to (64, 64, 32) with 32 components
# Image 3516/6804 reshaped to (64, 64, 32) with 32 components
# Image 3517/6804 reshaped to (64, 64, 32) with 32 components
# Image 3518/6804 reshaped to (64, 64, 32) with 32 components
# Image 3519/6804 reshaped to (64, 64, 32) with 32 components
# Image 3520/6804 reshaped to (64, 64, 32) with 32 components
# Image 3521/6804 reshaped to (64, 64, 32) with 32 components
# Image 3522/6804 reshaped to (64, 64, 32) with 32 components
# Image 3523/6804 reshaped to (64, 64, 32) with 32 components
# Image 3524/6804 reshaped to (64, 64, 32) with 32 components
# Image 3525/6804 reshaped to (64, 64, 32) with 32 components
# Image 3526/6804 reshaped to (64, 64, 32) with 32 components
# Image 3527/6804 reshaped to (64, 64, 32) with 32 components
# Image 3528/6804 reshaped to (64, 64, 32) with 32 components
# Image 3529/6804 reshaped to (64, 64, 32) with 32 components
# Image 3530/6804 reshaped to (64, 64, 32) with 32 components
# Image 3531/6804 reshaped to (64, 64, 32) with 32 components
# Image 3532/6804 reshaped to (64, 64, 32) with 32 components
# Image 3533/6804 reshaped to (64, 64, 32) with 32 components
# Image 3534/6804 reshaped to (64, 64, 32) with 32 components
# Image 3535/6804 reshaped to (64, 64, 32) with 32 components
# Image 3536/6804 reshaped to (64, 64, 32) with 32 components
# Image 3537/6804 reshaped to (64, 64, 32) with 32 components
# Image 3538/6804 reshaped to (64, 64, 32) with 32 components
# Image 3539/6804 reshaped to (64, 64, 32) with 32 components
# Image 3540/6804 reshaped to (64, 64, 32) with 32 components
# Image 3541/6804 reshaped to (64, 64, 32) with 32 components
# Image 3542/6804 reshaped to (64, 64, 32) with 32 components
# Image 3543/6804 reshaped to (64, 64, 32) with 32 components
# Image 3544/6804 reshaped to (64, 64, 32) with 32 components
# Image 3545/6804 reshaped to (64, 64, 32) with 32 components
# Image 3546/6804 reshaped to (64, 64, 32) with 32 components
# Image 3547/6804 reshaped to (64, 64, 32) with 32 components
# Image 3548/6804 reshaped to (64, 64, 32) with 32 components
# Image 3549/6804 reshaped to (64, 64, 32) with 32 components
# Image 3550/6804 reshaped to (64, 64, 32) with 32 components
# Image 3551/6804 reshaped to (64, 64, 32) with 32 components
# Image 3552/6804 reshaped to (64, 64, 32) with 32 components
# Image 3553/6804 reshaped to (64, 64, 32) with 32 components
# Image 3554/6804 reshaped to (64, 64, 32) with 32 components
# Image 3555/6804 reshaped to (64, 64, 32) with 32 components
# Image 3556/6804 reshaped to (64, 64, 32) with 32 components
# Image 3557/6804 reshaped to (64, 64, 32) with 32 components
# Image 3558/6804 reshaped to (64, 64, 32) with 32 components
# Image 3559/6804 reshaped to (64, 64, 32) with 32 components
# Image 3560/6804 reshaped to (64, 64, 32) with 32 components
# Image 3561/6804 reshaped to (64, 64, 32) with 32 components
# Image 3562/6804 reshaped to (64, 64, 32) with 32 components
# Image 3563/6804 reshaped to (64, 64, 32) with 32 components
# Image 3564/6804 reshaped to (64, 64, 32) with 32 components
# Image 3565/6804 reshaped to (64, 64, 32) with 32 components
# Image 3566/6804 reshaped to (64, 64, 32) with 32 components
# Image 3567/6804 reshaped to (64, 64, 32) with 32 components
# Image 3568/6804 reshaped to (64, 64, 32) with 32 components
# Image 3569/6804 reshaped to (64, 64, 32) with 32 components
# Image 3570/6804 reshaped to (64, 64, 32) with 32 components
# Image 3571/6804 reshaped to (64, 64, 32) with 32 components
# Image 3572/6804 reshaped to (64, 64, 32) with 32 components
# Image 3573/6804 reshaped to (64, 64, 32) with 32 components
# Image 3574/6804 reshaped to (64, 64, 32) with 32 components
# Image 3575/6804 reshaped to (64, 64, 32) with 32 components
# Image 3576/6804 reshaped to (64, 64, 32) with 32 components
# Image 3577/6804 reshaped to (64, 64, 32) with 32 components
# Image 3578/6804 reshaped to (64, 64, 32) with 32 components
# Image 3579/6804 reshaped to (64, 64, 32) with 32 components
# Image 3580/6804 reshaped to (64, 64, 32) with 32 components
# Image 3581/6804 reshaped to (64, 64, 32) with 32 components
# Image 3582/6804 reshaped to (64, 64, 32) with 32 components
# Image 3583/6804 reshaped to (64, 64, 32) with 32 components
# Image 3584/6804 reshaped to (64, 64, 32) with 32 components
# Image 3585/6804 reshaped to (64, 64, 32) with 32 components
# Image 3586/6804 reshaped to (64, 64, 32) with 32 components
# Image 3587/6804 reshaped to (64, 64, 32) with 32 components
# Image 3588/6804 reshaped to (64, 64, 32) with 32 components
# Image 3589/6804 reshaped to (64, 64, 32) with 32 components
# Image 3590/6804 reshaped to (64, 64, 32) with 32 components
# Image 3591/6804 reshaped to (64, 64, 32) with 32 components
# Image 3592/6804 reshaped to (64, 64, 32) with 32 components
# Image 3593/6804 reshaped to (64, 64, 32) with 32 components
# Image 3594/6804 reshaped to (64, 64, 32) with 32 components
# Image 3595/6804 reshaped to (64, 64, 32) with 32 components
# Image 3596/6804 reshaped to (64, 64, 32) with 32 components
# Image 3597/6804 reshaped to (64, 64, 32) with 32 components
# Image 3598/6804 reshaped to (64, 64, 32) with 32 components
# Image 3599/6804 reshaped to (64, 64, 32) with 32 components
# Image 3600/6804 reshaped to (64, 64, 32) with 32 components
# Image 3601/6804 reshaped to (64, 64, 32) with 32 components
# Image 3602/6804 reshaped to (64, 64, 32) with 32 components
# Image 3603/6804 reshaped to (64, 64, 32) with 32 components
# Image 3604/6804 reshaped to (64, 64, 32) with 32 components
# Image 3605/6804 reshaped to (64, 64, 32) with 32 components
# Image 3606/6804 reshaped to (64, 64, 32) with 32 components
# Image 3607/6804 reshaped to (64, 64, 32) with 32 components
# Image 3608/6804 reshaped to (64, 64, 32) with 32 components
# Image 3609/6804 reshaped to (64, 64, 32) with 32 components
# Image 3610/6804 reshaped to (64, 64, 32) with 32 components
# Image 3611/6804 reshaped to (64, 64, 32) with 32 components
# Image 3612/6804 reshaped to (64, 64, 32) with 32 components
# Image 3613/6804 reshaped to (64, 64, 32) with 32 components
# Image 3614/6804 reshaped to (64, 64, 32) with 32 components
# Image 3615/6804 reshaped to (64, 64, 32) with 32 components
# Image 3616/6804 reshaped to (64, 64, 32) with 32 components
# Image 3617/6804 reshaped to (64, 64, 32) with 32 components
# Image 3618/6804 reshaped to (64, 64, 32) with 32 components
# Image 3619/6804 reshaped to (64, 64, 32) with 32 components
# Image 3620/6804 reshaped to (64, 64, 32) with 32 components
# Image 3621/6804 reshaped to (64, 64, 32) with 32 components
# Image 3622/6804 reshaped to (64, 64, 32) with 32 components
# Image 3623/6804 reshaped to (64, 64, 32) with 32 components
# Image 3624/6804 reshaped to (64, 64, 32) with 32 components
# Image 3625/6804 reshaped to (64, 64, 32) with 32 components
# Image 3626/6804 reshaped to (64, 64, 32) with 32 components
# Image 3627/6804 reshaped to (64, 64, 32) with 32 components
# Image 3628/6804 reshaped to (64, 64, 32) with 32 components
# Image 3629/6804 reshaped to (64, 64, 32) with 32 components
# Image 3630/6804 reshaped to (64, 64, 32) with 32 components
# Image 3631/6804 reshaped to (64, 64, 32) with 32 components
# Image 3632/6804 reshaped to (64, 64, 32) with 32 components
# Image 3633/6804 reshaped to (64, 64, 32) with 32 components
# Image 3634/6804 reshaped to (64, 64, 32) with 32 components
# Image 3635/6804 reshaped to (64, 64, 32) with 32 components
# Image 3636/6804 reshaped to (64, 64, 32) with 32 components
# Image 3637/6804 reshaped to (64, 64, 32) with 32 components
# Image 3638/6804 reshaped to (64, 64, 32) with 32 components
# Image 3639/6804 reshaped to (64, 64, 32) with 32 components
# Image 3640/6804 reshaped to (64, 64, 32) with 32 components
# Image 3641/6804 reshaped to (64, 64, 32) with 32 components
# Image 3642/6804 reshaped to (64, 64, 32) with 32 components
# Image 3643/6804 reshaped to (64, 64, 32) with 32 components
# Image 3644/6804 reshaped to (64, 64, 32) with 32 components
# Image 3645/6804 reshaped to (64, 64, 32) with 32 components
# Image 3646/6804 reshaped to (64, 64, 32) with 32 components
# Image 3647/6804 reshaped to (64, 64, 32) with 32 components
# Image 3648/6804 reshaped to (64, 64, 32) with 32 components
# Image 3649/6804 reshaped to (64, 64, 32) with 32 components
# Image 3650/6804 reshaped to (64, 64, 32) with 32 components
# Image 3651/6804 reshaped to (64, 64, 32) with 32 components
# Image 3652/6804 reshaped to (64, 64, 32) with 32 components
# Image 3653/6804 reshaped to (64, 64, 32) with 32 components
# Image 3654/6804 reshaped to (64, 64, 32) with 32 components
# Image 3655/6804 reshaped to (64, 64, 32) with 32 components
# Image 3656/6804 reshaped to (64, 64, 32) with 32 components
# Image 3657/6804 reshaped to (64, 64, 32) with 32 components
# Image 3658/6804 reshaped to (64, 64, 32) with 32 components
# Image 3659/6804 reshaped to (64, 64, 32) with 32 components
# Image 3660/6804 reshaped to (64, 64, 32) with 32 components
# Image 3661/6804 reshaped to (64, 64, 32) with 32 components
# Image 3662/6804 reshaped to (64, 64, 32) with 32 components
# Image 3663/6804 reshaped to (64, 64, 32) with 32 components
# Image 3664/6804 reshaped to (64, 64, 32) with 32 components
# Image 3665/6804 reshaped to (64, 64, 32) with 32 components
# Image 3666/6804 reshaped to (64, 64, 32) with 32 components
# Image 3667/6804 reshaped to (64, 64, 32) with 32 components
# Image 3668/6804 reshaped to (64, 64, 32) with 32 components
# Image 3669/6804 reshaped to (64, 64, 32) with 32 components
# Image 3670/6804 reshaped to (64, 64, 32) with 32 components
# Image 3671/6804 reshaped to (64, 64, 32) with 32 components
# Image 3672/6804 reshaped to (64, 64, 32) with 32 components
# Image 3673/6804 reshaped to (64, 64, 32) with 32 components
# Image 3674/6804 reshaped to (64, 64, 32) with 32 components
# Image 3675/6804 reshaped to (64, 64, 32) with 32 components
# Image 3676/6804 reshaped to (64, 64, 32) with 32 components
# Image 3677/6804 reshaped to (64, 64, 32) with 32 components
# Image 3678/6804 reshaped to (64, 64, 32) with 32 components
# Image 3679/6804 reshaped to (64, 64, 32) with 32 components
# Image 3680/6804 reshaped to (64, 64, 32) with 32 components
# Image 3681/6804 reshaped to (64, 64, 32) with 32 components
# Image 3682/6804 reshaped to (64, 64, 32) with 32 components
# Image 3683/6804 reshaped to (64, 64, 32) with 32 components
# Image 3684/6804 reshaped to (64, 64, 32) with 32 components
# Image 3685/6804 reshaped to (64, 64, 32) with 32 components
# Image 3686/6804 reshaped to (64, 64, 32) with 32 components
# Image 3687/6804 reshaped to (64, 64, 32) with 32 components
# Image 3688/6804 reshaped to (64, 64, 32) with 32 components
# Image 3689/6804 reshaped to (64, 64, 32) with 32 components
# Image 3690/6804 reshaped to (64, 64, 32) with 32 components
# Image 3691/6804 reshaped to (64, 64, 32) with 32 components
# Image 3692/6804 reshaped to (64, 64, 32) with 32 components
# Image 3693/6804 reshaped to (64, 64, 32) with 32 components
# Image 3694/6804 reshaped to (64, 64, 32) with 32 components
# Image 3695/6804 reshaped to (64, 64, 32) with 32 components
# Image 3696/6804 reshaped to (64, 64, 32) with 32 components
# Image 3697/6804 reshaped to (64, 64, 32) with 32 components
# Image 3698/6804 reshaped to (64, 64, 32) with 32 components
# Image 3699/6804 reshaped to (64, 64, 32) with 32 components
# Image 3700/6804 reshaped to (64, 64, 32) with 32 components
# Image 3701/6804 reshaped to (64, 64, 32) with 32 components
# Image 3702/6804 reshaped to (64, 64, 32) with 32 components
# Image 3703/6804 reshaped to (64, 64, 32) with 32 components
# Image 3704/6804 reshaped to (64, 64, 32) with 32 components
# Image 3705/6804 reshaped to (64, 64, 32) with 32 components
# Image 3706/6804 reshaped to (64, 64, 32) with 32 components
# Image 3707/6804 reshaped to (64, 64, 32) with 32 components
# Image 3708/6804 reshaped to (64, 64, 32) with 32 components
# Image 3709/6804 reshaped to (64, 64, 32) with 32 components
# Image 3710/6804 reshaped to (64, 64, 32) with 32 components
# Image 3711/6804 reshaped to (64, 64, 32) with 32 components
# Image 3712/6804 reshaped to (64, 64, 32) with 32 components
# Image 3713/6804 reshaped to (64, 64, 32) with 32 components
# Image 3714/6804 reshaped to (64, 64, 32) with 32 components
# Image 3715/6804 reshaped to (64, 64, 32) with 32 components
# Image 3716/6804 reshaped to (64, 64, 32) with 32 components
# Image 3717/6804 reshaped to (64, 64, 32) with 32 components
# Image 3718/6804 reshaped to (64, 64, 32) with 32 components
# Image 3719/6804 reshaped to (64, 64, 32) with 32 components
# Image 3720/6804 reshaped to (64, 64, 32) with 32 components
# Image 3721/6804 reshaped to (64, 64, 32) with 32 components
# Image 3722/6804 reshaped to (64, 64, 32) with 32 components
# Image 3723/6804 reshaped to (64, 64, 32) with 32 components
# Image 3724/6804 reshaped to (64, 64, 32) with 32 components
# Image 3725/6804 reshaped to (64, 64, 32) with 32 components
# Image 3726/6804 reshaped to (64, 64, 32) with 32 components
# Image 3727/6804 reshaped to (64, 64, 32) with 32 components
# Image 3728/6804 reshaped to (64, 64, 32) with 32 components
# Image 3729/6804 reshaped to (64, 64, 32) with 32 components
# Image 3730/6804 reshaped to (64, 64, 32) with 32 components
# Image 3731/6804 reshaped to (64, 64, 32) with 32 components
# Image 3732/6804 reshaped to (64, 64, 32) with 32 components
# Image 3733/6804 reshaped to (64, 64, 32) with 32 components
# Image 3734/6804 reshaped to (64, 64, 32) with 32 components
# Image 3735/6804 reshaped to (64, 64, 32) with 32 components
# Image 3736/6804 reshaped to (64, 64, 32) with 32 components
# Image 3737/6804 reshaped to (64, 64, 32) with 32 components
# Image 3738/6804 reshaped to (64, 64, 32) with 32 components
# Image 3739/6804 reshaped to (64, 64, 32) with 32 components
# Image 3740/6804 reshaped to (64, 64, 32) with 32 components
# Image 3741/6804 reshaped to (64, 64, 32) with 32 components
# Image 3742/6804 reshaped to (64, 64, 32) with 32 components
# Image 3743/6804 reshaped to (64, 64, 32) with 32 components
# Image 3744/6804 reshaped to (64, 64, 32) with 32 components
# Image 3745/6804 reshaped to (64, 64, 32) with 32 components
# Image 3746/6804 reshaped to (64, 64, 32) with 32 components
# Image 3747/6804 reshaped to (64, 64, 32) with 32 components
# Image 3748/6804 reshaped to (64, 64, 32) with 32 components
# Image 3749/6804 reshaped to (64, 64, 32) with 32 components
# Image 3750/6804 reshaped to (64, 64, 32) with 32 components
# Image 3751/6804 reshaped to (64, 64, 32) with 32 components
# Image 3752/6804 reshaped to (64, 64, 32) with 32 components
# Image 3753/6804 reshaped to (64, 64, 32) with 32 components
# Image 3754/6804 reshaped to (64, 64, 32) with 32 components
# Image 3755/6804 reshaped to (64, 64, 32) with 32 components
# Image 3756/6804 reshaped to (64, 64, 32) with 32 components
# Image 3757/6804 reshaped to (64, 64, 32) with 32 components
# Image 3758/6804 reshaped to (64, 64, 32) with 32 components
# Image 3759/6804 reshaped to (64, 64, 32) with 32 components
# Image 3760/6804 reshaped to (64, 64, 32) with 32 components
# Image 3761/6804 reshaped to (64, 64, 32) with 32 components
# Image 3762/6804 reshaped to (64, 64, 32) with 32 components
# Image 3763/6804 reshaped to (64, 64, 32) with 32 components
# Image 3764/6804 reshaped to (64, 64, 32) with 32 components
# Image 3765/6804 reshaped to (64, 64, 32) with 32 components
# Image 3766/6804 reshaped to (64, 64, 32) with 32 components
# Image 3767/6804 reshaped to (64, 64, 32) with 32 components
# Image 3768/6804 reshaped to (64, 64, 32) with 32 components
# Image 3769/6804 reshaped to (64, 64, 32) with 32 components
# Image 3770/6804 reshaped to (64, 64, 32) with 32 components
# Image 3771/6804 reshaped to (64, 64, 32) with 32 components
# Image 3772/6804 reshaped to (64, 64, 32) with 32 components
# Image 3773/6804 reshaped to (64, 64, 32) with 32 components
# Image 3774/6804 reshaped to (64, 64, 32) with 32 components
# Image 3775/6804 reshaped to (64, 64, 32) with 32 components
# Image 3776/6804 reshaped to (64, 64, 32) with 32 components
# Image 3777/6804 reshaped to (64, 64, 32) with 32 components
# Image 3778/6804 reshaped to (64, 64, 32) with 32 components
# Image 3779/6804 reshaped to (64, 64, 32) with 32 components
# Image 3780/6804 reshaped to (64, 64, 32) with 32 components
# Image 3781/6804 reshaped to (64, 64, 32) with 32 components
# Image 3782/6804 reshaped to (64, 64, 32) with 32 components
# Image 3783/6804 reshaped to (64, 64, 32) with 32 components
# Image 3784/6804 reshaped to (64, 64, 32) with 32 components
# Image 3785/6804 reshaped to (64, 64, 32) with 32 components
# Image 3786/6804 reshaped to (64, 64, 32) with 32 components
# Image 3787/6804 reshaped to (64, 64, 32) with 32 components
# Image 3788/6804 reshaped to (64, 64, 32) with 32 components
# Image 3789/6804 reshaped to (64, 64, 32) with 32 components
# Image 3790/6804 reshaped to (64, 64, 32) with 32 components
# Image 3791/6804 reshaped to (64, 64, 32) with 32 components
# Image 3792/6804 reshaped to (64, 64, 32) with 32 components
# Image 3793/6804 reshaped to (64, 64, 32) with 32 components
# Image 3794/6804 reshaped to (64, 64, 32) with 32 components
# Image 3795/6804 reshaped to (64, 64, 32) with 32 components
# Image 3796/6804 reshaped to (64, 64, 32) with 32 components
# Image 3797/6804 reshaped to (64, 64, 32) with 32 components
# Image 3798/6804 reshaped to (64, 64, 32) with 32 components
# Image 3799/6804 reshaped to (64, 64, 32) with 32 components
# Image 3800/6804 reshaped to (64, 64, 32) with 32 components
# Image 3801/6804 reshaped to (64, 64, 32) with 32 components
# Image 3802/6804 reshaped to (64, 64, 32) with 32 components
# Image 3803/6804 reshaped to (64, 64, 32) with 32 components
# Image 3804/6804 reshaped to (64, 64, 32) with 32 components
# Image 3805/6804 reshaped to (64, 64, 32) with 32 components
# Image 3806/6804 reshaped to (64, 64, 32) with 32 components
# Image 3807/6804 reshaped to (64, 64, 32) with 32 components
# Image 3808/6804 reshaped to (64, 64, 32) with 32 components
# Image 3809/6804 reshaped to (64, 64, 32) with 32 components
# Image 3810/6804 reshaped to (64, 64, 32) with 32 components
# Image 3811/6804 reshaped to (64, 64, 32) with 32 components
# Image 3812/6804 reshaped to (64, 64, 32) with 32 components
# Image 3813/6804 reshaped to (64, 64, 32) with 32 components
# Image 3814/6804 reshaped to (64, 64, 32) with 32 components
# Image 3815/6804 reshaped to (64, 64, 32) with 32 components
# Image 3816/6804 reshaped to (64, 64, 32) with 32 components
# Image 3817/6804 reshaped to (64, 64, 32) with 32 components
# Image 3818/6804 reshaped to (64, 64, 32) with 32 components
# Image 3819/6804 reshaped to (64, 64, 32) with 32 components
# Image 3820/6804 reshaped to (64, 64, 32) with 32 components
# Image 3821/6804 reshaped to (64, 64, 32) with 32 components
# Image 3822/6804 reshaped to (64, 64, 32) with 32 components
# Image 3823/6804 reshaped to (64, 64, 32) with 32 components
# Image 3824/6804 reshaped to (64, 64, 32) with 32 components
# Image 3825/6804 reshaped to (64, 64, 32) with 32 components
# Image 3826/6804 reshaped to (64, 64, 32) with 32 components
# Image 3827/6804 reshaped to (64, 64, 32) with 32 components
# Image 3828/6804 reshaped to (64, 64, 32) with 32 components
# Image 3829/6804 reshaped to (64, 64, 32) with 32 components
# Image 3830/6804 reshaped to (64, 64, 32) with 32 components
# Image 3831/6804 reshaped to (64, 64, 32) with 32 components
# Image 3832/6804 reshaped to (64, 64, 32) with 32 components
# Image 3833/6804 reshaped to (64, 64, 32) with 32 components
# Image 3834/6804 reshaped to (64, 64, 32) with 32 components
# Image 3835/6804 reshaped to (64, 64, 32) with 32 components
# Image 3836/6804 reshaped to (64, 64, 32) with 32 components
# Image 3837/6804 reshaped to (64, 64, 32) with 32 components
# Image 3838/6804 reshaped to (64, 64, 32) with 32 components
# Image 3839/6804 reshaped to (64, 64, 32) with 32 components
# Image 3840/6804 reshaped to (64, 64, 32) with 32 components
# Image 3841/6804 reshaped to (64, 64, 32) with 32 components
# Image 3842/6804 reshaped to (64, 64, 32) with 32 components
# Image 3843/6804 reshaped to (64, 64, 32) with 32 components
# Image 3844/6804 reshaped to (64, 64, 32) with 32 components
# Image 3845/6804 reshaped to (64, 64, 32) with 32 components
# Image 3846/6804 reshaped to (64, 64, 32) with 32 components
# Image 3847/6804 reshaped to (64, 64, 32) with 32 components
# Image 3848/6804 reshaped to (64, 64, 32) with 32 components
# Image 3849/6804 reshaped to (64, 64, 32) with 32 components
# Image 3850/6804 reshaped to (64, 64, 32) with 32 components
# Image 3851/6804 reshaped to (64, 64, 32) with 32 components
# Image 3852/6804 reshaped to (64, 64, 32) with 32 components
# Image 3853/6804 reshaped to (64, 64, 32) with 32 components
# Image 3854/6804 reshaped to (64, 64, 32) with 32 components
# Image 3855/6804 reshaped to (64, 64, 32) with 32 components
# Image 3856/6804 reshaped to (64, 64, 32) with 32 components
# Image 3857/6804 reshaped to (64, 64, 32) with 32 components
# Image 3858/6804 reshaped to (64, 64, 32) with 32 components
# Image 3859/6804 reshaped to (64, 64, 32) with 32 components
# Image 3860/6804 reshaped to (64, 64, 32) with 32 components
# Image 3861/6804 reshaped to (64, 64, 32) with 32 components
# Image 3862/6804 reshaped to (64, 64, 32) with 32 components
# Image 3863/6804 reshaped to (64, 64, 32) with 32 components
# Image 3864/6804 reshaped to (64, 64, 32) with 32 components
# Image 3865/6804 reshaped to (64, 64, 32) with 32 components
# Image 3866/6804 reshaped to (64, 64, 32) with 32 components
# Image 3867/6804 reshaped to (64, 64, 32) with 32 components
# Image 3868/6804 reshaped to (64, 64, 32) with 32 components
# Image 3869/6804 reshaped to (64, 64, 32) with 32 components
# Image 3870/6804 reshaped to (64, 64, 32) with 32 components
# Image 3871/6804 reshaped to (64, 64, 32) with 32 components
# Image 3872/6804 reshaped to (64, 64, 32) with 32 components
# Image 3873/6804 reshaped to (64, 64, 32) with 32 components
# Image 3874/6804 reshaped to (64, 64, 32) with 32 components
# Image 3875/6804 reshaped to (64, 64, 32) with 32 components
# Image 3876/6804 reshaped to (64, 64, 32) with 32 components
# Image 3877/6804 reshaped to (64, 64, 32) with 32 components
# Image 3878/6804 reshaped to (64, 64, 32) with 32 components
# Image 3879/6804 reshaped to (64, 64, 32) with 32 components
# Image 3880/6804 reshaped to (64, 64, 32) with 32 components
# Image 3881/6804 reshaped to (64, 64, 32) with 32 components
# Image 3882/6804 reshaped to (64, 64, 32) with 32 components
# Image 3883/6804 reshaped to (64, 64, 32) with 32 components
# Image 3884/6804 reshaped to (64, 64, 32) with 32 components
# Image 3885/6804 reshaped to (64, 64, 32) with 32 components
# Image 3886/6804 reshaped to (64, 64, 32) with 32 components
# Image 3887/6804 reshaped to (64, 64, 32) with 32 components
# Image 3888/6804 reshaped to (64, 64, 32) with 32 components
# Image 3889/6804 reshaped to (64, 64, 32) with 32 components
# Image 3890/6804 reshaped to (64, 64, 32) with 32 components
# Image 3891/6804 reshaped to (64, 64, 32) with 32 components
# Image 3892/6804 reshaped to (64, 64, 32) with 32 components
# Image 3893/6804 reshaped to (64, 64, 32) with 32 components
# Image 3894/6804 reshaped to (64, 64, 32) with 32 components
# Image 3895/6804 reshaped to (64, 64, 32) with 32 components
# Image 3896/6804 reshaped to (64, 64, 32) with 32 components
# Image 3897/6804 reshaped to (64, 64, 32) with 32 components
# Image 3898/6804 reshaped to (64, 64, 32) with 32 components
# Image 3899/6804 reshaped to (64, 64, 32) with 32 components
# Image 3900/6804 reshaped to (64, 64, 32) with 32 components
# Image 3901/6804 reshaped to (64, 64, 32) with 32 components
# Image 3902/6804 reshaped to (64, 64, 32) with 32 components
# Image 3903/6804 reshaped to (64, 64, 32) with 32 components
# Image 3904/6804 reshaped to (64, 64, 32) with 32 components
# Image 3905/6804 reshaped to (64, 64, 32) with 32 components
# Image 3906/6804 reshaped to (64, 64, 32) with 32 components
# Image 3907/6804 reshaped to (64, 64, 32) with 32 components
# Image 3908/6804 reshaped to (64, 64, 32) with 32 components
# Image 3909/6804 reshaped to (64, 64, 32) with 32 components
# Image 3910/6804 reshaped to (64, 64, 32) with 32 components
# Image 3911/6804 reshaped to (64, 64, 32) with 32 components
# Image 3912/6804 reshaped to (64, 64, 32) with 32 components
# Image 3913/6804 reshaped to (64, 64, 32) with 32 components
# Image 3914/6804 reshaped to (64, 64, 32) with 32 components
# Image 3915/6804 reshaped to (64, 64, 32) with 32 components
# Image 3916/6804 reshaped to (64, 64, 32) with 32 components
# Image 3917/6804 reshaped to (64, 64, 32) with 32 components
# Image 3918/6804 reshaped to (64, 64, 32) with 32 components
# Image 3919/6804 reshaped to (64, 64, 32) with 32 components
# Image 3920/6804 reshaped to (64, 64, 32) with 32 components
# Image 3921/6804 reshaped to (64, 64, 32) with 32 components
# Image 3922/6804 reshaped to (64, 64, 32) with 32 components
# Image 3923/6804 reshaped to (64, 64, 32) with 32 components
# Image 3924/6804 reshaped to (64, 64, 32) with 32 components
# Image 3925/6804 reshaped to (64, 64, 32) with 32 components
# Image 3926/6804 reshaped to (64, 64, 32) with 32 components
# Image 3927/6804 reshaped to (64, 64, 32) with 32 components
# Image 3928/6804 reshaped to (64, 64, 32) with 32 components
# Image 3929/6804 reshaped to (64, 64, 32) with 32 components
# Image 3930/6804 reshaped to (64, 64, 32) with 32 components
# Image 3931/6804 reshaped to (64, 64, 32) with 32 components
# Image 3932/6804 reshaped to (64, 64, 32) with 32 components
# Image 3933/6804 reshaped to (64, 64, 32) with 32 components
# Image 3934/6804 reshaped to (64, 64, 32) with 32 components
# Image 3935/6804 reshaped to (64, 64, 32) with 32 components
# Image 3936/6804 reshaped to (64, 64, 32) with 32 components
# Image 3937/6804 reshaped to (64, 64, 32) with 32 components
# Image 3938/6804 reshaped to (64, 64, 32) with 32 components
# Image 3939/6804 reshaped to (64, 64, 32) with 32 components
# Image 3940/6804 reshaped to (64, 64, 32) with 32 components
# Image 3941/6804 reshaped to (64, 64, 32) with 32 components
# Image 3942/6804 reshaped to (64, 64, 32) with 32 components
# Image 3943/6804 reshaped to (64, 64, 32) with 32 components
# Image 3944/6804 reshaped to (64, 64, 32) with 32 components
# Image 3945/6804 reshaped to (64, 64, 32) with 32 components
# Image 3946/6804 reshaped to (64, 64, 32) with 32 components
# Image 3947/6804 reshaped to (64, 64, 32) with 32 components
# Image 3948/6804 reshaped to (64, 64, 32) with 32 components
# Image 3949/6804 reshaped to (64, 64, 32) with 32 components
# Image 3950/6804 reshaped to (64, 64, 32) with 32 components
# Image 3951/6804 reshaped to (64, 64, 32) with 32 components
# Image 3952/6804 reshaped to (64, 64, 32) with 32 components
# Image 3953/6804 reshaped to (64, 64, 32) with 32 components
# Image 3954/6804 reshaped to (64, 64, 32) with 32 components
# Image 3955/6804 reshaped to (64, 64, 32) with 32 components
# Image 3956/6804 reshaped to (64, 64, 32) with 32 components
# Image 3957/6804 reshaped to (64, 64, 32) with 32 components
# Image 3958/6804 reshaped to (64, 64, 32) with 32 components
# Image 3959/6804 reshaped to (64, 64, 32) with 32 components
# Image 3960/6804 reshaped to (64, 64, 32) with 32 components
# Image 3961/6804 reshaped to (64, 64, 32) with 32 components
# Image 3962/6804 reshaped to (64, 64, 32) with 32 components
# Image 3963/6804 reshaped to (64, 64, 32) with 32 components
# Image 3964/6804 reshaped to (64, 64, 32) with 32 components
# Image 3965/6804 reshaped to (64, 64, 32) with 32 components
# Image 3966/6804 reshaped to (64, 64, 32) with 32 components
# Image 3967/6804 reshaped to (64, 64, 32) with 32 components
# Image 3968/6804 reshaped to (64, 64, 32) with 32 components
# Image 3969/6804 reshaped to (64, 64, 32) with 32 components
# Image 3970/6804 reshaped to (64, 64, 32) with 32 components
# Image 3971/6804 reshaped to (64, 64, 32) with 32 components
# Image 3972/6804 reshaped to (64, 64, 32) with 32 components
# Image 3973/6804 reshaped to (64, 64, 32) with 32 components
# Image 3974/6804 reshaped to (64, 64, 32) with 32 components
# Image 3975/6804 reshaped to (64, 64, 32) with 32 components
# Image 3976/6804 reshaped to (64, 64, 32) with 32 components
# Image 3977/6804 reshaped to (64, 64, 32) with 32 components
# Image 3978/6804 reshaped to (64, 64, 32) with 32 components
# Image 3979/6804 reshaped to (64, 64, 32) with 32 components
# Image 3980/6804 reshaped to (64, 64, 32) with 32 components
# Image 3981/6804 reshaped to (64, 64, 32) with 32 components
# Image 3982/6804 reshaped to (64, 64, 32) with 32 components
# Image 3983/6804 reshaped to (64, 64, 32) with 32 components
# Image 3984/6804 reshaped to (64, 64, 32) with 32 components
# Image 3985/6804 reshaped to (64, 64, 32) with 32 components
# Image 3986/6804 reshaped to (64, 64, 32) with 32 components
# Image 3987/6804 reshaped to (64, 64, 32) with 32 components
# Image 3988/6804 reshaped to (64, 64, 32) with 32 components
# Image 3989/6804 reshaped to (64, 64, 32) with 32 components
# Image 3990/6804 reshaped to (64, 64, 32) with 32 components
# Image 3991/6804 reshaped to (64, 64, 32) with 32 components
# Image 3992/6804 reshaped to (64, 64, 32) with 32 components
# Image 3993/6804 reshaped to (64, 64, 32) with 32 components
# Image 3994/6804 reshaped to (64, 64, 32) with 32 components
# Image 3995/6804 reshaped to (64, 64, 32) with 32 components
# Image 3996/6804 reshaped to (64, 64, 32) with 32 components
# Image 3997/6804 reshaped to (64, 64, 32) with 32 components
# Image 3998/6804 reshaped to (64, 64, 32) with 32 components
# Image 3999/6804 reshaped to (64, 64, 32) with 32 components
# Image 4000/6804 reshaped to (64, 64, 32) with 32 components
# Image 4001/6804 reshaped to (64, 64, 32) with 32 components
# Image 4002/6804 reshaped to (64, 64, 32) with 32 components
# Image 4003/6804 reshaped to (64, 64, 32) with 32 components
# Image 4004/6804 reshaped to (64, 64, 32) with 32 components
# Image 4005/6804 reshaped to (64, 64, 32) with 32 components
# Image 4006/6804 reshaped to (64, 64, 32) with 32 components
# Image 4007/6804 reshaped to (64, 64, 32) with 32 components
# Image 4008/6804 reshaped to (64, 64, 32) with 32 components
# Image 4009/6804 reshaped to (64, 64, 32) with 32 components
# Image 4010/6804 reshaped to (64, 64, 32) with 32 components
# Image 4011/6804 reshaped to (64, 64, 32) with 32 components
# Image 4012/6804 reshaped to (64, 64, 32) with 32 components
# Image 4013/6804 reshaped to (64, 64, 32) with 32 components
# Image 4014/6804 reshaped to (64, 64, 32) with 32 components
# Image 4015/6804 reshaped to (64, 64, 32) with 32 components
# Image 4016/6804 reshaped to (64, 64, 32) with 32 components
# Image 4017/6804 reshaped to (64, 64, 32) with 32 components
# Image 4018/6804 reshaped to (64, 64, 32) with 32 components
# Image 4019/6804 reshaped to (64, 64, 32) with 32 components
# Image 4020/6804 reshaped to (64, 64, 32) with 32 components
# Image 4021/6804 reshaped to (64, 64, 32) with 32 components
# Image 4022/6804 reshaped to (64, 64, 32) with 32 components
# Image 4023/6804 reshaped to (64, 64, 32) with 32 components
# Image 4024/6804 reshaped to (64, 64, 32) with 32 components
# Image 4025/6804 reshaped to (64, 64, 32) with 32 components
# Image 4026/6804 reshaped to (64, 64, 32) with 32 components
# Image 4027/6804 reshaped to (64, 64, 32) with 32 components
# Image 4028/6804 reshaped to (64, 64, 32) with 32 components
# Image 4029/6804 reshaped to (64, 64, 32) with 32 components
# Image 4030/6804 reshaped to (64, 64, 32) with 32 components
# Image 4031/6804 reshaped to (64, 64, 32) with 32 components
# Image 4032/6804 reshaped to (64, 64, 32) with 32 components
# Image 4033/6804 reshaped to (64, 64, 32) with 32 components
# Image 4034/6804 reshaped to (64, 64, 32) with 32 components
# Image 4035/6804 reshaped to (64, 64, 32) with 32 components
# Image 4036/6804 reshaped to (64, 64, 32) with 32 components
# Image 4037/6804 reshaped to (64, 64, 32) with 32 components
# Image 4038/6804 reshaped to (64, 64, 32) with 32 components
# Image 4039/6804 reshaped to (64, 64, 32) with 32 components
# Image 4040/6804 reshaped to (64, 64, 32) with 32 components
# Image 4041/6804 reshaped to (64, 64, 32) with 32 components
# Image 4042/6804 reshaped to (64, 64, 32) with 32 components
# Image 4043/6804 reshaped to (64, 64, 32) with 32 components
# Image 4044/6804 reshaped to (64, 64, 32) with 32 components
# Image 4045/6804 reshaped to (64, 64, 32) with 32 components
# Image 4046/6804 reshaped to (64, 64, 32) with 32 components
# Image 4047/6804 reshaped to (64, 64, 32) with 32 components
# Image 4048/6804 reshaped to (64, 64, 32) with 32 components
# Image 4049/6804 reshaped to (64, 64, 32) with 32 components
# Image 4050/6804 reshaped to (64, 64, 32) with 32 components
# Image 4051/6804 reshaped to (64, 64, 32) with 32 components
# Image 4052/6804 reshaped to (64, 64, 32) with 32 components
# Image 4053/6804 reshaped to (64, 64, 32) with 32 components
# Image 4054/6804 reshaped to (64, 64, 32) with 32 components
# Image 4055/6804 reshaped to (64, 64, 32) with 32 components
# Image 4056/6804 reshaped to (64, 64, 32) with 32 components
# Image 4057/6804 reshaped to (64, 64, 32) with 32 components
# Image 4058/6804 reshaped to (64, 64, 32) with 32 components
# Image 4059/6804 reshaped to (64, 64, 32) with 32 components
# Image 4060/6804 reshaped to (64, 64, 32) with 32 components
# Image 4061/6804 reshaped to (64, 64, 32) with 32 components
# Image 4062/6804 reshaped to (64, 64, 32) with 32 components
# Image 4063/6804 reshaped to (64, 64, 32) with 32 components
# Image 4064/6804 reshaped to (64, 64, 32) with 32 components
# Image 4065/6804 reshaped to (64, 64, 32) with 32 components
# Image 4066/6804 reshaped to (64, 64, 32) with 32 components
# Image 4067/6804 reshaped to (64, 64, 32) with 32 components
# Image 4068/6804 reshaped to (64, 64, 32) with 32 components
# Image 4069/6804 reshaped to (64, 64, 32) with 32 components
# Image 4070/6804 reshaped to (64, 64, 32) with 32 components
# Image 4071/6804 reshaped to (64, 64, 32) with 32 components
# Image 4072/6804 reshaped to (64, 64, 32) with 32 components
# Image 4073/6804 reshaped to (64, 64, 32) with 32 components
# Image 4074/6804 reshaped to (64, 64, 32) with 32 components
# Image 4075/6804 reshaped to (64, 64, 32) with 32 components
# Image 4076/6804 reshaped to (64, 64, 32) with 32 components
# Image 4077/6804 reshaped to (64, 64, 32) with 32 components
# Image 4078/6804 reshaped to (64, 64, 32) with 32 components
# Image 4079/6804 reshaped to (64, 64, 32) with 32 components
# Image 4080/6804 reshaped to (64, 64, 32) with 32 components
# Image 4081/6804 reshaped to (64, 64, 32) with 32 components
# Image 4082/6804 reshaped to (64, 64, 32) with 32 components
# Image 4083/6804 reshaped to (64, 64, 32) with 32 components
# Image 4084/6804 reshaped to (64, 64, 32) with 32 components
# Image 4085/6804 reshaped to (64, 64, 32) with 32 components
# Image 4086/6804 reshaped to (64, 64, 32) with 32 components
# Image 4087/6804 reshaped to (64, 64, 32) with 32 components
# Image 4088/6804 reshaped to (64, 64, 32) with 32 components
# Image 4089/6804 reshaped to (64, 64, 32) with 32 components
# Image 4090/6804 reshaped to (64, 64, 32) with 32 components
# Image 4091/6804 reshaped to (64, 64, 32) with 32 components
# Image 4092/6804 reshaped to (64, 64, 32) with 32 components
# Image 4093/6804 reshaped to (64, 64, 32) with 32 components
# Image 4094/6804 reshaped to (64, 64, 32) with 32 components
# Image 4095/6804 reshaped to (64, 64, 32) with 32 components
# Image 4096/6804 reshaped to (64, 64, 32) with 32 components
# Image 4097/6804 reshaped to (64, 64, 32) with 32 components
# Image 4098/6804 reshaped to (64, 64, 32) with 32 components
# Image 4099/6804 reshaped to (64, 64, 32) with 32 components
# Image 4100/6804 reshaped to (64, 64, 32) with 32 components
# Image 4101/6804 reshaped to (64, 64, 32) with 32 components
# Image 4102/6804 reshaped to (64, 64, 32) with 32 components
# Image 4103/6804 reshaped to (64, 64, 32) with 32 components
# Image 4104/6804 reshaped to (64, 64, 32) with 32 components
# Image 4105/6804 reshaped to (64, 64, 32) with 32 components
# Image 4106/6804 reshaped to (64, 64, 32) with 32 components
# Image 4107/6804 reshaped to (64, 64, 32) with 32 components
# Image 4108/6804 reshaped to (64, 64, 32) with 32 components
# Image 4109/6804 reshaped to (64, 64, 32) with 32 components
# Image 4110/6804 reshaped to (64, 64, 32) with 32 components
# Image 4111/6804 reshaped to (64, 64, 32) with 32 components
# Image 4112/6804 reshaped to (64, 64, 32) with 32 components
# Image 4113/6804 reshaped to (64, 64, 32) with 32 components
# Image 4114/6804 reshaped to (64, 64, 32) with 32 components
# Image 4115/6804 reshaped to (64, 64, 32) with 32 components
# Image 4116/6804 reshaped to (64, 64, 32) with 32 components
# Image 4117/6804 reshaped to (64, 64, 32) with 32 components
# Image 4118/6804 reshaped to (64, 64, 32) with 32 components
# Image 4119/6804 reshaped to (64, 64, 32) with 32 components
# Image 4120/6804 reshaped to (64, 64, 32) with 32 components
# Image 4121/6804 reshaped to (64, 64, 32) with 32 components
# Image 4122/6804 reshaped to (64, 64, 32) with 32 components
# Image 4123/6804 reshaped to (64, 64, 32) with 32 components
# Image 4124/6804 reshaped to (64, 64, 32) with 32 components
# Image 4125/6804 reshaped to (64, 64, 32) with 32 components
# Image 4126/6804 reshaped to (64, 64, 32) with 32 components
# Image 4127/6804 reshaped to (64, 64, 32) with 32 components
# Image 4128/6804 reshaped to (64, 64, 32) with 32 components
# Image 4129/6804 reshaped to (64, 64, 32) with 32 components
# Image 4130/6804 reshaped to (64, 64, 32) with 32 components
# Image 4131/6804 reshaped to (64, 64, 32) with 32 components
# Image 4132/6804 reshaped to (64, 64, 32) with 32 components
# Image 4133/6804 reshaped to (64, 64, 32) with 32 components
# Image 4134/6804 reshaped to (64, 64, 32) with 32 components
# Image 4135/6804 reshaped to (64, 64, 32) with 32 components
# Image 4136/6804 reshaped to (64, 64, 32) with 32 components
# Image 4137/6804 reshaped to (64, 64, 32) with 32 components
# Image 4138/6804 reshaped to (64, 64, 32) with 32 components
# Image 4139/6804 reshaped to (64, 64, 32) with 32 components
# Image 4140/6804 reshaped to (64, 64, 32) with 32 components
# Image 4141/6804 reshaped to (64, 64, 32) with 32 components
# Image 4142/6804 reshaped to (64, 64, 32) with 32 components
# Image 4143/6804 reshaped to (64, 64, 32) with 32 components
# Image 4144/6804 reshaped to (64, 64, 32) with 32 components
# Image 4145/6804 reshaped to (64, 64, 32) with 32 components
# Image 4146/6804 reshaped to (64, 64, 32) with 32 components
# Image 4147/6804 reshaped to (64, 64, 32) with 32 components
# Image 4148/6804 reshaped to (64, 64, 32) with 32 components
# Image 4149/6804 reshaped to (64, 64, 32) with 32 components
# Image 4150/6804 reshaped to (64, 64, 32) with 32 components
# Image 4151/6804 reshaped to (64, 64, 32) with 32 components
# Image 4152/6804 reshaped to (64, 64, 32) with 32 components
# Image 4153/6804 reshaped to (64, 64, 32) with 32 components
# Image 4154/6804 reshaped to (64, 64, 32) with 32 components
# Image 4155/6804 reshaped to (64, 64, 32) with 32 components
# Image 4156/6804 reshaped to (64, 64, 32) with 32 components
# Image 4157/6804 reshaped to (64, 64, 32) with 32 components
# Image 4158/6804 reshaped to (64, 64, 32) with 32 components
# Image 4159/6804 reshaped to (64, 64, 32) with 32 components
# Image 4160/6804 reshaped to (64, 64, 32) with 32 components
# Image 4161/6804 reshaped to (64, 64, 32) with 32 components
# Image 4162/6804 reshaped to (64, 64, 32) with 32 components
# Image 4163/6804 reshaped to (64, 64, 32) with 32 components
# Image 4164/6804 reshaped to (64, 64, 32) with 32 components
# Image 4165/6804 reshaped to (64, 64, 32) with 32 components
# Image 4166/6804 reshaped to (64, 64, 32) with 32 components
# Image 4167/6804 reshaped to (64, 64, 32) with 32 components
# ...
# Image 522/780 reshaped to (64, 64, 32) with 32 components
# Image 523/780 reshaped to (64, 64, 32) with 32 components
# Image 524/780 reshaped to (64, 64, 32) with 32 components
# Image 525/780 reshaped to (64, 64, 32) with 32 components
# Image 526/780 reshaped to (64, 64, 32) with 32 components
# Image 527/780 reshaped to (64, 64, 32) with 32 components
# Image 528/780 reshaped to (64, 64, 32) with 32 components
# Image 529/780 reshaped to (64, 64, 32) with 32 components
# Image 530/780 reshaped to (64, 64, 32) with 32 components
# Image 531/780 reshaped to (64, 64, 32) with 32 components
# Image 532/780 reshaped to (64, 64, 32) with 32 components
# Image 533/780 reshaped to (64, 64, 32) with 32 components
# Image 534/780 reshaped to (64, 64, 32) with 32 components
# Image 535/780 reshaped to (64, 64, 32) with 32 components
# Image 536/780 reshaped to (64, 64, 32) with 32 components
# Image 537/780 reshaped to (64, 64, 32) with 32 components
# Image 538/780 reshaped to (64, 64, 32) with 32 components
# Image 539/780 reshaped to (64, 64, 32) with 32 components
# Image 540/780 reshaped to (64, 64, 32) with 32 components
# Image 541/780 reshaped to (64, 64, 32) with 32 components
# Image 542/780 reshaped to (64, 64, 32) with 32 components
# Image 543/780 reshaped to (64, 64, 32) with 32 components
# Image 544/780 reshaped to (64, 64, 32) with 32 components
# Image 545/780 reshaped to (64, 64, 32) with 32 components
# Image 546/780 reshaped to (64, 64, 32) with 32 components
# Image 547/780 reshaped to (64, 64, 32) with 32 components
# Image 548/780 reshaped to (64, 64, 32) with 32 components
# Image 549/780 reshaped to (64, 64, 32) with 32 components
# Image 550/780 reshaped to (64, 64, 32) with 32 components
# Image 551/780 reshaped to (64, 64, 32) with 32 components
# Image 552/780 reshaped to (64, 64, 32) with 32 components
# Image 553/780 reshaped to (64, 64, 32) with 32 components
# Image 554/780 reshaped to (64, 64, 32) with 32 components
# Image 555/780 reshaped to (64, 64, 32) with 32 components
# Image 556/780 reshaped to (64, 64, 32) with 32 components
# Image 557/780 reshaped to (64, 64, 32) with 32 components
# Image 558/780 reshaped to (64, 64, 32) with 32 components
# Image 559/780 reshaped to (64, 64, 32) with 32 components
# Image 560/780 reshaped to (64, 64, 32) with 32 components
# Image 561/780 reshaped to (64, 64, 32) with 32 components
# Image 562/780 reshaped to (64, 64, 32) with 32 components
# Image 563/780 reshaped to (64, 64, 32) with 32 components
# Image 564/780 reshaped to (64, 64, 32) with 32 components
# Image 565/780 reshaped to (64, 64, 32) with 32 components
# Image 566/780 reshaped to (64, 64, 32) with 32 components
# Image 567/780 reshaped to (64, 64, 32) with 32 components
# Image 568/780 reshaped to (64, 64, 32) with 32 components
# Image 569/780 reshaped to (64, 64, 32) with 32 components
# Image 570/780 reshaped to (64, 64, 32) with 32 components
# Image 571/780 reshaped to (64, 64, 32) with 32 components
# Image 572/780 reshaped to (64, 64, 32) with 32 components
# Image 573/780 reshaped to (64, 64, 32) with 32 components
# Image 574/780 reshaped to (64, 64, 32) with 32 components
# Image 575/780 reshaped to (64, 64, 32) with 32 components
# Image 576/780 reshaped to (64, 64, 32) with 32 components
# Image 577/780 reshaped to (64, 64, 32) with 32 components
# Image 578/780 reshaped to (64, 64, 32) with 32 components
# Image 579/780 reshaped to (64, 64, 32) with 32 components
# Image 580/780 reshaped to (64, 64, 32) with 32 components
# Image 581/780 reshaped to (64, 64, 32) with 32 components
# Image 582/780 reshaped to (64, 64, 32) with 32 components
# Image 583/780 reshaped to (64, 64, 32) with 32 components
# Image 584/780 reshaped to (64, 64, 32) with 32 components
# Image 585/780 reshaped to (64, 64, 32) with 32 components
# Image 586/780 reshaped to (64, 64, 32) with 32 components
# Image 587/780 reshaped to (64, 64, 32) with 32 components
# Image 588/780 reshaped to (64, 64, 32) with 32 components
# Image 589/780 reshaped to (64, 64, 32) with 32 components
# Image 590/780 reshaped to (64, 64, 32) with 32 components
# Image 591/780 reshaped to (64, 64, 32) with 32 components
# Image 592/780 reshaped to (64, 64, 32) with 32 components
# Image 593/780 reshaped to (64, 64, 32) with 32 components
# Image 594/780 reshaped to (64, 64, 32) with 32 components
# Image 595/780 reshaped to (64, 64, 32) with 32 components
# Image 596/780 reshaped to (64, 64, 32) with 32 components
# Image 597/780 reshaped to (64, 64, 32) with 32 components
# Image 598/780 reshaped to (64, 64, 32) with 32 components
# Image 599/780 reshaped to (64, 64, 32) with 32 components
# Image 600/780 reshaped to (64, 64, 32) with 32 components
# Image 601/780 reshaped to (64, 64, 32) with 32 components
# Image 602/780 reshaped to (64, 64, 32) with 32 components
# Image 603/780 reshaped to (64, 64, 32) with 32 components
# Image 604/780 reshaped to (64, 64, 32) with 32 components
# Image 605/780 reshaped to (64, 64, 32) with 32 components
# Image 606/780 reshaped to (64, 64, 32) with 32 components
# Image 607/780 reshaped to (64, 64, 32) with 32 components
# Image 608/780 reshaped to (64, 64, 32) with 32 components
# Image 609/780 reshaped to (64, 64, 32) with 32 components
# Image 610/780 reshaped to (64, 64, 32) with 32 components
# Image 611/780 reshaped to (64, 64, 32) with 32 components
# Image 612/780 reshaped to (64, 64, 32) with 32 components
# Image 613/780 reshaped to (64, 64, 32) with 32 components
# Image 614/780 reshaped to (64, 64, 32) with 32 components
# Image 615/780 reshaped to (64, 64, 32) with 32 components
# Image 616/780 reshaped to (64, 64, 32) with 32 components
# Image 617/780 reshaped to (64, 64, 32) with 32 components
# Image 618/780 reshaped to (64, 64, 32) with 32 components
# Image 619/780 reshaped to (64, 64, 32) with 32 components
# Image 620/780 reshaped to (64, 64, 32) with 32 components
# Image 621/780 reshaped to (64, 64, 32) with 32 components
# Image 622/780 reshaped to (64, 64, 32) with 32 components
# Image 623/780 reshaped to (64, 64, 32) with 32 components
# Image 624/780 reshaped to (64, 64, 32) with 32 components
# Image 625/780 reshaped to (64, 64, 32) with 32 components
# Image 626/780 reshaped to (64, 64, 32) with 32 components
# Image 627/780 reshaped to (64, 64, 32) with 32 components
# Image 628/780 reshaped to (64, 64, 32) with 32 components
# Image 629/780 reshaped to (64, 64, 32) with 32 components
# Image 630/780 reshaped to (64, 64, 32) with 32 components
# Image 631/780 reshaped to (64, 64, 32) with 32 components
# Image 632/780 reshaped to (64, 64, 32) with 32 components
# Image 633/780 reshaped to (64, 64, 32) with 32 components
# Image 634/780 reshaped to (64, 64, 32) with 32 components
# Image 635/780 reshaped to (64, 64, 32) with 32 components
# Image 636/780 reshaped to (64, 64, 32) with 32 components
# Image 637/780 reshaped to (64, 64, 32) with 32 components
# Image 638/780 reshaped to (64, 64, 32) with 32 components
# Image 639/780 reshaped to (64, 64, 32) with 32 components
# Image 640/780 reshaped to (64, 64, 32) with 32 components
# Image 641/780 reshaped to (64, 64, 32) with 32 components
# Image 642/780 reshaped to (64, 64, 32) with 32 components
# Image 643/780 reshaped to (64, 64, 32) with 32 components
# Image 644/780 reshaped to (64, 64, 32) with 32 components
# Image 645/780 reshaped to (64, 64, 32) with 32 components
# Image 646/780 reshaped to (64, 64, 32) with 32 components
# Image 647/780 reshaped to (64, 64, 32) with 32 components
# Image 648/780 reshaped to (64, 64, 32) with 32 components
# Image 649/780 reshaped to (64, 64, 32) with 32 components
# Image 650/780 reshaped to (64, 64, 32) with 32 components
# Image 651/780 reshaped to (64, 64, 32) with 32 components
# Image 652/780 reshaped to (64, 64, 32) with 32 components
# Image 653/780 reshaped to (64, 64, 32) with 32 components
# Image 654/780 reshaped to (64, 64, 32) with 32 components
# Image 655/780 reshaped to (64, 64, 32) with 32 components
# Image 656/780 reshaped to (64, 64, 32) with 32 components
# Image 657/780 reshaped to (64, 64, 32) with 32 components
# Image 658/780 reshaped to (64, 64, 32) with 32 components
# Image 659/780 reshaped to (64, 64, 32) with 32 components
# Image 660/780 reshaped to (64, 64, 32) with 32 components
# Image 661/780 reshaped to (64, 64, 32) with 32 components
# Image 662/780 reshaped to (64, 64, 32) with 32 components
# Image 663/780 reshaped to (64, 64, 32) with 32 components
# Image 664/780 reshaped to (64, 64, 32) with 32 components
# Image 665/780 reshaped to (64, 64, 32) with 32 components
# Image 666/780 reshaped to (64, 64, 32) with 32 components
# Image 667/780 reshaped to (64, 64, 32) with 32 components
# Image 668/780 reshaped to (64, 64, 32) with 32 components
# Image 669/780 reshaped to (64, 64, 32) with 32 components
# Image 670/780 reshaped to (64, 64, 32) with 32 components
# Image 671/780 reshaped to (64, 64, 32) with 32 components
# Image 672/780 reshaped to (64, 64, 32) with 32 components
# Image 673/780 reshaped to (64, 64, 32) with 32 components
# Image 674/780 reshaped to (64, 64, 32) with 32 components
# Image 675/780 reshaped to (64, 64, 32) with 32 components
# Image 676/780 reshaped to (64, 64, 32) with 32 components
# Image 677/780 reshaped to (64, 64, 32) with 32 components
# Image 678/780 reshaped to (64, 64, 32) with 32 components
# Image 679/780 reshaped to (64, 64, 32) with 32 components
# Image 680/780 reshaped to (64, 64, 32) with 32 components
# Image 681/780 reshaped to (64, 64, 32) with 32 components
# Image 682/780 reshaped to (64, 64, 32) with 32 components
# Image 683/780 reshaped to (64, 64, 32) with 32 components
# Image 684/780 reshaped to (64, 64, 32) with 32 components
# Image 685/780 reshaped to (64, 64, 32) with 32 components
# Image 686/780 reshaped to (64, 64, 32) with 32 components
# Image 687/780 reshaped to (64, 64, 32) with 32 components
# Image 688/780 reshaped to (64, 64, 32) with 32 components
# Image 689/780 reshaped to (64, 64, 32) with 32 components
# Image 690/780 reshaped to (64, 64, 32) with 32 components
# Image 691/780 reshaped to (64, 64, 32) with 32 components
# Image 692/780 reshaped to (64, 64, 32) with 32 components
# Image 693/780 reshaped to (64, 64, 32) with 32 components
# Image 694/780 reshaped to (64, 64, 32) with 32 components
# Image 695/780 reshaped to (64, 64, 32) with 32 components
# Image 696/780 reshaped to (64, 64, 32) with 32 components
# Image 697/780 reshaped to (64, 64, 32) with 32 components
# Image 698/780 reshaped to (64, 64, 32) with 32 components
# Image 699/780 reshaped to (64, 64, 32) with 32 components
# Image 700/780 reshaped to (64, 64, 32) with 32 components
# Image 701/780 reshaped to (64, 64, 32) with 32 components
# Image 702/780 reshaped to (64, 64, 32) with 32 components
# Image 703/780 reshaped to (64, 64, 32) with 32 components
# Image 704/780 reshaped to (64, 64, 32) with 32 components
# Image 705/780 reshaped to (64, 64, 32) with 32 components
# Image 706/780 reshaped to (64, 64, 32) with 32 components
# Image 707/780 reshaped to (64, 64, 32) with 32 components
# Image 708/780 reshaped to (64, 64, 32) with 32 components
# Image 709/780 reshaped to (64, 64, 32) with 32 components
# Image 710/780 reshaped to (64, 64, 32) with 32 components
# Image 711/780 reshaped to (64, 64, 32) with 32 components
# Image 712/780 reshaped to (64, 64, 32) with 32 components
# Image 713/780 reshaped to (64, 64, 32) with 32 components
# Image 714/780 reshaped to (64, 64, 32) with 32 components
# Image 715/780 reshaped to (64, 64, 32) with 32 components
# Image 716/780 reshaped to (64, 64, 32) with 32 components
# Image 717/780 reshaped to (64, 64, 32) with 32 components
# Image 718/780 reshaped to (64, 64, 32) with 32 components
# Image 719/780 reshaped to (64, 64, 32) with 32 components
# Image 720/780 reshaped to (64, 64, 32) with 32 components
# Image 721/780 reshaped to (64, 64, 32) with 32 components
# Image 722/780 reshaped to (64, 64, 32) with 32 components
# Image 723/780 reshaped to (64, 64, 32) with 32 components
# Image 724/780 reshaped to (64, 64, 32) with 32 components
# Image 725/780 reshaped to (64, 64, 32) with 32 components
# Image 726/780 reshaped to (64, 64, 32) with 32 components
# Image 727/780 reshaped to (64, 64, 32) with 32 components
# Image 728/780 reshaped to (64, 64, 32) with 32 components
# Image 729/780 reshaped to (64, 64, 32) with 32 components
# Image 730/780 reshaped to (64, 64, 32) with 32 components
# Image 731/780 reshaped to (64, 64, 32) with 32 components
# Image 732/780 reshaped to (64, 64, 32) with 32 components
# Image 733/780 reshaped to (64, 64, 32) with 32 components
# Image 734/780 reshaped to (64, 64, 32) with 32 components
# Image 735/780 reshaped to (64, 64, 32) with 32 components
# Image 736/780 reshaped to (64, 64, 32) with 32 components
# Image 737/780 reshaped to (64, 64, 32) with 32 components
# Image 738/780 reshaped to (64, 64, 32) with 32 components
# Image 739/780 reshaped to (64, 64, 32) with 32 components
# Image 740/780 reshaped to (64, 64, 32) with 32 components
# Image 741/780 reshaped to (64, 64, 32) with 32 components
# Image 742/780 reshaped to (64, 64, 32) with 32 components
# Image 743/780 reshaped to (64, 64, 32) with 32 components
# Image 744/780 reshaped to (64, 64, 32) with 32 components
# Image 745/780 reshaped to (64, 64, 32) with 32 components
# Image 746/780 reshaped to (64, 64, 32) with 32 components
# Image 747/780 reshaped to (64, 64, 32) with 32 components
# Image 748/780 reshaped to (64, 64, 32) with 32 components
# Image 749/780 reshaped to (64, 64, 32) with 32 components
# Image 750/780 reshaped to (64, 64, 32) with 32 components
# Image 751/780 reshaped to (64, 64, 32) with 32 components
# Image 752/780 reshaped to (64, 64, 32) with 32 components
# Image 753/780 reshaped to (64, 64, 32) with 32 components
# Image 754/780 reshaped to (64, 64, 32) with 32 components
# Image 755/780 reshaped to (64, 64, 32) with 32 components
# Image 756/780 reshaped to (64, 64, 32) with 32 components
# Image 757/780 reshaped to (64, 64, 32) with 32 components
# Image 758/780 reshaped to (64, 64, 32) with 32 components
# Image 759/780 reshaped to (64, 64, 32) with 32 components
# Image 760/780 reshaped to (64, 64, 32) with 32 components
# Image 761/780 reshaped to (64, 64, 32) with 32 components
# Image 762/780 reshaped to (64, 64, 32) with 32 components
# Image 763/780 reshaped to (64, 64, 32) with 32 components
# Image 764/780 reshaped to (64, 64, 32) with 32 components
# Image 765/780 reshaped to (64, 64, 32) with 32 components
# Image 766/780 reshaped to (64, 64, 32) with 32 components
# Image 767/780 reshaped to (64, 64, 32) with 32 components
# Image 768/780 reshaped to (64, 64, 32) with 32 components
# Image 769/780 reshaped to (64, 64, 32) with 32 components
# Image 770/780 reshaped to (64, 64, 32) with 32 components
# Image 771/780 reshaped to (64, 64, 32) with 32 components
# Image 772/780 reshaped to (64, 64, 32) with 32 components
# Image 773/780 reshaped to (64, 64, 32) with 32 components
# Image 774/780 reshaped to (64, 64, 32) with 32 components
# Image 775/780 reshaped to (64, 64, 32) with 32 components
# Image 776/780 reshaped to (64, 64, 32) with 32 components
# Image 777/780 reshaped to (64, 64, 32) with 32 components
# Image 778/780 reshaped to (64, 64, 32) with 32 components
# Image 779/780 reshaped to (64, 64, 32) with 32 components
# Image 780/780 reshaped to (64, 64, 32) with 32 components
#
# Saving reduced training data...
# Saved 6804 items to /content/drive/MyDrive/DataSets/HSI-Augmented-Splitted/TrainTiles_32PCA_normalized.npz
#
# Saving reduced validation data...
# Saved 759 items to /content/drive/MyDrive/DataSets/HSI-Augmented-Splitted/ValTiles_32PCA_normalized.npz
#
# Saving reduced test data...
# Saved 780 items to /content/drive/MyDrive/DataSets/HSI-Augmented-Splitted/TestTiles_32PCA_normalized.npz
#
# Saving training labels...
# Saved 6804 items to /content/drive/MyDrive/DataSets/HSI-Augmented-Splitted/TrainLabels_32PCA_normalized.npz
#
# Saving validation labels...
# Saved 759 items to /content/drive/MyDrive/DataSets/HSI-Augmented-Splitted/ValLabels_32PCA_normalized.npz
#
# Saving test labels...
# Saved 780 items to /content/drive/MyDrive/DataSets/HSI-Augmented-Splitted/TestLabels_32PCA_normalized.npz
#
# Saving test masks...
# Test masks saved to /content/drive/MyDrive/DataSets/HSI-Augmented-Splitted/TestMasks_32PCA_normalized.npz
# 0
